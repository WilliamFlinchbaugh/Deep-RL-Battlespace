# %%
# pip install pygame # 2.1.2
# pip install numpy # 1.21.5
# pip install gym # 2.0.0
# pip install torch==1.10.2 # 1.10.2
# pip install stable-baselines3[extra] optuna # 1.5.0 for stable-baselines3, 2.10.1 for optuna

# %%
import random
import pygame
from pygame.locals import *
import numpy as np
import numpy.linalg as LA
import math
from collections import defaultdict
import gym
from gym import spaces
import os
import sys
os.environ['KMP_DUPLICATE_LIB_OK']='True'
# Out:
# pygame 2.1.2 (SDL 2.0.18, Python 3.9.12)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
WHITE = (255, 255, 255)
RED = (138, 24, 26)
BLUE = (0, 93, 135)
BLACK = (0, 0, 0)
DISP_WIDTH = 1000
DISP_HEIGHT = 1000

# %% [markdown]
# ---------- Helper Functions ----------

# %%
def get_angle(p0, p1):
    dx = p1[0] - p0[0]
    dy = p1[1] - p0[1]
    rads = math.atan2(-dy,dx)
    rads %= 2*math.pi
    degs = math.degrees(rads)
    return degs

def dist(p1,p0):
    return math.sqrt((p1[0]-p0[0])**2 + (p1[1]-p0[1])**2)

def blitRotate(image, pos, originPos, angle):

    # offset from pivot to center
    image_rect = image.get_rect(topleft = (pos[0] - originPos[0], pos[1]-originPos[1]))
    offset_center_to_pivot = pygame.math.Vector2(pos) - image_rect.center
    
    # roatated offset from pivot to center
    rotated_offset = offset_center_to_pivot.rotate(-angle)

    # rotated image center
    rotated_image_center = (pos[0] - rotated_offset.x, pos[1] - rotated_offset.y)

    # get a rotated image
    rotated_image = pygame.transform.rotate(image, angle)
    rotated_image_rect = rotated_image.get_rect(center = rotated_image_center)

    return rotated_image, rotated_image_rect

def calc_new_xy(old_xy, speed, time, angle):
    new_x = old_xy[0] + (speed*time*math.cos(-math.radians(angle)))
    new_y = old_xy[1] + (speed*time*math.sin(-math.radians(angle)))
    return (new_x, new_y)

# %% [markdown]
# ---------- Plane Class ----------

# %%
class Plane:
    def __init__(self, team): 
        self.team = team
        self.image = pygame.image.load(f"Images/{team}_plane.png")
        self.w, self.h = self.image.get_size()
        self.direction = 0
        self.rect = self.image.get_rect()
        self.reset()

    def reset(self):
        if self.team == 'red':
            x = (DISP_WIDTH - self.w/2)/3 * random.random()
            y = (DISP_HEIGHT - self.h/2) * random.random()
            self.rect.center = (x, y)
            self.direction = 90 * random.random() if random.random() < .5 else 90 * random.random() + 270
            
        else:
            x = (DISP_WIDTH - self.w/2)/3 * random.random() + (DISP_WIDTH - self.w/2)/3*2
            y = (DISP_HEIGHT - self.h/2) * random.random()
            self.rect.center = (x, y)
            self.direction = 180 * random.random() + 90
        
    def rotate(self, angle):
        self.direction += angle
        while self.direction > 360:
            self.direction -= 360
        while self.direction < 0:
            self.direction += 360
        # Keep player on the screen
        if self.rect.left < 0:
            self.rect.left = 0
        if self.rect.right > DISP_WIDTH:
            self.rect.right = DISP_WIDTH
        if self.rect.top <= 0:
            self.rect.top = 0
        if self.rect.bottom >= DISP_HEIGHT:
            self.rect.bottom = DISP_HEIGHT

    def set_direction(self, direction):
        self.direction = direction

    def forward(self, speed, time):
        oldpos = self.rect.center
        self.rect.center = calc_new_xy(oldpos, speed, time, self.direction)
        # Keep player on the screen
        if self.rect.left < 0:
            self.rect.left = 0
        if self.rect.right > DISP_WIDTH:
            self.rect.right = DISP_WIDTH
        if self.rect.top <= 0:
            self.rect.top = 0
        if self.rect.bottom >= DISP_HEIGHT:
            self.rect.bottom = DISP_HEIGHT

    def draw(self, surface):
        image, rect = blitRotate(self.image, self.rect.center, (self.w/2, self.h/2), self.direction)
        surface.blit(image, rect)

    def update(self):
        # Keep player on the screen
        if self.rect.left < 0:
            self.rect.left = 0
        if self.rect.right > DISP_WIDTH:
            self.rect.right = DISP_WIDTH
        if self.rect.top <= 0:
            self.rect.top = 0
        if self.rect.bottom >= DISP_HEIGHT:
            self.rect.bottom = DISP_HEIGHT

    def get_pos(self):
        image, rect = blitRotate(self.image, self.rect.center, (self.w/2, self.h/2), self.direction)
        return (rect.centerx, rect.centery)
    
    def get_direction(self):
        return self.direction

# %% [markdown]
# ----------- Base Class ----------

# %%
class Base:
    
    def __init__(self, team):
        self.team = team
        self.image = pygame.image.load(f"Images/{team}_base.png")
        self.w, self.h = self.image.get_size()
        self.rect = self.image.get_rect()
        self.reset()
        
    def reset(self):
        if self.team == 'red':
            x = (DISP_WIDTH - self.w/2)/3 * random.random()
            y = (DISP_HEIGHT - self.h/2) * random.random()
            self.rect.center = (x, y)
        else:
            x = (DISP_WIDTH - self.w/2)/3 * random.random() + (DISP_WIDTH - self.w/2)/3*2
            y = (DISP_HEIGHT - self.h/2) * random.random()
            self.rect.center = (x, y)

    def draw(self, surface):
        surface.blit(self.image, self.rect)
            
    def get_pos(self):
        return self.rect.center

# %% [markdown]
# ---------- Bullet Class ----------

# %%
class Bullet(pygame.sprite.Sprite):
    def __init__(self, x, y, angle, speed, fteam, oteam):
        pygame.sprite.Sprite.__init__(self)
        self.off_screen = False
        self.image = pygame.Surface((6, 3), pygame.SRCALPHA)
        self.fteam = fteam
        self.color = RED if self.fteam == 'red' else BLUE
        self.oteam = oteam
        self.image.fill(self.color)
        self.rect = self.image.get_rect(center=(x, y))
        self.w, self.h = self.image.get_size()
        self.direction = angle + (random.random() * 10 - 5)
        self.pos = (x, y)
        self.speed = speed

    def update(self, screen_width, screen_height, time):
        oldpos = self.rect.center
        self.rect.center = calc_new_xy(oldpos, self.speed, time, self.direction)
        if self.rect.centerx > screen_width or self.rect.centerx < 0 or self.rect.centery > screen_height or self.rect.centery < 0:
            return 'miss'
        for plane in self.oteam['planes']:
            if self.rect.colliderect(plane.rect):
                return 'plane'
        if self.rect.colliderect(self.oteam['base'].rect):
            return 'base'
        return 'none'

    def draw(self, surface):
        image, rect = blitRotate(self.image, self.rect.center, (self.w/2, self.h/2), self.direction)
        surface.blit(image, rect)

    def get_pos(self):
        return self.rect.center
    
    def get_direction(self):
        return self.direction

# %% [markdown]
# ----------- Battle Environment ----------

# %%
class BattleEnvironment(gym.Env):
    def __init__(self, show=False, hit_base_reward=100, hit_plane_reward=100, miss_punishment=-5, too_long_punishment=0, closer_to_base_reward=0, 
        closer_to_plane_reward=0, lose_punishment=-50, fps=20):
        super(BattleEnvironment, self).__init__()

        self.width = DISP_WIDTH
        self.height = DISP_HEIGHT
        self.max_time = 10
        self.max_bullets = 10
        self.action_space = spaces.Discrete(4) # Forward, Turn to plane, Turn to base, Shoot

        # ---------- Observation Space ----------
        obs_space = {
            'fplane_x': spaces.Box(-1, 1, dtype=np.float32, shape=(1,)),
            'fplane_y': spaces.Box(-1, 1, dtype=np.float32, shape=(1,)),
            'fplane_direction': spaces.Box(-1, 1, dtype=np.float32, shape=(1,)),
            'rel_angle_oplane': spaces.Box(-1, 1, dtype=np.float32, shape=(1,)),
            'rel_angle_obase': spaces.Box(-1, 1, dtype=np.float32, shape=(1,)),
            'fbase_x': spaces.Box(-1, 1, shape=(1,)),
            'fbase_y': spaces.Box(-1, 1, dtype=np.float32, shape=(1,)),
            'oplane_x': spaces.Box(-1, 1, dtype=np.float32, shape=(1,)),
            'oplane_y': spaces.Box(-1, 1, dtype=np.float32, shape=(1,)),
            'oplane_direction': spaces.Box(-1, 1, dtype=np.float32, shape=(1,)),
            'obase_x': spaces.Box(-1, 1, dtype=np.float32, shape=(1,)),
            'obase_y': spaces.Box(-1, 1, dtype=np.float32, shape=(1,)),
            'time': spaces.Box(-1, 1, dtype=np.float32, shape=(1,))
        }

        for idx in range(self.max_bullets):
            obs_space[f'bullet_{idx}_shot'] = spaces.Box(-1, 1, dtype=np.int16, shape=(1,))
            obs_space[f'bullet_{idx}_x'] = spaces.Box(-1, 1, dtype=np.float32, shape=(1,))
            obs_space[f'bullet_{idx}_y'] = spaces.Box(-1, 1, dtype=np.float32, shape=(1,))
            obs_space[f'bullet_{idx}_direction'] = spaces.Box(-1, 1, dtype=np.float32, shape=(1,))
            obs_space[f'bullet_{idx}_dist_to_plane'] = spaces.Box(-1, 1, dtype=np.float32, shape=(1,))
            obs_space[f'bullet_{idx}_facing_plane'] = spaces.Box(-1, 1, dtype=np.float32, shape=(1,))

        mins = np.array([x.low[0] for x in obs_space.values()])
        maxs = np.array([x.high[0] for x in obs_space.values()])

        self.observation_space = spaces.Box(mins, maxs, dtype=np.float32)
        
        # ---------- Initialize values ----------
        self.team = {}
        self.team['red'] = {}
        self.team['blue'] = {}
        self.team['red']['base'] = Base('red')
        self.team['blue']['base'] = Base('blue')
        self.team['red']['planes'] = []
        self.team['red']['planes'].append(Plane('red'))
        self.team['blue']['planes'] = []
        self.team['blue']['planes'].append(Plane('blue'))
        self.team['red']['wins'] = 0
        self.team['blue']['wins'] = 0
        self.ties = 0
        self.bullets = {}
        self.speed = 400 # mph
        self.bullet_speed = 1000 # mph
        self.total_time = 0 # in hours
        self.time_step = 0.1 # hours per time step
        self.show = show # show the pygame animation
        self.step_turn = 25 # degrees to turn per step
        self.hit_base_reward = hit_base_reward
        self.hit_plane_reward = hit_plane_reward
        self.miss_punishment = miss_punishment
        self.too_long_punishment = too_long_punishment
        self.closer_to_base_reward = closer_to_base_reward
        self.closer_to_plane_reward = closer_to_plane_reward
        self.lose_punishment = lose_punishment
        self.fps = fps

        self.reset()
    
    def _get_observation(self):
        # Observation: Observation: fplane_pos, fplane_angle, obase_pos, oplane_pos, time
        # This code will all have to be changed when adding multiple planes
        fplane = self.team['red']['planes'][0]
        fbase = self.team['red']['base']
        oplane = self.team['blue']['planes'][0]
        obase = self.team['red']['base']

        fplane_pos = fplane.get_pos()
        fplane_direction = fplane.get_direction()
        fbase_pos = fbase.get_pos()
        oplane_pos = oplane.get_pos()
        oplane_direction = oplane.get_direction()
        obase_pos = obase.get_pos()

        angle_to_oplane = get_angle(fplane_pos, oplane_pos)
        angle_to_obase = get_angle(fplane_pos, obase_pos)
        rel_angle_oplane = (angle_to_oplane - fplane_direction)
        if rel_angle_oplane < -180: rel_angle_oplane += 360
        rel_angle_obase = (angle_to_obase - fplane_direction)
        if rel_angle_obase < -180: rel_angle_obase += 360

        dct = {
            'fplane_x': (fplane_pos[0] / self.width) * 2 - 1,
            'fplane_y': (fplane_pos[1] / self.height) * 2 - 1,
            'fplane_direction': (fplane_direction / 360) * 2 - 1,
            'rel_angle_oplane': rel_angle_oplane / 360,
            'rel_angle_obase': rel_angle_obase,
            'fbase_x': (fbase_pos[0] / self.width) * 2 - 1,
            'fbase_y': (fbase_pos[1] / self.height) * 2 - 1,
            'oplane_x': (oplane_pos[0] / self.width) * 2 - 1,
            'oplane_y': (oplane_pos[1] / self.width) * 2 - 1,
            'oplane_direction': (oplane_direction / 360) * 2 - 1,
            'obase_x': (obase_pos[0] / self.width) * 2 - 1,
            'obase_y': (obase_pos[1] / self.width) * 2 - 1,
            'time': self.total_time / self.max_time
        }

        for idx, bullet in self.bullets.items():
            if bullet is not None:
                bullet_pos = bullet.get_pos()
                bullet_direction = bullet.get_direction()
                dct[f'bullet_{idx}_shot'] = 1
                dct[f'bullet_{idx}_x'] = (bullet_pos[0] / self.width) * 2 - 1
                dct[f'bullet_{idx}_y'] = (bullet_pos[1] / self.height) * 2 - 1
                dct[f'bullet_{idx}_direction'] = (bullet_direction / self.height) * 2 - 1
                dct[f'bullet_{idx}_dist_to_plane'] = (dist(bullet_pos, fplane_pos)) * 2 - 1
                if math.fabs(bullet_direction - get_angle(bullet_pos, fplane_pos)) < self.step_turn:
                    dct[f'bullet_{idx}_facing_plane'] = 1
                else:
                    dct[f'bullet_{idx}_facing_plane'] = -1
            else:
                dct[f'bullet_{idx}_shot'] = -1
                dct[f'bullet_{idx}_x'] = -1
                dct[f'bullet_{idx}_y'] = -1
                dct[f'bullet_{idx}_direction'] = 0
                dct[f'bullet_{idx}_dist_to_plane'] = 0
                dct[f'bullet_{idx}_facing_plane'] = 0
        return np.array([x for x in dct.values()], dtype=np.float32)

    def reset(self): # return observation
        self.done = False
        self.winner = 'none'

        self.team['red']['base'].reset()
        self.team['blue']['base'].reset()

        for plane in self.team['red']['planes']:
            plane.reset()
        for plane in self.team['blue']['planes']:
            plane.reset()

        self.total_time = 0
        self.bullets = {n: None for n in range(self.max_bullets)}

        if self.show:
            pygame.init()
            pygame.font.init()
            self.clock = pygame.time.Clock()
            self.display = pygame.display.set_mode((DISP_WIDTH, DISP_HEIGHT))
            pygame.display.set_caption("Battlespace Simulator")
            pygame.time.wait(1000)

        return self._get_observation()

    def step(self, action): # return observation, reward, done, info
        reward = 0

        # Check if over time, if so, end game in tie
        self.total_time += self.time_step
        if self.total_time >= self.max_time:
            self.done = True
            self.ties += 1
            if self.show:
                self.render()
                print("Draw")
            return self._get_observation(), 0, self.done, {}

        # Red turn
        self.friendly = 'red'
        self.opponent = 'blue'
        reward += self._process_action(action, self.friendly, self.opponent)
        
        # Blue turn
        self.friendly = 'blue'
        self.opponent = 'red'
        self._process_action(random.randint(0, 3), self.friendly, self.opponent)        

        # Check if bullets hit and move them
        for key, bullet in self.bullets.items():
            if bullet is not None:
                outcome = bullet.update(self.width, self.height, self.time_step)
                if outcome == 'miss':
                    reward = reward + self.miss_punishment if bullet.fteam == 'red' else 0
                    self.bullets[key].kill()
                    self.bullets[key] = None
                elif outcome == 'base' or outcome == 'plane': # If a bullet hit
                    self.winner = bullet.fteam
                    self.team[self.winner]['wins'] += 1
                    if bullet.fteam == 'red':
                        reward = reward + self.hit_base_reward if outcome == 'base' else reward + self.hit_plane_reward
                    else:
                        reward += self.lose_punishment
                    self.done = True
                    if self.show:
                        self.render()
                        print(f"{self.winner} wins")
                    return self._get_observation(), reward, self.done, {}
            
        # Check if past half of max time and give punishment
        if (self.total_time > self.max_time//2):
            reward += self.too_long_punishment

        # Continue game
        if self.show:
            self.render()
        return self._get_observation(), reward, self.done, {}
    
    def _process_action(self, action, fteam, oteam): # friendly and opponent teams
        reward = 0

        fplane = self.team[fteam]['planes'][0]
        obase = self.team[oteam]['base']
        oplane = self.team[oteam]['planes'][0]

        fplane_pos = fplane.get_pos()
        fplane_angle = fplane.get_direction()
        obase_pos = obase.get_pos()
        oplane_pos = oplane.get_pos()

        dist_oplane = dist(oplane_pos, fplane_pos)
        dist_obase = dist(obase_pos, fplane_pos)

        angle_to_oplane = get_angle(fplane_pos, oplane_pos)
        angle_to_obase = get_angle(fplane_pos, obase_pos)
        rel_angle_oplane = (angle_to_oplane - fplane_angle)
        if rel_angle_oplane < -180: rel_angle_oplane += 360
        rel_angle_obase = (angle_to_obase - fplane_angle)
        if rel_angle_obase < -180: rel_angle_obase += 360

        # --------------- FORWARDS ---------------
        if action == 0: 
            fplane.forward(self.speed, self.time_step)

         # --------------- SHOOT ---------------
        elif action == 1:
            if any([v is None for v in self.bullets.values()]):
                for k, v in self.bullets.items():
                    if v is None:
                        self.bullets[k] = Bullet(fplane_pos[0], fplane_pos[1], fplane_angle, self.bullet_speed, fteam, self.team[oteam])
                        break
            fplane.forward(self.speed, self.time_step)
        
        # --------------- TURN TO ENEMY PLANE ---------------
        elif action == 2:
            if math.fabs(rel_angle_oplane) < self.step_turn:
                fplane.rotate(rel_angle_oplane)
            elif rel_angle_oplane < 0:
                fplane.rotate(-self.step_turn)
            else:
                fplane.rotate(self.step_turn)
            fplane.forward(self.speed, self.time_step)

        # ---------------- TURN TO ENEMY BASE ----------------
        elif action == 3:
            if math.fabs(rel_angle_obase) < self.step_turn:
                fplane.rotate(rel_angle_obase)
            elif rel_angle_obase < 0:
                fplane.rotate(-self.step_turn)
            else:
                fplane.rotate(self.step_turn)
            fplane.forward(self.speed, self.time_step)

        # ---------------- GIVE REWARDS IF CLOSER (DIST OR ANGLE) ----------------
        new_fplane_pos = fplane.get_pos()
        new_oplane_pos = oplane.get_pos()
        new_obase_pos = obase.get_pos()

        new_dist_oplane = dist(new_oplane_pos, new_fplane_pos)
        new_dist_obase = dist(new_obase_pos, new_fplane_pos)

        if new_dist_oplane < dist_oplane: # If got closer to enemy plane
            reward += self.closer_to_plane_reward

        if new_dist_obase < dist_obase: # If got closer to enemy base
            reward += self.closer_to_base_reward

        return reward

    def draw_shot(self, hit, friendly_pos, target_pos, team):
        color = BLACK
        color = RED if team == 'red' else BLUE
        if not hit: target_pos = (target_pos[0] + (random.random() * 2 - 1) * 100, target_pos[1] + (random.random() * 2 - 1) * 100)
        self.shot_history.append((hit, friendly_pos, target_pos, color))
    
    def winner_screen(self):
        if self.show:
            font = pygame.font.Font('freesansbold.ttf', 32)
            if self.winner != 'none':
                text = font.render(f"THE WINNER IS {self.winner.upper()}", True, BLACK)
                textRect = text.get_rect()
                textRect.center = (DISP_WIDTH//2, DISP_HEIGHT//2)
            else:
                text = font.render(f"THE GAME IS A TIE", True, BLACK)
                textRect = text.get_rect()
                textRect.center = (DISP_WIDTH//2, DISP_HEIGHT//2)
            self.display.blit(text, textRect)

    def show_wins(self):
        print("Wins by red:", self.team['red']['wins'])
        print("Wins by blue:", self.team['blue']['wins'])
        print("Tied games:", self.ties)

    def render(self, mode="human"):
        if self.show: # Just to ensure it won't render if self.show == False
            for event in pygame.event.get():
                # Check for KEYDOWN event
                if event.type == KEYDOWN:
                    # If the Esc key is pressed, then exit the main loop
                    if event.key == K_ESCAPE:
                        pygame.quit()
                        sys.exit()
                # Check for QUIT event. If QUIT, then set running to false.
                elif event.type == QUIT:
                    pygame.quit()
                    self.done = True
                    sys.exit()
                    
            # Fill background
            self.display.fill(WHITE)

            # Draw bullets
            for bullet in self.bullets.values():
                if bullet is not None:
                    bullet.draw(self.display)
                    
            # Draw bases
            self.team['red']['base'].draw(self.display)
            self.team['blue']['base'].draw(self.display)

            # Draw planes
            for plane in self.team['red']['planes']:
                plane.update()
                plane.draw(self.display)
            for plane in self.team['blue']['planes']:
                plane.update()
                plane.draw(self.display)

            # Winner Screen
            if self.done:
                font = pygame.font.Font('freesansbold.ttf', 32)
                if self.winner != 'none':
                    text = font.render(f"THE WINNER IS {self.winner.upper()}", True, BLACK)
                    textRect = text.get_rect()
                    textRect.center = (DISP_WIDTH//2, DISP_HEIGHT//2)
                else:
                    text = font.render(f"THE GAME IS A TIE", True, BLACK)
                    textRect = text.get_rect()
                    textRect.center = (DISP_WIDTH//2, DISP_HEIGHT//2)
                self.display.blit(text, textRect)
                pygame.display.update()
                pygame.time.wait(1000)
                pygame.quit()
                return
            
            pygame.display.update()
            self.clock.tick(self.fps)

# %% [markdown]
# ----------- Hyperparam Tuning ----------

# %%
import optuna
from stable_baselines3 import PPO
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.callbacks import BaseCallback
# from stable_baselines3.common import env_checker
# env_checker.check_env(BattleEnvironment())

# %%
FOLDER = 'PPO(3)'
LOG_DIR = f'{FOLDER}/logs/'
OPT_DIR = f'{FOLDER}/opt/'
if not os.path.exists(LOG_DIR):
    os.makedirs(LOG_DIR)
if not os.path.exists(OPT_DIR):
    os.makedirs(OPT_DIR)

# %%
def optimize_ppo(trial): 
    return {
        'n_steps':trial.suggest_int('n_steps', 2048, 8192),
        'gamma':trial.suggest_loguniform('gamma', 0.8, 0.9999),
        'learning_rate':trial.suggest_loguniform('learning_rate', 1e-5, 1e-4),
        'clip_range':trial.suggest_uniform('clip_range', 0.1, 0.4),
        'gae_lambda':trial.suggest_uniform('gae_lambda', 0.8, 0.99)
    }

# %%
def optimize_agent(trial):
    try:
        model_params = optimize_ppo(trial)
        env = BattleEnvironment()
        model = PPO('MlpPolicy', env, tensorboard_log=LOG_DIR, verbose=0, **model_params)
        model.learn(total_timesteps=200000)
        mean_reward, _ = evaluate_policy(model, env, n_eval_episodes=5)
        SAVE_PATH = os.path.join(OPT_DIR, 'trial_{}'.format(trial.number))
        model.save(SAVE_PATH)
        return mean_reward
    except Exception as e:
        return -1000

# %%
study = optuna.create_study(direction='maximize')
study.optimize(optimize_agent, n_trials=20)
# Out:
# [I 2022-07-02 13:25:09,844] A new study created in memory with name: no-name-6ab95736-1635-41c7-b3bc-8374bf456b55
# c:\Users\Willi\anaconda3\lib\site-packages\stable_baselines3\ppo\ppo.py:140: UserWarning: You have specified a mini-batch size of 64, but because the `RolloutBuffer` is of size `n_steps * n_envs = 7649`, after every 119 untruncated mini-batches, there will be a truncated mini-batch of size 33
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=7649 and n_envs=1)
#   warnings.warn(
# c:\Users\Willi\anaconda3\lib\site-packages\stable_baselines3\common\evaluation.py:65: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# [I 2022-07-02 13:39:30,626] Trial 0 finished with value: -6.2 and parameters: {'n_steps': 7649, 'gamma': 0.8946663787485506, 'learning_rate': 1.4266799712631003e-05, 'clip_range': 0.18642251944832786, 'gae_lambda': 0.8477375470890243}. Best is trial 0 with value: -6.2.
# c:\Users\Willi\anaconda3\lib\site-packages\stable_baselines3\ppo\ppo.py:140: UserWarning: You have specified a mini-batch size of 64, but because the `RolloutBuffer` is of size `n_steps * n_envs = 7206`, after every 112 untruncated mini-batches, there will be a truncated mini-batch of size 38
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=7206 and n_envs=1)
#   warnings.warn(
# c:\Users\Willi\anaconda3\lib\site-packages\stable_baselines3\common\evaluation.py:65: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# [I 2022-07-02 13:55:02,176] Trial 1 finished with value: -34.4 and parameters: {'n_steps': 7206, 'gamma': 0.8352397690147373, 'learning_rate': 3.235842211828897e-05, 'clip_range': 0.1011473276955016, 'gae_lambda': 0.8136795498947424}. Best is trial 0 with value: -6.2.
# c:\Users\Willi\anaconda3\lib\site-packages\stable_baselines3\ppo\ppo.py:140: UserWarning: You have specified a mini-batch size of 64, but because the `RolloutBuffer` is of size `n_steps * n_envs = 3036`, after every 47 untruncated mini-batches, there will be a truncated mini-batch of size 28
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=3036 and n_envs=1)
#   warnings.warn(
# c:\Users\Willi\anaconda3\lib\site-packages\stable_baselines3\common\evaluation.py:65: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# [I 2022-07-02 14:01:29,533] Trial 2 finished with value: 49.0 and parameters: {'n_steps': 3036, 'gamma': 0.9372753578576305, 'learning_rate': 2.3922602246853955e-05, 'clip_range': 0.19531618772324538, 'gae_lambda': 0.8344967829103379}. Best is trial 2 with value: 49.0.
# c:\Users\Willi\anaconda3\lib\site-packages\stable_baselines3\ppo\ppo.py:140: UserWarning: You have specified a mini-batch size of 64, but because the `RolloutBuffer` is of size `n_steps * n_envs = 2981`, after every 46 untruncated mini-batches, there will be a truncated mini-batch of size 37
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=2981 and n_envs=1)
#   warnings.warn(
# c:\Users\Willi\anaconda3\lib\site-packages\stable_baselines3\common\evaluation.py:65: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# [I 2022-07-02 14:07:39,309] Trial 3 finished with value: 38.8 and parameters: {'n_steps': 2981, 'gamma': 0.9673943300346082, 'learning_rate': 8.863690121633375e-05, 'clip_range': 0.15393136524674084, 'gae_lambda': 0.8720947552598463}. Best is trial 2 with value: 49.0.
# c:\Users\Willi\anaconda3\lib\site-packages\stable_baselines3\ppo\ppo.py:140: UserWarning: You have specified a mini-batch size of 64, but because the `RolloutBuffer` is of size `n_steps * n_envs = 4925`, after every 76 untruncated mini-batches, there will be a truncated mini-batch of size 61
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=4925 and n_envs=1)
#   warnings.warn(
# c:\Users\Willi\anaconda3\lib\site-packages\stable_baselines3\common\evaluation.py:65: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# [I 2022-07-02 14:13:43,166] Trial 4 finished with value: -16.0 and parameters: {'n_steps': 4925, 'gamma': 0.8139337152998256, 'learning_rate': 1.0694764168126729e-05, 'clip_range': 0.19194409048949562, 'gae_lambda': 0.883456344406655}. Best is trial 2 with value: 49.0.
# c:\Users\Willi\anaconda3\lib\site-packages\stable_baselines3\ppo\ppo.py:140: UserWarning: You have specified a mini-batch size of 64, but because the `RolloutBuffer` is of size `n_steps * n_envs = 5968`, after every 93 untruncated mini-batches, there will be a truncated mini-batch of size 16
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=5968 and n_envs=1)
#   warnings.warn(
# c:\Users\Willi\anaconda3\lib\site-packages\stable_baselines3\common\evaluation.py:65: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# [I 2022-07-02 14:20:10,444] Trial 5 finished with value: -37.6 and parameters: {'n_steps': 5968, 'gamma': 0.8508455177032938, 'learning_rate': 2.02337741881742e-05, 'clip_range': 0.10304949747845187, 'gae_lambda': 0.8758647222819608}. Best is trial 2 with value: 49.0.
# c:\Users\Willi\anaconda3\lib\site-packages\stable_baselines3\ppo\ppo.py:140: UserWarning: You have specified a mini-batch size of 64, but because the `RolloutBuffer` is of size `n_steps * n_envs = 4991`, after every 77 untruncated mini-batches, there will be a truncated mini-batch of size 63
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=4991 and n_envs=1)
#   warnings.warn(
# c:\Users\Willi\anaconda3\lib\site-packages\stable_baselines3\common\evaluation.py:65: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# [I 2022-07-02 14:26:27,541] Trial 6 finished with value: 29.2 and parameters: {'n_steps': 4991, 'gamma': 0.9420642349448138, 'learning_rate': 4.871945148280228e-05, 'clip_range': 0.16977439973301556, 'gae_lambda': 0.8106576223971556}. Best is trial 2 with value: 49.0.
# c:\Users\Willi\anaconda3\lib\site-packages\stable_baselines3\ppo\ppo.py:140: UserWarning: You have specified a mini-batch size of 64, but because the `RolloutBuffer` is of size `n_steps * n_envs = 5610`, after every 87 untruncated mini-batches, there will be a truncated mini-batch of size 42
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=5610 and n_envs=1)
#   warnings.warn(
# c:\Users\Willi\anaconda3\lib\site-packages\stable_baselines3\common\evaluation.py:65: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# [I 2022-07-02 14:32:33,854] Trial 7 finished with value: 2.2 and parameters: {'n_steps': 5610, 'gamma': 0.8113260769486537, 'learning_rate': 2.0589671537362267e-05, 'clip_range': 0.39042246216972487, 'gae_lambda': 0.8964428700369397}. Best is trial 2 with value: 49.0.
# c:\Users\Willi\anaconda3\lib\site-packages\stable_baselines3\ppo\ppo.py:140: UserWarning: You have specified a mini-batch size of 64, but because the `RolloutBuffer` is of size `n_steps * n_envs = 5754`, after every 89 untruncated mini-batches, there will be a truncated mini-batch of size 58
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=5754 and n_envs=1)
#   warnings.warn(
# c:\Users\Willi\anaconda3\lib\site-packages\stable_baselines3\common\evaluation.py:65: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# [I 2022-07-02 14:38:45,833] Trial 8 finished with value: 7.4 and parameters: {'n_steps': 5754, 'gamma': 0.9927009639323578, 'learning_rate': 5.257659030245961e-05, 'clip_range': 0.17980920779828732, 'gae_lambda': 0.8763626708518174}. Best is trial 2 with value: 49.0.
# c:\Users\Willi\anaconda3\lib\site-packages\stable_baselines3\ppo\ppo.py:140: UserWarning: You have specified a mini-batch size of 64, but because the `RolloutBuffer` is of size `n_steps * n_envs = 6617`, after every 103 untruncated mini-batches, there will be a truncated mini-batch of size 25
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=6617 and n_envs=1)
#   warnings.warn(
# c:\Users\Willi\anaconda3\lib\site-packages\stable_baselines3\common\evaluation.py:65: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# [I 2022-07-02 14:45:05,083] Trial 9 finished with value: 22.6 and parameters: {'n_steps': 6617, 'gamma': 0.8954762108990824, 'learning_rate': 8.368972126940346e-05, 'clip_range': 0.3280474206901879, 'gae_lambda': 0.9682240094276813}. Best is trial 2 with value: 49.0.
# c:\Users\Willi\anaconda3\lib\site-packages\stable_baselines3\ppo\ppo.py:140: UserWarning: You have specified a mini-batch size of 64, but because the `RolloutBuffer` is of size `n_steps * n_envs = 2397`, after every 37 untruncated mini-batches, there will be a truncated mini-batch of size 29
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=2397 and n_envs=1)
#   warnings.warn(
# c:\Users\Willi\anaconda3\lib\site-packages\stable_baselines3\common\evaluation.py:65: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# [I 2022-07-02 14:51:20,729] Trial 10 finished with value: 4.0 and parameters: {'n_steps': 2397, 'gamma': 0.9290299484097679, 'learning_rate': 2.8106323413251185e-05, 'clip_range': 0.2701443493794814, 'gae_lambda': 0.9335337268026035}. Best is trial 2 with value: 49.0.
# c:\Users\Willi\anaconda3\lib\site-packages\stable_baselines3\ppo\ppo.py:140: UserWarning: You have specified a mini-batch size of 64, but because the `RolloutBuffer` is of size `n_steps * n_envs = 2780`, after every 43 untruncated mini-batches, there will be a truncated mini-batch of size 28
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=2780 and n_envs=1)
#   warnings.warn(
# c:\Users\Willi\anaconda3\lib\site-packages\stable_baselines3\common\evaluation.py:65: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# [I 2022-07-02 14:57:38,289] Trial 11 finished with value: -21.2 and parameters: {'n_steps': 2780, 'gamma': 0.9934142549664537, 'learning_rate': 9.17508454727442e-05, 'clip_range': 0.2516345220808467, 'gae_lambda': 0.8401224406366188}. Best is trial 2 with value: 49.0.
# c:\Users\Willi\anaconda3\lib\site-packages\stable_baselines3\ppo\ppo.py:140: UserWarning: You have specified a mini-batch size of 64, but because the `RolloutBuffer` is of size `n_steps * n_envs = 3593`, after every 56 untruncated mini-batches, there will be a truncated mini-batch of size 9
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=3593 and n_envs=1)
#   warnings.warn(
# c:\Users\Willi\anaconda3\lib\site-packages\stable_baselines3\common\evaluation.py:65: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# [I 2022-07-02 15:03:47,340] Trial 12 finished with value: 47.2 and parameters: {'n_steps': 3593, 'gamma': 0.947842550855732, 'learning_rate': 4.851497563251581e-05, 'clip_range': 0.14759926611574992, 'gae_lambda': 0.8434056121629329}. Best is trial 2 with value: 49.0.
# c:\Users\Willi\anaconda3\lib\site-packages\stable_baselines3\ppo\ppo.py:140: UserWarning: You have specified a mini-batch size of 64, but because the `RolloutBuffer` is of size `n_steps * n_envs = 3975`, after every 62 untruncated mini-batches, there will be a truncated mini-batch of size 7
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=3975 and n_envs=1)
#   warnings.warn(
# c:\Users\Willi\anaconda3\lib\site-packages\stable_baselines3\common\evaluation.py:65: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# [I 2022-07-02 15:10:00,458] Trial 13 finished with value: -46.6 and parameters: {'n_steps': 3975, 'gamma': 0.9216577515035939, 'learning_rate': 4.367644242859803e-05, 'clip_range': 0.2258251420821633, 'gae_lambda': 0.8357250991706888}. Best is trial 2 with value: 49.0.
# c:\Users\Willi\anaconda3\lib\site-packages\stable_baselines3\ppo\ppo.py:140: UserWarning: You have specified a mini-batch size of 64, but because the `RolloutBuffer` is of size `n_steps * n_envs = 3741`, after every 58 untruncated mini-batches, there will be a truncated mini-batch of size 29
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=3741 and n_envs=1)
#   warnings.warn(
# c:\Users\Willi\anaconda3\lib\site-packages\stable_baselines3\common\evaluation.py:65: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# [I 2022-07-02 15:16:46,129] Trial 14 finished with value: 26.8 and parameters: {'n_steps': 3741, 'gamma': 0.9537949340248436, 'learning_rate': 3.0967385318321964e-05, 'clip_range': 0.13534936796921765, 'gae_lambda': 0.801971436398308}. Best is trial 2 with value: 49.0.
# c:\Users\Willi\anaconda3\lib\site-packages\stable_baselines3\ppo\ppo.py:140: UserWarning: You have specified a mini-batch size of 64, but because the `RolloutBuffer` is of size `n_steps * n_envs = 3765`, after every 58 untruncated mini-batches, there will be a truncated mini-batch of size 53
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=3765 and n_envs=1)
#   warnings.warn(
# c:\Users\Willi\anaconda3\lib\site-packages\stable_baselines3\common\evaluation.py:65: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# [I 2022-07-02 15:23:45,680] Trial 15 finished with value: 52.0 and parameters: {'n_steps': 3765, 'gamma': 0.8700984298291107, 'learning_rate': 6.294699052129512e-05, 'clip_range': 0.2136607542362127, 'gae_lambda': 0.9216032309214884}. Best is trial 15 with value: 52.0.
# c:\Users\Willi\anaconda3\lib\site-packages\stable_baselines3\ppo\ppo.py:140: UserWarning: You have specified a mini-batch size of 64, but because the `RolloutBuffer` is of size `n_steps * n_envs = 2076`, after every 32 untruncated mini-batches, there will be a truncated mini-batch of size 28
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=2076 and n_envs=1)
#   warnings.warn(
# c:\Users\Willi\anaconda3\lib\site-packages\stable_baselines3\common\evaluation.py:65: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# [I 2022-07-02 15:30:26,898] Trial 16 finished with value: 64.6 and parameters: {'n_steps': 2076, 'gamma': 0.866331689775563, 'learning_rate': 6.604645883688687e-05, 'clip_range': 0.286690354522357, 'gae_lambda': 0.9183168288996518}. Best is trial 16 with value: 64.6.
# c:\Users\Willi\anaconda3\lib\site-packages\stable_baselines3\ppo\ppo.py:140: UserWarning: You have specified a mini-batch size of 64, but because the `RolloutBuffer` is of size `n_steps * n_envs = 2080`, after every 32 untruncated mini-batches, there will be a truncated mini-batch of size 32
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=2080 and n_envs=1)
#   warnings.warn(
# c:\Users\Willi\anaconda3\lib\site-packages\stable_baselines3\common\evaluation.py:65: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# [I 2022-07-02 15:37:09,089] Trial 17 finished with value: 38.8 and parameters: {'n_steps': 2080, 'gamma': 0.8571648702218164, 'learning_rate': 6.461184885086594e-05, 'clip_range': 0.3055555307552461, 'gae_lambda': 0.9252204225096619}. Best is trial 16 with value: 64.6.
# c:\Users\Willi\anaconda3\lib\site-packages\stable_baselines3\ppo\ppo.py:140: UserWarning: You have specified a mini-batch size of 64, but because the `RolloutBuffer` is of size `n_steps * n_envs = 4281`, after every 66 untruncated mini-batches, there will be a truncated mini-batch of size 57
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=4281 and n_envs=1)
#   warnings.warn(
# c:\Users\Willi\anaconda3\lib\site-packages\stable_baselines3\common\evaluation.py:65: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# [I 2022-07-02 15:44:06,482] Trial 18 finished with value: -15.2 and parameters: {'n_steps': 4281, 'gamma': 0.871546158621787, 'learning_rate': 6.58764641087044e-05, 'clip_range': 0.29469969859147965, 'gae_lambda': 0.9286065020433562}. Best is trial 16 with value: 64.6.
# c:\Users\Willi\anaconda3\lib\site-packages\stable_baselines3\ppo\ppo.py:140: UserWarning: You have specified a mini-batch size of 64, but because the `RolloutBuffer` is of size `n_steps * n_envs = 4552`, after every 71 untruncated mini-batches, there will be a truncated mini-batch of size 8
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=4552 and n_envs=1)
#   warnings.warn(
# c:\Users\Willi\anaconda3\lib\site-packages\stable_baselines3\common\evaluation.py:65: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# [I 2022-07-02 15:50:37,184] Trial 19 finished with value: -1.4 and parameters: {'n_steps': 4552, 'gamma': 0.8705576663900102, 'learning_rate': 3.8336912812113785e-05, 'clip_range': 0.226160375328528, 'gae_lambda': 0.9821104808280818}. Best is trial 16 with value: 64.6.

# %%
model_params = study.best_params
model_params['n_steps'] = (model_params['n_steps'] // 64) * 64 # set to a factor of 64
study.best_trial
# Out:
# FrozenTrial(number=16, values=[64.6], datetime_start=datetime.datetime(2022, 7, 2, 15, 23, 45, 688205), datetime_complete=datetime.datetime(2022, 7, 2, 15, 30, 26, 898660), params={'n_steps': 2076, 'gamma': 0.866331689775563, 'learning_rate': 6.604645883688687e-05, 'clip_range': 0.286690354522357, 'gae_lambda': 0.9183168288996518}, distributions={'n_steps': IntUniformDistribution(high=8192, low=2048, step=1), 'gamma': LogUniformDistribution(high=0.9999, low=0.8), 'learning_rate': LogUniformDistribution(high=0.0001, low=1e-05), 'clip_range': UniformDistribution(high=0.4, low=0.1), 'gae_lambda': UniformDistribution(high=0.99, low=0.8)}, user_attrs={}, system_attrs={}, intermediate_values={}, trial_id=16, state=TrialState.COMPLETE, value=None)

# %% [markdown]
# ---------- Training the Best Model ----------

# %%
class TrainAndLoggingCallback(BaseCallback):
    def __init__(self, check_freq, save_path, verbose=1):
        super(TrainAndLoggingCallback, self).__init__(verbose)
        self.check_freq = check_freq
        self.save_path = save_path

    def _init_callback(self):
        if self.save_path is not None:
            os.makedirs(self.save_path, exist_ok=True)

    def _on_step(self):
        if self.n_calls % self.check_freq == 0:
            model_path = os.path.join(self.save_path, 'best_model_{}'.format(self.n_calls))
            self.model.save(model_path)
        return True

CHECKPOINT_DIR = f'{FOLDER}/train/'
save_freq = 50000
timesteps = 1000000
saved_timesteps = timesteps // save_freq * save_freq

# %%
callback = TrainAndLoggingCallback(check_freq=save_freq, save_path=CHECKPOINT_DIR)
env = BattleEnvironment()
model = PPO('MlpPolicy', env, tensorboard_log=LOG_DIR, verbose=1, **model_params)
model.load(os.path.join(OPT_DIR, f'trial_16.zip'))
model.learn(total_timesteps=timesteps, callback=callback)
del model
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to PPO(3)/logs/PPO_21
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 26.2     |
# |    ep_rew_mean     | 20.1     |
# | time/              |          |
# |    fps             | 329      |
# |    iterations      | 1        |
# |    time_elapsed    | 6        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 23.6         |
# |    ep_rew_mean          | 15.9         |
# | time/                   |              |
# |    fps                  | 310          |
# |    iterations           | 2            |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0009034141 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.287        |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | -0.00379     |
# |    learning_rate        | 6.6e-05      |
# |    loss                 | 159          |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00173     |
# |    value_loss           | 443          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 24.7         |
# |    ep_rew_mean          | 12.2         |
# | time/                   |              |
# |    fps                  | 327          |
# |    iterations           | 3            |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0003635913 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.287        |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | 0.00448      |
# |    learning_rate        | 6.6e-05      |
# |    loss                 | 311          |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00173     |
# |    value_loss           | 436          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 22.1         |
# |    ep_rew_mean          | 31.5         |
# | time/                   |              |
# |    fps                  | 317          |
# |    iterations           | 4            |
# |    time_elapsed         | 25           |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0026983358 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.287        |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0.00487      |
# |    learning_rate        | 6.6e-05      |
# |    loss                 | 351          |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00335     |
# |    value_loss           | 450          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 24.4          |
# |    ep_rew_mean          | 13.3          |
# | time/                   |               |
# |    fps                  | 325           |
# |    iterations           | 5             |
# |    time_elapsed         | 31            |
# |    total_timesteps      | 10240         |
# | train/                  |               |
# |    approx_kl            | 0.00048540384 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.287         |
# |    entropy_loss         | -1.38         |
# |    explained_variance   | 0.0129        |
# |    learning_rate        | 6.6e-05       |
# |    loss                 | 443           |
# |    n_updates            | 40            |
# |    policy_gradient_loss | -0.00208      |
# |    value_loss           | 617           |
# -------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 21.1       |
# |    ep_rew_mean          | 36.7       |
# | time/                   |            |
# |    fps                  | 319        |
# |    iterations           | 6          |
# |    time_elapsed         | 38         |
# |    total_timesteps      | 12288      |
# | train/                  |            |
# |    approx_kl            | 0.00052728 |
# |    clip_fraction        | 0          |
# |    clip_range           | 0.287      |
# |    entropy_loss         | -1.38      |
# |    explained_variance   | 0.00473    |
# |    learning_rate        | 6.6e-05    |
# |    loss                 | 90.1       |
# |    n_updates            | 50         |
# |    policy_gradient_loss | -0.00206   |
# |    value_loss           | 456        |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 19.3         |
# |    ep_rew_mean          | 29.5         |
# | time/                   |              |
# |    fps                  | 323          |
# |    iterations           | 7            |
# |    time_elapsed         | 44           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0025117528 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.287        |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0.0162       |
# |    learning_rate        | 6.6e-05      |
# |    loss                 | 315          |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.0035      |
# |    value_loss           | 659          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 24.5        |
# |    ep_rew_mean          | 27.8        |
# | time/                   |             |
# |    fps                  | 329         |
# |    iterations           | 8           |
# |    time_elapsed         | 49          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.000489883 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.287       |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.0111      |
# |    learning_rate        | 6.6e-05     |
# |    loss                 | 314         |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00209    |
# |    value_loss           | 618         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 22.3         |
# |    ep_rew_mean          | 18.5         |
# | time/                   |              |
# |    fps                  | 323          |
# |    iterations           | 9            |
# |    time_elapsed         | 57           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0032546222 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.287        |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | 0.0117       |
# |    learning_rate        | 6.6e-05      |
# |    loss                 | 208          |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00372     |
# |    value_loss           | 540          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 20.6         |
# |    ep_rew_mean          | 19.4         |
# | time/                   |              |
# |    fps                  | 327          |
# |    iterations           | 10           |
# |    time_elapsed         | 62           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0018805898 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.287        |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | 0.0236       |
# |    learning_rate        | 6.6e-05      |
# |    loss                 | 407          |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00387     |
# |    value_loss           | 462          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 19.6         |
# |    ep_rew_mean          | 45.5         |
# | time/                   |              |
# |    fps                  | 327          |
# |    iterations           | 11           |
# |    time_elapsed         | 68           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0011672603 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.287        |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | 0.00548      |
# |    learning_rate        | 6.6e-05      |
# |    loss                 | 307          |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00307     |
# |    value_loss           | 533          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 20.5        |
# |    ep_rew_mean          | 30.2        |
# | time/                   |             |
# |    fps                  | 327         |
# |    iterations           | 12          |
# |    time_elapsed         | 75          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.001937076 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.287       |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 0.0346      |
# |    learning_rate        | 6.6e-05     |
# |    loss                 | 370         |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00419    |
# |    value_loss           | 736         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 18.4         |
# |    ep_rew_mean          | 26.7         |
# | time/                   |              |
# |    fps                  | 330          |
# |    iterations           | 13           |
# |    time_elapsed         | 80           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0007650588 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.287        |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | 0.0275       |
# |    learning_rate        | 6.6e-05      |
# |    loss                 | 435          |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00319     |
# |    value_loss           | 585          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 18            |
# |    ep_rew_mean          | 40.1          |
# | time/                   |               |
# |    fps                  | 325           |
# |    iterations           | 14            |
# |    time_elapsed         | 88            |
# |    total_timesteps      | 28672         |
# | train/                  |               |
# |    approx_kl            | 0.00035065506 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.287         |
# |    entropy_loss         | -1.31         |
# |    explained_variance   | 0.0191        |
# |    learning_rate        | 6.6e-05       |
# |    loss                 | 333           |
# |    n_updates            | 130           |
# |    policy_gradient_loss | -0.00246      |
# |    value_loss           | 667           |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 18.9         |
# |    ep_rew_mean          | 24.1         |
# | time/                   |              |
# |    fps                  | 327          |
# |    iterations           | 15           |
# |    time_elapsed         | 93           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0009555114 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.287        |
# |    entropy_loss         | -1.3         |
# |    explained_variance   | 0.0185       |
# |    learning_rate        | 6.6e-05      |
# |    loss                 | 575          |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.0029      |
# |    value_loss           | 747          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 20          |
# |    ep_rew_mean          | 33          |
# | time/                   |             |
# |    fps                  | 327         |
# |    iterations           | 16          |
# |    time_elapsed         | 99          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.001184656 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.287       |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | 0.0332      |
# |    learning_rate        | 6.6e-05     |
# |    loss                 | 199         |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00326    |
# |    value_loss           | 580         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 18.5         |
# |    ep_rew_mean          | 36.7         |
# | time/                   |              |
# |    fps                  | 328          |
# |    iterations           | 17           |
# |    time_elapsed         | 106          |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0011899576 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.287        |
# |    entropy_loss         | -1.3         |
# |    explained_variance   | 0.00998      |
# |    learning_rate        | 6.6e-05      |
# |    loss                 | 367          |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00315     |
# |    value_loss           | 629          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 15.7        |
# |    ep_rew_mean          | 34.3        |
# | time/                   |             |
# |    fps                  | 329         |
# |    iterations           | 18          |
# |    time_elapsed         | 111         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.001912572 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.287       |
# |    entropy_loss         | -1.28       |
# |    explained_variance   | 0.0415      |
# |    learning_rate        | 6.6e-05     |
# |    loss                 | 531         |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00335    |
# |    value_loss           | 682         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 18.4         |
# |    ep_rew_mean          | 40.7         |
# | time/                   |              |
# |    fps                  | 326          |
# |    iterations           | 19           |
# |    time_elapsed         | 119          |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0016374316 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.287        |
# |    entropy_loss         | -1.25        |
# |    explained_variance   | 0.0329       |
# |    learning_rate        | 6.6e-05      |
# |    loss                 | 300          |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00437     |
# |    value_loss           | 730          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 18.2         |
# |    ep_rew_mean          | 41.6         |
# | time/                   |              |
# |    fps                  | 326          |
# |    iterations           | 20           |
# |    time_elapsed         | 125          |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0015743156 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.287        |
# |    entropy_loss         | -1.24        |
# |    explained_variance   | 0.044        |
# |    learning_rate        | 6.6e-05      |
# |    loss                 | 278          |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00387     |
# |    value_loss           | 740          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 16.1         |
# |    ep_rew_mean          | 46.5         |
# | time/                   |              |
# |    fps                  | 327          |
# |    iterations           | 21           |
# |    time_elapsed         | 131          |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0028760307 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.287        |
# |    entropy_loss         | -1.21        |
# |    explained_variance   | 0.0486       |
# |    learning_rate        | 6.6e-05      |
# |    loss                 | 475          |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00411     |
# |    value_loss           | 718          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 16.4         |
# |    ep_rew_mean          | 27.6         |
# | time/                   |              |
# |    fps                  | 326          |
# |    iterations           | 22           |
# |    time_elapsed         | 138          |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0046089822 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.287        |
# |    entropy_loss         | -1.2         |
# |    explained_variance   | 0.055        |
# |    learning_rate        | 6.6e-05      |
# |    loss                 | 243          |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00494     |
# |    value_loss           | 760          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 15.8         |
# |    ep_rew_mean          | 40.8         |
# | time/                   |              |
# |    fps                  | 327          |
# |    iterations           | 23           |
# |    time_elapsed         | 143          |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0016737123 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.287        |
# |    entropy_loss         | -1.2         |
# |    explained_variance   | 0.0411       |
# |    learning_rate        | 6.6e-05      |
# |    loss                 | 376          |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00371     |
# |    value_loss           | 705          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 15.3          |
# |    ep_rew_mean          | 48.7          |
# | time/                   |               |
# |    fps                  | 323           |
# |    iterations           | 24            |
# |    time_elapsed         | 151           |
# |    total_timesteps      | 49152         |
# | train/                  |               |
# |    approx_kl            | 0.00063085963 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.287         |
# |    entropy_loss         | -1.19         |
# |    explained_variance   | 0.0482        |
# |    learning_rate        | 6.6e-05       |
# |    loss                 | 508           |
# |    n_updates            | 230           |
# |    policy_gradient_loss | -0.0031       |
# |    value_loss           | 805           |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 17.4         |
# |    ep_rew_mean          | 42.1         |
# | time/                   |              |
# |    fps                  | 321          |
# |    iterations           | 25           |
# |    time_elapsed         | 159          |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0024387278 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.287        |
# |    entropy_loss         | -1.17        |
# |    explained_variance   | 0.0543       |
# |    learning_rate        | 6.6e-05      |
# |    loss                 | 314          |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00476     |
# |    value_loss           | 828          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 17.2         |
# |    ep_rew_mean          | 42           |
# | time/                   |              |
# |    fps                  | 317          |
# |    iterations           | 26           |
# |    time_elapsed         | 167          |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0006483311 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.287        |
# |    entropy_loss         | -1.16        |
# |    explained_variance   | 0.0611       |
# |    learning_rate        | 6.6e-05      |
# |    loss                 | 481          |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.00289     |
# |    value_loss           | 730          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 17.4         |
# |    ep_rew_mean          | 54.3         |
# | time/                   |              |
# |    fps                  | 318          |
# |    iterations           | 27           |
# |    time_elapsed         | 173          |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0023077542 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.287        |
# |    entropy_loss         | -1.14        |
# |    explained_variance   | 0.0374       |
# |    learning_rate        | 6.6e-05      |
# |    loss                 | 467          |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.00333     |
# |    value_loss           | 751          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 17           |
# |    ep_rew_mean          | 43.1         |
# | time/                   |              |
# |    fps                  | 318          |
# |    iterations           | 28           |
# |    time_elapsed         | 180          |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0012907269 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.287        |
# |    entropy_loss         | -1.13        |
# |    explained_variance   | 0.0675       |
# |    learning_rate        | 6.6e-05      |
# |    loss                 | 482          |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.0038      |
# |    value_loss           | 775          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 17.6        |
# |    ep_rew_mean          | 37.2        |
# | time/                   |             |
# |    fps                  | 318         |
# |    iterations           | 29          |
# |    time_elapsed         | 186         |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.003366868 |
# |    clip_fraction        | 0.000293    |
# |    clip_range           | 0.287       |
# |    entropy_loss         | -1.1        |
# |    explained_variance   | 0.0703      |
# |    learning_rate        | 6.6e-05     |
# |    loss                 | 442         |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.00452    |
# |    value_loss           | 737         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 15.8         |
# |    ep_rew_mean          | 42.8         |
# | time/                   |              |
# |    fps                  | 319          |
# |    iterations           | 30           |
# |    time_elapsed         | 192          |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0059159743 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.287        |
# |    entropy_loss         | -1.11        |
# |    explained_variance   | 0.0561       |
# |    learning_rate        | 6.6e-05      |
# |    loss                 | 327          |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.00552     |
# |    value_loss           | 711          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 15.2         |
# |    ep_rew_mean          | 48.1         |
# | time/                   |              |
# |    fps                  | 317          |
# |    iterations           | 31           |
# |    time_elapsed         | 200          |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0030306673 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.287        |
# |    entropy_loss         | -1.11        |
# |    explained_variance   | 0.0775       |
# |    learning_rate        | 6.6e-05      |
# |    loss                 | 278          |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.00475     |
# |    value_loss           | 748          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 15.8        |
# |    ep_rew_mean          | 47.1        |
# | time/                   |             |
# |    fps                  | 318         |
# |    iterations           | 32          |
# |    time_elapsed         | 205         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.000774604 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.287       |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.0939      |
# |    learning_rate        | 6.6e-05     |
# |    loss                 | 284         |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.0027     |
# |    value_loss           | 832         |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 16.5          |
# |    ep_rew_mean          | 40.1          |
# | time/                   |               |
# |    fps                  | 317           |
# |    iterations           | 33            |
# |    time_elapsed         | 212           |
# |    total_timesteps      | 67584         |
# | train/                  |               |
# |    approx_kl            | 0.00047305677 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.287         |
# |    entropy_loss         | -1.07         |
# |    explained_variance   | 0.0923        |
# |    learning_rate        | 6.6e-05       |
# |    loss                 | 330           |
# |    n_updates            | 320           |
# |    policy_gradient_loss | -0.00259      |
# |    value_loss           | 768           |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 18.6          |
# |    ep_rew_mean          | 50.4          |
# | time/                   |               |
# |    fps                  | 317           |
# |    iterations           | 34            |
# |    time_elapsed         | 219           |
# |    total_timesteps      | 69632         |
# | train/                  |               |
# |    approx_kl            | 0.00028231431 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.287         |
# |    entropy_loss         | -1.07         |
# |    explained_variance   | 0.0815        |
# |    learning_rate        | 6.6e-05       |
# |    loss                 | 253           |
# |    n_updates            | 330           |
# |    policy_gradient_loss | -0.0028       |
# |    value_loss           | 741           |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 18.2         |
# |    ep_rew_mean          | 45.5         |
# | time/                   |              |
# |    fps                  | 318          |
# |    iterations           | 35           |
# |    time_elapsed         | 225          |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0005635985 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.287        |
# |    entropy_loss         | -1.07        |
# |    explained_variance   | 0.116        |
# |    learning_rate        | 6.6e-05      |
# |    loss                 | 426          |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.0032      |
# |    value_loss           | 722          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 15.2         |
# |    ep_rew_mean          | 41.4         |
# | time/                   |              |
# |    fps                  | 316          |
# |    iterations           | 36           |
# |    time_elapsed         | 232          |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0009019448 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.287        |
# |    entropy_loss         | -1.06        |
# |    explained_variance   | 0.105        |
# |    learning_rate        | 6.6e-05      |
# |    loss                 | 379          |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.00392     |
# |    value_loss           | 688          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 18.5         |
# |    ep_rew_mean          | 47.2         |
# | time/                   |              |
# |    fps                  | 317          |
# |    iterations           | 37           |
# |    time_elapsed         | 238          |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 0.0005110608 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.287        |
# |    entropy_loss         | -1.05        |
# |    explained_variance   | 0.121        |
# |    learning_rate        | 6.6e-05      |
# |    loss                 | 476          |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.00332     |
# |    value_loss           | 739          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 14.6         |
# |    ep_rew_mean          | 52.4         |
# | time/                   |              |
# |    fps                  | 316          |
# |    iterations           | 38           |
# |    time_elapsed         | 245          |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0004617517 |
# |    clip_fraction        | 0.000244     |
# |    clip_range           | 0.287        |
# |    entropy_loss         | -1.05        |
# |    explained_variance   | 0.105        |
# |    learning_rate        | 6.6e-05      |
# |    loss                 | 351          |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.00308     |
# |    value_loss           | 721          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 17.3          |
# |    ep_rew_mean          | 35.1          |
# | time/                   |               |
# |    fps                  | 316           |
# |    iterations           | 39            |
# |    time_elapsed         | 251           |
# |    total_timesteps      | 79872         |
# | train/                  |               |
# |    approx_kl            | 0.00022213536 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.287         |
# |    entropy_loss         | -1.04         |
# |    explained_variance   | 0.127         |
# |    learning_rate        | 6.6e-05       |
# |    loss                 | 330           |
# |    n_updates            | 380           |
# |    policy_gradient_loss | -0.0023       |
# |    value_loss           | 802           |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 17.7        |
# |    ep_rew_mean          | 36.2        |
# | time/                   |             |
# |    fps                  | 317         |
# |    iterations           | 40          |
# |    time_elapsed         | 257         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.003551553 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.287       |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | 0.0716      |
# |    learning_rate        | 6.6e-05     |
# |    loss                 | 309         |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.0047     |
# |    value_loss           | 715         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 16.7        |
# |    ep_rew_mean          | 55.9        |
# | time/                   |             |
# |    fps                  | 316         |
# |    iterations           | 41          |
# |    time_elapsed         | 265         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.012641006 |
# |    clip_fraction        | 0.00269     |
# |    clip_range           | 0.287       |
# |    entropy_loss         | -1.03       |
# |    explained_variance   | 0.112       |
# |    learning_rate        | 6.6e-05     |
# |    loss                 | 234         |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.00851    |
# |    value_loss           | 714         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 16.4         |
# |    ep_rew_mean          | 46.1         |
# | time/                   |              |
# |    fps                  | 317          |
# |    iterations           | 42           |
# |    time_elapsed         | 270          |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0019915218 |
# |    clip_fraction        | 0.000293     |
# |    clip_range           | 0.287        |
# |    entropy_loss         | -1.02        |
# |    explained_variance   | 0.179        |
# |    learning_rate        | 6.6e-05      |
# |    loss                 | 274          |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.00322     |
# |    value_loss           | 698          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 16           |
# |    ep_rew_mean          | 49.8         |
# | time/                   |              |
# |    fps                  | 317          |
# |    iterations           | 43           |
# |    time_elapsed         | 277          |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0014497463 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.287        |
# |    entropy_loss         | -1.01        |
# |    explained_variance   | 0.123        |
# |    learning_rate        | 6.6e-05      |
# |    loss                 | 376          |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.00288     |
# |    value_loss           | 757          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 17.4          |
# |    ep_rew_mean          | 34.7          |
# | time/                   |               |
# |    fps                  | 317           |
# |    iterations           | 44            |
# |    time_elapsed         | 283           |
# |    total_timesteps      | 90112         |
# | train/                  |               |
# |    approx_kl            | 0.00024641183 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.287         |
# |    entropy_loss         | -1.03         |
# |    explained_variance   | 0.155         |
# |    learning_rate        | 6.6e-05       |
# |    loss                 | 378           |
# |    n_updates            | 430           |
# |    policy_gradient_loss | -0.00267      |
# |    value_loss           | 724           |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 14.8          |
# |    ep_rew_mean          | 40.8          |
# | time/                   |               |
# |    fps                  | 318           |
# |    iterations           | 45            |
# |    time_elapsed         | 289           |
# |    total_timesteps      | 92160         |
# | train/                  |               |
# |    approx_kl            | 0.00054287055 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.287         |
# |    entropy_loss         | -1.02         |
# |    explained_variance   | 0.0874        |
# |    learning_rate        | 6.6e-05       |
# |    loss                 | 229           |
# |    n_updates            | 440           |
# |    policy_gradient_loss | -0.00286      |
# |    value_loss           | 675           |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 15.6         |
# |    ep_rew_mean          | 41           |
# | time/                   |              |
# |    fps                  | 317          |
# |    iterations           | 46           |
# |    time_elapsed         | 297          |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0004451218 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.287        |
# |    entropy_loss         | -0.999       |
# |    explained_variance   | 0.0985       |
# |    learning_rate        | 6.6e-05      |
# |    loss                 | 416          |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.0031      |
# |    value_loss           | 764          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 16.3         |
# |    ep_rew_mean          | 46.4         |
# | time/                   |              |
# |    fps                  | 317          |
# |    iterations           | 47           |
# |    time_elapsed         | 302          |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0021893275 |
# |    clip_fraction        | 0.000195     |
# |    clip_range           | 0.287        |
# |    entropy_loss         | -1.01        |
# |    explained_variance   | 0.124        |
# |    learning_rate        | 6.6e-05      |
# |    loss                 | 318          |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.00434     |
# |    value_loss           | 712          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 16.2        |
# |    ep_rew_mean          | 53.9        |
# | time/                   |             |
# |    fps                  | 318         |
# |    iterations           | 48          |
# |    time_elapsed         | 308         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.001176139 |
# |    clip_fraction        | 0.000195    |
# |    clip_range           | 0.287       |
# |    entropy_loss         | -0.998      |
# |    explained_variance   | 0.108       |
# |    learning_rate        | 6.6e-05     |
# |    loss                 | 268         |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.00276    |
# |    value_loss           | 745         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 15.5         |
# |    ep_rew_mean          | 49.7         |
# | time/                   |              |
# |    fps                  | 316          |
# |    iterations           | 49           |
# |    time_elapsed         | 317          |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0013095404 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.287        |
# |    entropy_loss         | -1           |
# |    explained_variance   | 0.129        |
# |    learning_rate        | 6.6e-05      |
# |    loss                 | 328          |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.00306     |
# |    value_loss           | 740          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 14.8         |
# |    ep_rew_mean          | 46           |
# | time/                   |              |
# |    fps                  | 313          |
# |    iterations           | 50           |
# |    time_elapsed         | 326          |
# |    total_timesteps      | 102400       |
# | train/                  |              |
# |    approx_kl            | 0.0019195437 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.287        |
# |    entropy_loss         | -1           |
# |    explained_variance   | 0.155        |
# |    learning_rate        | 6.6e-05      |
# |    loss                 | 299          |
# |    n_updates            | 490          |
# |    policy_gradient_loss | -0.00334     |
# |    value_loss           | 715          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 15.8        |
# |    ep_rew_mean          | 48.8        |
# | time/                   |             |
# |    fps                  | 312         |
# |    iterations           | 51          |
# |    time_elapsed         | 334         |
# |    total_timesteps      | 104448      |
# | train/                  |             |
# |    approx_kl            | 0.003410372 |
# |    clip_fraction        | 0.000244    |
# |    clip_range           | 0.287       |
# |    entropy_loss         | -0.996      |
# |    explained_variance   | 0.181       |
# |    learning_rate        | 6.6e-05     |
# |    loss                 | 348         |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.00444    |
# |    value_loss           | 715         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 15.8        |
# |    ep_rew_mean          | 36.6        |
# | time/                   |             |
# |    fps                  | 195         |
# |    iterations           | 52          |
# |    time_elapsed         | 543         |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.002033467 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.287       |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | 0.0888      |
# |    learning_rate        | 6.6e-05     |
# |    loss                 | 415         |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.00392    |
# |    value_loss           | 755         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 17           |
# |    ep_rew_mean          | 34.2         |
# | time/                   |              |
# |    fps                  | 197          |
# |    iterations           | 53           |
# |    time_elapsed         | 550          |
# |    total_timesteps      | 108544       |
# | train/                  |              |
# |    approx_kl            | 0.0019306454 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.287        |
# |    entropy_loss         | -1.01        |
# |    explained_variance   | 0.0896       |
# |    learning_rate        | 6.6e-05      |
# |    loss                 | 483          |
# |    n_updates            | 520          |
# |    policy_gradient_loss | -0.00348     |
# |    value_loss           | 762          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 16.7          |
# |    ep_rew_mean          | 56.4          |
# | time/                   |               |
# |    fps                  | 198           |
# |    iterations           | 54            |
# |    time_elapsed         | 556           |
# |    total_timesteps      | 110592        |
# | train/                  |               |
# |    approx_kl            | 0.00016972271 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.287         |
# |    entropy_loss         | -1.02         |
# |    explained_variance   | 0.18          |
# ...
# |    clip_range           | 0.287         |
# |    entropy_loss         | -0.815        |
# |    explained_variance   | 0.35          |
# |    learning_rate        | 6.6e-05       |
# |    loss                 | 266           |
# |    n_updates            | 4710          |
# |    policy_gradient_loss | -0.00121      |
# |    value_loss           | 622           |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 15.3         |
# |    ep_rew_mean          | 41.2         |
# | time/                   |              |
# |    fps                  | 289          |
# |    iterations           | 473          |
# |    time_elapsed         | 3346         |
# |    total_timesteps      | 968704       |
# | train/                  |              |
# |    approx_kl            | 0.0006361014 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.287        |
# |    entropy_loss         | -0.816       |
# |    explained_variance   | 0.342        |
# |    learning_rate        | 6.6e-05      |
# |    loss                 | 284          |
# |    n_updates            | 4720         |
# |    policy_gradient_loss | -0.00314     |
# |    value_loss           | 575          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 14.2         |
# |    ep_rew_mean          | 46.8         |
# | time/                   |              |
# |    fps                  | 289          |
# |    iterations           | 474          |
# |    time_elapsed         | 3351         |
# |    total_timesteps      | 970752       |
# | train/                  |              |
# |    approx_kl            | 0.0001626676 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.287        |
# |    entropy_loss         | -0.811       |
# |    explained_variance   | 0.322        |
# |    learning_rate        | 6.6e-05      |
# |    loss                 | 351          |
# |    n_updates            | 4730         |
# |    policy_gradient_loss | -0.00122     |
# |    value_loss           | 607          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 15.1          |
# |    ep_rew_mean          | 49.8          |
# | time/                   |               |
# |    fps                  | 289           |
# |    iterations           | 475           |
# |    time_elapsed         | 3357          |
# |    total_timesteps      | 972800        |
# | train/                  |               |
# |    approx_kl            | 0.00038782894 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.287         |
# |    entropy_loss         | -0.804        |
# |    explained_variance   | 0.243         |
# |    learning_rate        | 6.6e-05       |
# |    loss                 | 362           |
# |    n_updates            | 4740          |
# |    policy_gradient_loss | -0.00207      |
# |    value_loss           | 707           |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 15.3          |
# |    ep_rew_mean          | 53.5          |
# | time/                   |               |
# |    fps                  | 289           |
# |    iterations           | 476           |
# |    time_elapsed         | 3361          |
# |    total_timesteps      | 974848        |
# | train/                  |               |
# |    approx_kl            | 0.00012869158 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.287         |
# |    entropy_loss         | -0.811        |
# |    explained_variance   | 0.341         |
# |    learning_rate        | 6.6e-05       |
# |    loss                 | 295           |
# |    n_updates            | 4750          |
# |    policy_gradient_loss | -0.00165      |
# |    value_loss           | 594           |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 14.6         |
# |    ep_rew_mean          | 50.1         |
# | time/                   |              |
# |    fps                  | 290          |
# |    iterations           | 477          |
# |    time_elapsed         | 3366         |
# |    total_timesteps      | 976896       |
# | train/                  |              |
# |    approx_kl            | 0.0001887726 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.287        |
# |    entropy_loss         | -0.81        |
# |    explained_variance   | 0.344        |
# |    learning_rate        | 6.6e-05      |
# |    loss                 | 267          |
# |    n_updates            | 4760         |
# |    policy_gradient_loss | -0.0021      |
# |    value_loss           | 597          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 15.2         |
# |    ep_rew_mean          | 54.9         |
# | time/                   |              |
# |    fps                  | 290          |
# |    iterations           | 478          |
# |    time_elapsed         | 3373         |
# |    total_timesteps      | 978944       |
# | train/                  |              |
# |    approx_kl            | 0.0003444938 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.287        |
# |    entropy_loss         | -0.811       |
# |    explained_variance   | 0.323        |
# |    learning_rate        | 6.6e-05      |
# |    loss                 | 251          |
# |    n_updates            | 4770         |
# |    policy_gradient_loss | -0.00186     |
# |    value_loss           | 619          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 16.2          |
# |    ep_rew_mean          | 55.5          |
# | time/                   |               |
# |    fps                  | 290           |
# |    iterations           | 479           |
# |    time_elapsed         | 3378          |
# |    total_timesteps      | 980992        |
# | train/                  |               |
# |    approx_kl            | 0.00017704855 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.287         |
# |    entropy_loss         | -0.816        |
# |    explained_variance   | 0.323         |
# |    learning_rate        | 6.6e-05       |
# |    loss                 | 365           |
# |    n_updates            | 4780          |
# |    policy_gradient_loss | -0.00174      |
# |    value_loss           | 623           |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 16.4          |
# |    ep_rew_mean          | 54.4          |
# | time/                   |               |
# |    fps                  | 290           |
# |    iterations           | 480           |
# |    time_elapsed         | 3383          |
# |    total_timesteps      | 983040        |
# | train/                  |               |
# |    approx_kl            | 0.00027114834 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.287         |
# |    entropy_loss         | -0.817        |
# |    explained_variance   | 0.288         |
# |    learning_rate        | 6.6e-05       |
# |    loss                 | 336           |
# |    n_updates            | 4790          |
# |    policy_gradient_loss | -0.00188      |
# |    value_loss           | 628           |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 15.8          |
# |    ep_rew_mean          | 50.5          |
# | time/                   |               |
# |    fps                  | 290           |
# |    iterations           | 481           |
# |    time_elapsed         | 3388          |
# |    total_timesteps      | 985088        |
# | train/                  |               |
# |    approx_kl            | 0.00024006658 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.287         |
# |    entropy_loss         | -0.82         |
# |    explained_variance   | 0.424         |
# |    learning_rate        | 6.6e-05       |
# |    loss                 | 234           |
# |    n_updates            | 4800          |
# |    policy_gradient_loss | -0.00179      |
# |    value_loss           | 527           |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 15.5          |
# |    ep_rew_mean          | 63.5          |
# | time/                   |               |
# |    fps                  | 290           |
# |    iterations           | 482           |
# |    time_elapsed         | 3393          |
# |    total_timesteps      | 987136        |
# | train/                  |               |
# |    approx_kl            | 0.00023679555 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.287         |
# |    entropy_loss         | -0.808        |
# |    explained_variance   | 0.283         |
# |    learning_rate        | 6.6e-05       |
# |    loss                 | 226           |
# |    n_updates            | 4810          |
# |    policy_gradient_loss | -0.0019       |
# |    value_loss           | 625           |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 16.2          |
# |    ep_rew_mean          | 49.4          |
# | time/                   |               |
# |    fps                  | 291           |
# |    iterations           | 483           |
# |    time_elapsed         | 3398          |
# |    total_timesteps      | 989184        |
# | train/                  |               |
# |    approx_kl            | 0.00030924295 |
# |    clip_fraction        | 0.000146      |
# |    clip_range           | 0.287         |
# |    entropy_loss         | -0.805        |
# |    explained_variance   | 0.338         |
# |    learning_rate        | 6.6e-05       |
# |    loss                 | 384           |
# |    n_updates            | 4820          |
# |    policy_gradient_loss | -0.00207      |
# |    value_loss           | 613           |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 16.1          |
# |    ep_rew_mean          | 43.9          |
# | time/                   |               |
# |    fps                  | 291           |
# |    iterations           | 484           |
# |    time_elapsed         | 3404          |
# |    total_timesteps      | 991232        |
# | train/                  |               |
# |    approx_kl            | 0.00019942288 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.287         |
# |    entropy_loss         | -0.81         |
# |    explained_variance   | 0.318         |
# |    learning_rate        | 6.6e-05       |
# |    loss                 | 292           |
# |    n_updates            | 4830          |
# |    policy_gradient_loss | -0.00171      |
# |    value_loss           | 591           |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 15.3          |
# |    ep_rew_mean          | 48.7          |
# | time/                   |               |
# |    fps                  | 291           |
# |    iterations           | 485           |
# |    time_elapsed         | 3408          |
# |    total_timesteps      | 993280        |
# | train/                  |               |
# |    approx_kl            | 0.00042869424 |
# |    clip_fraction        | 0.000146      |
# |    clip_range           | 0.287         |
# |    entropy_loss         | -0.832        |
# |    explained_variance   | 0.233         |
# |    learning_rate        | 6.6e-05       |
# |    loss                 | 277           |
# |    n_updates            | 4840          |
# |    policy_gradient_loss | -0.00227      |
# |    value_loss           | 651           |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 14.8          |
# |    ep_rew_mean          | 49.3          |
# | time/                   |               |
# |    fps                  | 291           |
# |    iterations           | 486           |
# |    time_elapsed         | 3413          |
# |    total_timesteps      | 995328        |
# | train/                  |               |
# |    approx_kl            | 0.00028075257 |
# |    clip_fraction        | 9.77e-05      |
# |    clip_range           | 0.287         |
# |    entropy_loss         | -0.803        |
# |    explained_variance   | 0.31          |
# |    learning_rate        | 6.6e-05       |
# |    loss                 | 268           |
# |    n_updates            | 4850          |
# |    policy_gradient_loss | -0.00152      |
# |    value_loss           | 602           |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 14.6          |
# |    ep_rew_mean          | 50.5          |
# | time/                   |               |
# |    fps                  | 291           |
# |    iterations           | 487           |
# |    time_elapsed         | 3418          |
# |    total_timesteps      | 997376        |
# | train/                  |               |
# |    approx_kl            | 0.00018341027 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.287         |
# |    entropy_loss         | -0.811        |
# |    explained_variance   | 0.318         |
# |    learning_rate        | 6.6e-05       |
# |    loss                 | 341           |
# |    n_updates            | 4860          |
# |    policy_gradient_loss | -0.00176      |
# |    value_loss           | 606           |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 14.6         |
# |    ep_rew_mean          | 51.8         |
# | time/                   |              |
# |    fps                  | 291          |
# |    iterations           | 488          |
# |    time_elapsed         | 3424         |
# |    total_timesteps      | 999424       |
# | train/                  |              |
# |    approx_kl            | 0.0014747523 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.287        |
# |    entropy_loss         | -0.808       |
# |    explained_variance   | 0.329        |
# |    learning_rate        | 6.6e-05      |
# |    loss                 | 225          |
# |    n_updates            | 4870         |
# |    policy_gradient_loss | -0.00409     |
# |    value_loss           | 617          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 15.6         |
# |    ep_rew_mean          | 47           |
# | time/                   |              |
# |    fps                  | 291          |
# |    iterations           | 489          |
# |    time_elapsed         | 3430         |
# |    total_timesteps      | 1001472      |
# | train/                  |              |
# |    approx_kl            | 0.0003404604 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.287        |
# |    entropy_loss         | -0.808       |
# |    explained_variance   | 0.346        |
# |    learning_rate        | 6.6e-05      |
# |    loss                 | 330          |
# |    n_updates            | 4880         |
# |    policy_gradient_loss | -0.00162     |
# |    value_loss           | 603          |
# ------------------------------------------

# %% [markdown]
# ----------- Evaluation ----------

# %%
model = PPO.load(f'{CHECKPOINT_DIR}best_model_{saved_timesteps}')
env = BattleEnvironment(show=True, fps=120)
episodes = 100
for episode in range(episodes): # Evaluates the model n times
    state = env.reset()
    score = 0
    while not env.done:
        env.render()
        action, _states = model.predict(state)
        n_state, reward, done, info = env.step(action)
        score += reward
    print('Episode:{} Score:{}'.format(episode+1, score))
env.show_wins()
# Out:
# red wins
# Episode:1 Score:100
# blue wins
# Episode:2 Score:-32
# blue wins
# Episode:3 Score:-23
# red wins
# Episode:4 Score:100
# red wins
# Episode:5 Score:100
# red wins
# Episode:6 Score:100
# red wins
# Episode:7 Score:100
# blue wins
# Episode:8 Score:-23
# Draw
# Episode:9 Score:-57
# blue wins
# Episode:10 Score:-20
# red wins
# Episode:11 Score:82
# blue wins
# Episode:12 Score:-20
# red wins
# Episode:13 Score:97
# red wins
# Episode:14 Score:100
# red wins
# Episode:15 Score:94
# blue wins
# Episode:16 Score:-20
# blue wins
# Episode:17 Score:-32
# red wins
# Episode:18 Score:100
# red wins
# Episode:19 Score:97
# red wins
# Episode:20 Score:94
# blue wins
# Episode:21 Score:-20
# red wins
# Episode:22 Score:94
# red wins
# Episode:23 Score:100
# red wins
# Episode:24 Score:97
# blue wins
# Episode:25 Score:-20
# red wins
# Episode:26 Score:100
# blue wins
# Episode:27 Score:-20
# blue wins
# Episode:28 Score:-29
# blue wins
# Episode:29 Score:-29
# blue wins
# Episode:30 Score:-20
# blue wins
# Episode:31 Score:-32
# blue wins
# Episode:32 Score:-20
# blue wins
# Episode:33 Score:-35
# red wins
# Episode:34 Score:100
# red wins
# Episode:35 Score:97
# blue wins
# Episode:36 Score:-29
# red wins
# Episode:37 Score:100
# red wins
# Episode:38 Score:100
# Draw
# Episode:39 Score:-63
# red wins
# Episode:40 Score:100
# red wins
# Episode:41 Score:97
# blue wins
# Episode:42 Score:-23
# blue wins
# Episode:43 Score:-29
# red wins
# Episode:44 Score:100
# blue wins
# Episode:45 Score:-23
# blue wins
# Episode:46 Score:-20
# red wins
# Episode:47 Score:100
# red wins
# Episode:48 Score:100
# red wins
# Episode:49 Score:100
# red wins
# Episode:50 Score:100
# blue wins
# Episode:51 Score:-20
# red wins
# Episode:52 Score:100
# red wins
# Episode:53 Score:100
# blue wins
# Episode:54 Score:-32
# red wins
# Episode:55 Score:100
# red wins
# Episode:56 Score:91
# blue wins
# Episode:57 Score:-20
# red wins
# Episode:58 Score:64
# blue wins
# Episode:59 Score:-20
# red wins
# Episode:60 Score:97
# blue wins
# Episode:61 Score:-26
# blue wins
# Episode:62 Score:-26
# red wins
# Episode:63 Score:100
# blue wins
# Episode:64 Score:-23
# blue wins
# Episode:65 Score:-35
# blue wins
# Episode:66 Score:-29
# red wins
# Episode:67 Score:61
# red wins
# Episode:68 Score:100
# red wins
# Episode:69 Score:85
# blue wins
# Episode:70 Score:-20
# blue wins
# Episode:71 Score:-38
# red wins
# Episode:72 Score:100
# blue wins
# Episode:73 Score:-29
# red wins
# Episode:74 Score:97
# blue wins
# Episode:75 Score:-20
# blue wins
# Episode:76 Score:-29
# red wins
# Episode:77 Score:100
# red wins
# Episode:78 Score:67
# red wins
# Episode:79 Score:100
# red wins
# Episode:80 Score:97
# blue wins
# Episode:81 Score:-20
# red wins
# Episode:82 Score:46
# blue wins
# Episode:83 Score:-23
# blue wins
# Episode:84 Score:-20
# red wins
# Episode:85 Score:97
# red wins
# Episode:86 Score:100
# red wins
# Episode:87 Score:100
# blue wins
# Episode:88 Score:-35
# blue wins
# Episode:89 Score:-20
# blue wins
# Episode:90 Score:-29
# blue wins
# Episode:91 Score:-29
# red wins
# Episode:92 Score:100
# blue wins
# Episode:93 Score:-29
# red wins
# Episode:94 Score:100
# blue wins
# Episode:95 Score:-20
# red wins
# Episode:96 Score:100
# blue wins
# Episode:97 Score:-26
# red wins
# Episode:98 Score:100
# blue wins
# Episode:99 Score:-20
# red wins
# Episode:100 Score:94
# Wins by red: 52
# Wins by blue: 46
# Tied games: 2

# %% [markdown]
# ---------- Visualize Games ----------

# %%
env = BattleEnvironment(show=True)
episodes = 10
for episode in range(episodes): # Evaluates the model n times
    state = env.reset()
    score = 0
    while not env.done:
        env.render()
        action, _states = model.predict(state)
        # action = env.action_space.sample()
        n_state, reward, done, info = env.step(action)
        score += reward
    print('Episode:{} Score:{}'.format(episode+1, score))
# Out:
# blue wins
# Episode:1 Score:-20
# red wins
# Episode:2 Score:100
# red wins
# Episode:3 Score:100
# blue wins
# Episode:4 Score:-20
# red wins
# Episode:5 Score:100
# red wins
# Episode:6 Score:100
# blue wins
# Episode:7 Score:-26
# blue wins
# Episode:8 Score:-20
# blue wins
# Episode:9 Score:-26
# red wins
# Episode:10 Score:73
