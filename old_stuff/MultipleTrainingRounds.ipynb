# %% [markdown]
# Working on implementing a Stable-Baselines3 Model

# %%
import random
import pygame
import numpy as np
import numpy.linalg as LA
import math
from collections import defaultdict
import gym
from gym import spaces
from stable_baselines3 import PPO
import os
import sys

from pygame.locals import *

WHITE = (255, 255, 255)
RED = (255, 0, 0)
BLUE = (0, 0, 255)
DISP_WIDTH = 1000
DISP_HEIGHT = 1000
FPS = pygame.time.Clock()

os.environ['KMP_DUPLICATE_LIB_OK']='True'

# %%
def get_angle(p1, p0):
    return math.degrees(math.atan2(p1[1]-p0[1],p1[0]-p0[0]))

def dist(p1,p0):
    return math.sqrt((p1[0]-p0[0])**2 + (p1[1]-p0[1])**2)

def blitRotate(image, pos, originPos, angle):

    # offset from pivot to center
    image_rect = image.get_rect(topleft = (pos[0] - originPos[0], pos[1]-originPos[1]))
    offset_center_to_pivot = pygame.math.Vector2(pos) - image_rect.center
    
    # roatated offset from pivot to center
    rotated_offset = offset_center_to_pivot.rotate(-angle)

    # rotated image center
    rotated_image_center = (pos[0] - rotated_offset.x, pos[1] - rotated_offset.y)

    # get a rotated image
    rotated_image = pygame.transform.rotate(image, angle)
    rotated_image_rect = rotated_image.get_rect(center = rotated_image_center)

    return rotated_image, rotated_image_rect

def calc_new_xy(old_xy, speed, time, angle):
    new_x = old_xy[0] + (speed*time*math.cos(-math.radians(angle)))
    new_y = old_xy[1] + (speed*time*math.sin(-math.radians(angle)))
    return (new_x, new_y)

# %%
class Plane:
    def __init__(self, team): 
        self.team = team
        self.image = pygame.image.load(f"Images/{team}_plane.png")
        self.w, self.h = self.image.get_size()
        self.heading = 0
        self.rect = self.image.get_rect()
        self.reset()

    def reset(self):
        if self.team == 'red':
            x = (DISP_WIDTH - self.w/2)/2 * random.random()
            y = (DISP_HEIGHT - self.h/2) * random.random()
            self.rect.center = (x, y)
            self.heading = 90 * random.random() if random.random() < .5 else 90 * random.random() + 270
            
        else:
            x = (DISP_WIDTH - self.w/2)/2 * random.random() + (DISP_WIDTH - self.w/2)/2
            y = (DISP_HEIGHT - self.h/2) * random.random()
            self.rect.center = (x, y)
            self.heading = 180 * random.random() + 90
        
    def rotate(self, angle):
        self.heading += angle

    def set_heading(self, heading):
        self.heading = heading

    def forward(self, speed, time):
        oldpos = self.rect.center
        self.rect.center = calc_new_xy(oldpos, speed, time, self.heading)

    def draw(self, surface):
        image, rect = blitRotate(self.image, self.rect.center, (self.w/2, self.h/2), self.heading)
        surface.blit(image, rect)

    def update(self):
        # Keep player on the screen
        if self.rect.left < 0:
            self.rect.left = 0
        if self.rect.right > DISP_WIDTH:
            self.rect.right = DISP_WIDTH
        if self.rect.top <= 0:
            self.rect.top = 0
        if self.rect.bottom >= DISP_HEIGHT:
            self.rect.bottom = DISP_HEIGHT

    def get_pos(self):
        return self.rect.center

# %%
class Base:
    
    def __init__(self, team):
        self.team = team
        self.image = pygame.image.load(f"Images/{team}_base.png")
        self.w, self.h = self.image.get_size()
        self.rect = self.image.get_rect()
        self.reset()
        
    def reset(self):
        if self.team == 'red':
            x = (DISP_WIDTH - self.w/2)/2 * random.random()
            y = (DISP_HEIGHT - self.h/2) * random.random()
            self.rect.center = (x, y)
        else:
            x = (DISP_WIDTH - self.w/2)/2 * random.random() + (DISP_WIDTH - self.w/2)/2
            y = (DISP_HEIGHT - self.h/2) * random.random()
            self.rect.center = (x, y)

    def draw(self, surface):
        surface.blit(self.image, self.rect)
            
    def get_pos(self):
        return self.rect.center

# %%
class Bullet(pygame.sprite.Sprite):
    def __init__(self, x, y, angle, speed, fteam, oteam):
        pygame.sprite.Sprite.__init__(self)
        self.off_screen = False
        self.image = pygame.Surface((8, 4), pygame.SRCALPHA)
        self.fteam = fteam
        self.color = RED if self.fteam == 'red' else BLUE
        self.oteam = oteam
        self.image.fill(self.color)
        self.rect = self.image.get_rect(center=(x, y))
        self.w, self.h = self.image.get_size()
        self.heading = angle
        self.pos = (x, y)
        self.speed = speed

    def update(self, screen_width, screen_height, time):
        oldpos = self.rect.center
        self.rect.center = calc_new_xy(oldpos, self.speed, time, self.heading)
        if self.rect.centerx > screen_width or self.rect.centerx < 0 or self.rect.centery > screen_height or self.rect.centery < 0:
            self.off_screen = True
            return 'none'
        for plane in self.oteam['planes']:
            if self.rect.colliderect(plane.rect):
                return 'plane'
        if self.rect.colliderect(self.oteam['base'].rect):
            return 'base'
        return 'none'

    def draw(self, surface):
        image, rect = blitRotate(self.image, self.rect.center, (self.w/2, self.h/2), self.heading)
        surface.blit(image, rect)

# %%
class BattleEnvironment(gym.Env):
    def __init__(self, show):
        super(BattleEnvironment, self).__init__()
        self.show = show # Visualization

        # For the Agent, actions are turn left, turn right, turn to enemy, turn to target, go forward, or shoot
        # For the Random choice Agent, the actions are to enemy, to target, shoot enemy, or shoot target
        self.action_space = spaces.Discrete(6)
        self.random_action_space = [0, 1, 4, 5]
        self.width = DISP_WIDTH
        self.height = DISP_HEIGHT

        high = np.array( # Observation space: fplane_pos_x, fplane_pos_y, fplane_angle, dist_obase, dist_oplane, rel_angle_obase, rel_angle_oplane
            [
                self.width,
                self.height,
                720,
                math.sqrt(math.pow(self.width, 2) + math.pow(self.height, 2)),
                math.sqrt(math.pow(self.width, 2) + math.pow(self.height, 2)),
                720,
                720,
            ],
            dtype=np.float32,
        )
        
        self.observation_space = spaces.Box(-high, high, dtype=np.float32)

        self.team = {}
        self.team['red'] = {}
        self.team['blue'] = {}
        self.team['red']['base'] = Base('red')
        self.team['blue']['base'] = Base('blue')
        self.team['red']['planes'] = []
        self.team['red']['planes'].append(Plane('red'))
        self.team['blue']['planes'] = []
        self.team['blue']['planes'].append(Plane('blue'))
        self.team['red']['wins'] = 0
        self.team['blue']['wins'] = 0

        self.ties = 0


        self.bullets = []

        self.time_step = 0.1 # hours
        self.speed = 500 # knots - nautical miles per hour
        self.bullet_speed = 700
        self.total_time = 0 # in hours
        self.max_time = 10 # hours
        self.shot_history = []

    def _get_observation(self):
        # This code will all have to be changed when adding multiple planes
        fplane = self.team['red']['planes'][0]
        oplane = self.team['blue']['planes'][0]
        obase = self.team['red']['base']

        fplane_pos = fplane.get_pos()
        fplane_angle = fplane.heading
        oplane_pos = oplane.get_pos()
        obase_pos = obase.get_pos()

        dist_oplane = dist(oplane_pos, fplane_pos)
        dist_obase = dist(obase_pos, fplane_pos)

        angle_to_oplane = get_angle(oplane_pos, fplane_pos)
        angle_to_obase = get_angle(obase_pos, fplane_pos)
        rel_angle_oplane = (angle_to_oplane - fplane_angle) % 360
        rel_angle_obase = (angle_to_obase - fplane_angle) % 360
        
        self.observation = (fplane_pos[0], fplane_pos[1], fplane_angle, dist_obase, dist_oplane, rel_angle_obase, rel_angle_oplane)
        return np.array(self.observation, dtype=np.float32)

        
    def reset(self): # return observation
        self.done = False
        self.winner = 'none'

        self.team['red']['base'].reset()
        self.team['blue']['base'].reset()

        for plane in self.team['red']['planes']:
            plane.reset()
        for plane in self.team['blue']['planes']:
            plane.reset()

        self.total_time = 0
        self.bullets = []

        if self.show:
            pygame.init()
            self.display = pygame.display.set_mode((DISP_WIDTH, DISP_HEIGHT))
            pygame.display.set_caption("Battlespace Simulator")

        return self._get_observation()

    def step(self, action): # return observation, reward, done, info

        reward = 0

        # Check if over time, if so, end game in tie
        self.total_time += self.time_step
        if self.total_time >= self.max_time:
            self.done = True
            self.ties += 1
            if self.show:
                self.render()
                print("Draw")
            return self._get_observation(), 0, self.done, {}

        # Red turn
        self.friendly = 'red'
        self.opponent = 'blue'
        reward += self._process_action(action, self.team[self.friendly], self.team[self.opponent])
        
        # Blue turn
        self.friendly = 'blue'
        self.opponent = 'red'
        self._process_action(self.random_action_space[random.randint(0, 3)], self.team[self.friendly], self.team[self.opponent])        
        

        # Check if bullets hit and move them
        for bullet in self.bullets:
            if not bullet.off_screen:
                outcome = bullet.update(self.width, self.height, self.time_step)
                if outcome == 'plane' or outcome == 'base': # If a bullet hit
                    self.winner = bullet.fteam
                    self.team[self.winner]['wins'] += 1
                    self.done = True
                    reward = reward + HIT_BASE_REWARD if outcome == 'base' else reward + HIT_PLANE_REWARD
                    if self.show:
                        self.render()
                        print(f"{self.winner} wins")
                    return self._get_observation(), reward, self.done, {}
            else:
                self.bullets.pop(self.bullets.index(bullet))
    
        # Continue game
        if self.show:
            self.render()
        return self._get_observation(), reward, self.done, {}
    
    def _process_action(self, action, fteam, oteam): # friendly and opponent
        reward = 0

        fplane = fteam['planes'][0]
        oplane = oteam['planes'][0]
        obase = oteam['base']

        fplane_pos = fplane.get_pos()
        fplane_angle = fplane.heading
        oplane_pos = oplane.get_pos()
        obase_pos = obase.get_pos()

        dist_oplane = dist(oplane_pos, fplane_pos)
        dist_obase = dist(obase_pos, fplane_pos)

        angle_to_oplane = get_angle(oplane_pos, fplane_pos)
        angle_to_obase = get_angle(obase_pos, fplane_pos)
        rel_angle_oplane = (angle_to_oplane - fplane_angle) % 360
        rel_angle_obase = (angle_to_obase - fplane_angle) % 360

        # --------------- FORWARDS ---------------
        if action == 0: 
            fplane.forward(self.speed, self.time_step)

         # --------------- SHOOT ---------------
        elif action == 1:
            self.bullets.append(Bullet(fplane_pos[0], fplane_pos[1], fplane_angle, self.bullet_speed, self.friendly, oteam))
            fplane.forward(self.speed, self.time_step)
        
        # --------------- TURN RIGHT ---------------
        elif action == 2:
            fplane.rotate(-STEP_TURN)
            fplane.forward(self.speed, self.time_step)

        # ---------------- TURN LEFT ----------------
        elif action == 3:
            fplane.rotate(STEP_TURN)
            fplane.forward(self.speed, self.time_step)

        # ---------------- TURN TO OPLANE ----------------
        elif action == 4:
            if math.fabs(rel_angle_oplane) < STEP_TURN: # within step_turn of base
                fplane.set_heading(angle_to_oplane)

            elif math.fabs(rel_angle_oplane) > 360 - STEP_TURN: # within step_turn of base
                fplane.set_heading(angle_to_oplane)

            elif math.fabs(rel_angle_oplane) < 180: # turn right
                fplane.rotate(-STEP_TURN)

            else: # turn left
                fplane.rotate(STEP_TURN)
                
            fplane.forward(self.speed, self.time_step)

        # ---------------- TURN TO OBASE ----------------
        elif action == 5:
            if math.fabs(rel_angle_obase) < STEP_TURN: # within step_turn of base
                fplane.set_heading(angle_to_obase)

            elif math.fabs(rel_angle_obase) > 360 - STEP_TURN: # within step_turn of base
                fplane.set_heading(angle_to_obase)

            elif math.fabs(rel_angle_obase) < 180: # turn right
                fplane.rotate(-STEP_TURN)

            else: # turn left
                fplane.rotate(STEP_TURN)

            fplane.forward(self.speed, self.time_step)
        
        # ---------------- GIVE REWARDS IF CLOSER (DIST OR ANGLE) ----------------
        new_fplane_pos = fplane.get_pos()
        new_fplane_angle = fplane.heading
        new_oplane_pos = oplane.get_pos()
        new_obase_pos = obase.get_pos()

        new_dist_oplane = dist(new_oplane_pos, new_fplane_pos)
        new_dist_obase = dist(new_obase_pos, new_fplane_pos)

        new_angle_to_oplane = get_angle(new_oplane_pos, new_fplane_pos)
        new_angle_to_obase = get_angle(new_obase_pos, new_fplane_pos)
        new_rel_angle_oplane = (new_angle_to_oplane - new_fplane_angle) % 360
        new_rel_angle_obase = (new_angle_to_obase - new_fplane_angle) % 360

        if new_dist_oplane < dist_oplane: # If got closer to enemy plane
            reward += CLOSER_TO_PLANE_REWARD

        if new_dist_obase < dist_obase: # If got closer to enemy base
            reward += CLOSER_TO_BASE_REWARD

        if math.fabs(new_rel_angle_oplane) < math.fabs(rel_angle_oplane): # If aiming closer to enemy plane
            reward += TURN_TO_PLANE_REWARD

        if math.fabs(new_rel_angle_obase) < math.fabs(rel_angle_obase): # If aiming closer to enemy base
            reward += TURN_TO_BASE_REWARD

        return reward

    def draw_shot(self, hit, friendly_pos, target_pos, team):
        color = (0, 0, 0)
        color = (255, 0, 0) if team == 'red' else (0, 0, 255)
        if not hit: target_pos = (target_pos[0] + (random.random() * 2 - 1) * 100, target_pos[1] + (random.random() * 2 - 1) * 100)
        self.shot_history.append((hit, friendly_pos, target_pos, color))
    
    def winner_screen(self):
        if self.show:
            font = pygame.font.Font('freesansbold.ttf', 32)
            if self.winner != 'none':
                text = font.render(f"THE WINNER IS {self.winner.upper()}", True, (0, 0, 0))
                textRect = text.get_rect()
                textRect.center = (DISP_WIDTH//2, DISP_HEIGHT//2)
            else:
                text = font.render(f"THE GAME IS A TIE", True, (0, 0, 0))
                textRect = text.get_rect()
                textRect.center = (DISP_WIDTH//2, DISP_HEIGHT//2)
            self.display.blit(text, textRect)

    def show_wins(self):
        print("Wins by red:", self.team['red']['wins'])
        print("Wins by blue:", self.team['blue']['wins'])
        print("Tied games:", self.ties)

    def render(self):
        if self.show: # Just to ensure it won't render if self.show == False
            for event in pygame.event.get():
                # Check for KEYDOWN event
                if event.type == KEYDOWN:
                    # If the Esc key is pressed, then exit the main loop
                    if event.key == K_ESCAPE:
                        pygame.quit()
                        sys.exit()
                        return
                # Check for QUIT event. If QUIT, then set running to false.
                elif event.type == QUIT:
                    pygame.quit()
                    sys.exit()
                    return
                    
            # Fill background
            self.display.fill(WHITE)

            # Draw bullets
            for bullet in self.bullets:
                bullet.draw(self.display)
                    
            # Draw bases
            self.team['red']['base'].draw(self.display)
            self.team['blue']['base'].draw(self.display)

            # Draw planes
            for plane in self.team['red']['planes']:
                plane.update()
                plane.draw(self.display)
            for plane in self.team['blue']['planes']:
                plane.update()
                plane.draw(self.display)

            # Winner Screen
            if self.done:
                font = pygame.font.Font('freesansbold.ttf', 32)
                if self.winner != 'none':
                    text = font.render(f"THE WINNER IS {self.winner.upper()}", True, (0, 0, 0))
                    textRect = text.get_rect()
                    textRect.center = (DISP_WIDTH//2, DISP_HEIGHT//2)
                else:
                    text = font.render(f"THE GAME IS A TIE", True, (0, 0, 0))
                    textRect = text.get_rect()
                    textRect.center = (DISP_WIDTH//2, DISP_HEIGHT//2)
                self.display.blit(text, textRect)
                pygame.display.update()
                pygame.time.wait(3000)
                pygame.quit()
                return
            
            pygame.display.update()
            FPS.tick(7)

# %% [markdown]
# ---------- THESE REWARD VALUES SHOULD ENSURE THAT THE AGENT IS WILLING TO SHOOT -------------
#
# In other words, there's a high probability of hitting and little/no punishment for missing a shot
# Since this is likely the first round of training, it's okay if the agent shoots too often

# %%
STEP_TURN = 20 # degrees (amt to turn per step)
HIT_BASE_REWARD = 5000
HIT_PLANE_REWARD = 5000
MISS_PUNISHMENT = -1
CLOSER_TO_BASE_REWARD = 5
CLOSER_TO_PLANE_REWARD = 5
TURN_TO_BASE_REWARD = 5
TURN_TO_PLANE_REWARD = 5

TIMESTEPS = 50000 # Saves every x steps
R1_ITERATIONS = 10
R2_ITERATIONS = 10

train_env = BattleEnvironment(False)
logdir = "logs"
model_name = "PPO_ROUND1"
models_dir = f"models/{model_name}"

if not os.path.exists(logdir):
    os.makedirs(logdir)
if not os.path.exists(models_dir):
    os.makedirs(models_dir)

model = PPO("MlpPolicy", train_env, verbose=1, tensorboard_log=logdir)

for i in range(R1_ITERATIONS):
    model.learn(total_timesteps=TIMESTEPS, reset_num_timesteps=False, tb_log_name=f"{model_name}")
    model.save(f"{models_dir}/{TIMESTEPS*(i+1)}")

del model
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to logs\PPO_ROUND1_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 75.6     |
# |    ep_rew_mean     | 1.84e+03 |
# | time/              |          |
# |    fps             | 466      |
# |    iterations      | 1        |
# |    time_elapsed    | 4        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 81.7        |
# |    ep_rew_mean          | 1.63e+03    |
# | time/                   |             |
# |    fps                  | 478         |
# |    iterations           | 2           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.009868082 |
# |    clip_fraction        | 0.0287      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.79       |
# |    explained_variance   | 0.00011     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.26e+04    |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00706    |
# |    value_loss           | 4.06e+05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 84.1         |
# |    ep_rew_mean          | 1.49e+03     |
# | time/                   |              |
# |    fps                  | 473          |
# |    iterations           | 3            |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0074861925 |
# |    clip_fraction        | 0.038        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.77        |
# |    explained_variance   | 8.62e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.3e+03      |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00744     |
# |    value_loss           | 3.8e+05      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 84.5         |
# |    ep_rew_mean          | 1.52e+03     |
# | time/                   |              |
# |    fps                  | 477          |
# |    iterations           | 4            |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0108016785 |
# |    clip_fraction        | 0.119        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.75        |
# |    explained_variance   | 7.75e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.73e+03     |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00901     |
# |    value_loss           | 1.81e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 88.8         |
# |    ep_rew_mean          | 1.35e+03     |
# | time/                   |              |
# |    fps                  | 475          |
# |    iterations           | 5            |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0100751305 |
# |    clip_fraction        | 0.0487       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.73        |
# |    explained_variance   | 1.07e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.13e+05     |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00816     |
# |    value_loss           | 2.78e+05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 88          |
# |    ep_rew_mean          | 1.5e+03     |
# | time/                   |             |
# |    fps                  | 468         |
# |    iterations           | 6           |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.010698594 |
# |    clip_fraction        | 0.0847      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.67       |
# |    explained_variance   | 2.72e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.9e+03     |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0121     |
# |    value_loss           | 5.44e+04    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 87.7         |
# |    ep_rew_mean          | 1.58e+03     |
# | time/                   |              |
# |    fps                  | 481          |
# |    iterations           | 7            |
# |    time_elapsed         | 29           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0063174497 |
# |    clip_fraction        | 0.0124       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.63        |
# |    explained_variance   | 3.22e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.6e+05      |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00525     |
# |    value_loss           | 6.3e+05      |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 84.5       |
# |    ep_rew_mean          | 1.81e+03   |
# | time/                   |            |
# |    fps                  | 484        |
# |    iterations           | 8          |
# |    time_elapsed         | 33         |
# |    total_timesteps      | 16384      |
# | train/                  |            |
# |    approx_kl            | 0.01232594 |
# |    clip_fraction        | 0.0498     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.57      |
# |    explained_variance   | -8.82e-06  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.09e+05   |
# |    n_updates            | 70         |
# |    policy_gradient_loss | -0.00971   |
# |    value_loss           | 2.25e+05   |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 79.8         |
# |    ep_rew_mean          | 2.18e+03     |
# | time/                   |              |
# |    fps                  | 473          |
# |    iterations           | 9            |
# |    time_elapsed         | 38           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0077818725 |
# |    clip_fraction        | 0.0151       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.49        |
# |    explained_variance   | -1.43e-06    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.8e+05      |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00491     |
# |    value_loss           | 6.98e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 79           |
# |    ep_rew_mean          | 2.32e+03     |
# | time/                   |              |
# |    fps                  | 484          |
# |    iterations           | 10           |
# |    time_elapsed         | 42           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0031356916 |
# |    clip_fraction        | 0.00645      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.49        |
# |    explained_variance   | 7.03e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.14e+05     |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00546     |
# |    value_loss           | 8.73e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 76.2         |
# |    ep_rew_mean          | 2.47e+03     |
# | time/                   |              |
# |    fps                  | 486          |
# |    iterations           | 11           |
# |    time_elapsed         | 46           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0033839997 |
# |    clip_fraction        | 0.00356      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.46        |
# |    explained_variance   | 1.07e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.96e+05     |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00547     |
# |    value_loss           | 8.28e+05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 78.7        |
# |    ep_rew_mean          | 2.37e+03    |
# | time/                   |             |
# |    fps                  | 498         |
# |    iterations           | 12          |
# |    time_elapsed         | 49          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.005974589 |
# |    clip_fraction        | 0.0156      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.43       |
# |    explained_variance   | 8.94e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.58e+05    |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00602    |
# |    value_loss           | 5.21e+05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 81.4        |
# |    ep_rew_mean          | 2.26e+03    |
# | time/                   |             |
# |    fps                  | 500         |
# |    iterations           | 13          |
# |    time_elapsed         | 53          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.008197492 |
# |    clip_fraction        | 0.0537      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | -6.91e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.82e+05    |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00667    |
# |    value_loss           | 3.3e+05     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 83           |
# |    ep_rew_mean          | 2.14e+03     |
# | time/                   |              |
# |    fps                  | 506          |
# |    iterations           | 14           |
# |    time_elapsed         | 56           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0027333824 |
# |    clip_fraction        | 0.00645      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | 4.77e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.93e+05     |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.004       |
# |    value_loss           | 5.64e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 83.8         |
# |    ep_rew_mean          | 2.26e+03     |
# | time/                   |              |
# |    fps                  | 515          |
# |    iterations           | 15           |
# |    time_elapsed         | 59           |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0043228962 |
# |    clip_fraction        | 0.0125       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.28        |
# |    explained_variance   | 1.79e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.1e+05      |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00577     |
# |    value_loss           | 4.61e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 82.2         |
# |    ep_rew_mean          | 2.45e+03     |
# | time/                   |              |
# |    fps                  | 523          |
# |    iterations           | 16           |
# |    time_elapsed         | 62           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0033597597 |
# |    clip_fraction        | 0.0148       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.27        |
# |    explained_variance   | 1.2e-05      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.39e+05     |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.0056      |
# |    value_loss           | 9.03e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 82.7         |
# |    ep_rew_mean          | 2.45e+03     |
# | time/                   |              |
# |    fps                  | 530          |
# |    iterations           | 17           |
# |    time_elapsed         | 65           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0017154067 |
# |    clip_fraction        | 0.00171      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.24        |
# |    explained_variance   | 1.19e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.72e+05     |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00416     |
# |    value_loss           | 7.54e+05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 82.3        |
# |    ep_rew_mean          | 2.5e+03     |
# | time/                   |             |
# |    fps                  | 530         |
# |    iterations           | 18          |
# |    time_elapsed         | 69          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.010235772 |
# |    clip_fraction        | 0.0582      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.26       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.26e+05    |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00628    |
# |    value_loss           | 7.12e+05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 83          |
# |    ep_rew_mean          | 2.4e+03     |
# | time/                   |             |
# |    fps                  | 534         |
# |    iterations           | 19          |
# |    time_elapsed         | 72          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.006177904 |
# |    clip_fraction        | 0.024       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.22       |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.87e+05    |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00566    |
# |    value_loss           | 5.67e+05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 80.8         |
# |    ep_rew_mean          | 2.37e+03     |
# | time/                   |              |
# |    fps                  | 539          |
# |    iterations           | 20           |
# |    time_elapsed         | 75           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0070640426 |
# |    clip_fraction        | 0.0679       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.19        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.9e+05      |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00648     |
# |    value_loss           | 4.96e+05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 82.2        |
# |    ep_rew_mean          | 2.4e+03     |
# | time/                   |             |
# |    fps                  | 544         |
# |    iterations           | 21          |
# |    time_elapsed         | 78          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.006999048 |
# |    clip_fraction        | 0.0243      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.15       |
# |    explained_variance   | 2.98e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.54e+05    |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00654    |
# |    value_loss           | 8.26e+05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 78.7        |
# |    ep_rew_mean          | 2.67e+03    |
# | time/                   |             |
# |    fps                  | 548         |
# |    iterations           | 22          |
# |    time_elapsed         | 82          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.005990092 |
# |    clip_fraction        | 0.0302      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.12       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.48e+05    |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00415    |
# |    value_loss           | 7.13e+05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 78.6         |
# |    ep_rew_mean          | 2.78e+03     |
# | time/                   |              |
# |    fps                  | 546          |
# |    iterations           | 23           |
# |    time_elapsed         | 86           |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0059923623 |
# |    clip_fraction        | 0.0462       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.11        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.86e+05     |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00652     |
# |    value_loss           | 1.14e+06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 80.6         |
# |    ep_rew_mean          | 2.76e+03     |
# | time/                   |              |
# |    fps                  | 550          |
# |    iterations           | 24           |
# |    time_elapsed         | 89           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0026676129 |
# |    clip_fraction        | 0.0177       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.1         |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.32e+05     |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.0042      |
# |    value_loss           | 9.8e+05      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 80.3        |
# |    ep_rew_mean          | 2.82e+03    |
# | time/                   |             |
# |    fps                  | 554         |
# |    iterations           | 25          |
# |    time_elapsed         | 92          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.004917948 |
# |    clip_fraction        | 0.0431      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.1        |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.96e+04    |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00524    |
# |    value_loss           | 5.57e+05    |
# -----------------------------------------
# Logging to logs\PPO_ROUND1_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 81       |
# |    ep_rew_mean     | 2.83e+03 |
# | time/              |          |
# |    fps             | 646      |
# |    iterations      | 1        |
# |    time_elapsed    | 3        |
# |    total_timesteps | 53248    |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 81.9         |
# |    ep_rew_mean          | 2.63e+03     |
# | time/                   |              |
# |    fps                  | 596          |
# |    iterations           | 2            |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0039080535 |
# |    clip_fraction        | 0.0064       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.05        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.19e+05     |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.00424     |
# |    value_loss           | 1.08e+06     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 79.4        |
# |    ep_rew_mean          | 2.76e+03    |
# | time/                   |             |
# |    fps                  | 590         |
# |    iterations           | 3           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.009906765 |
# |    clip_fraction        | 0.0923      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.17e+04    |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.00566    |
# |    value_loss           | 4.35e+05    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 76.7       |
# |    ep_rew_mean          | 2.82e+03   |
# | time/                   |            |
# |    fps                  | 608        |
# |    iterations           | 4          |
# |    time_elapsed         | 13         |
# |    total_timesteps      | 59392      |
# | train/                  |            |
# |    approx_kl            | 0.00439026 |
# |    clip_fraction        | 0.033      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.01      |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.25e+05   |
# |    n_updates            | 280        |
# |    policy_gradient_loss | -0.00638   |
# |    value_loss           | 7.86e+05   |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 78.8         |
# |    ep_rew_mean          | 2.69e+03     |
# | time/                   |              |
# |    fps                  | 616          |
# |    iterations           | 5            |
# |    time_elapsed         | 16           |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0032244734 |
# |    clip_fraction        | 0.0167       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.01        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.75e+05     |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.00611     |
# |    value_loss           | 1.35e+06     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 79.2        |
# |    ep_rew_mean          | 2.75e+03    |
# | time/                   |             |
# |    fps                  | 623         |
# |    iterations           | 6           |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.005234001 |
# |    clip_fraction        | 0.0238      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.99       |
# |    explained_variance   | 1.79e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.18e+05    |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.00345    |
# |    value_loss           | 4.22e+05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 81.8        |
# |    ep_rew_mean          | 2.57e+03    |
# | time/                   |             |
# |    fps                  | 602         |
# |    iterations           | 7           |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.008703533 |
# |    clip_fraction        | 0.0373      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.55e+05    |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.00534    |
# |    value_loss           | 5.47e+05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 84.1         |
# |    ep_rew_mean          | 2.49e+03     |
# | time/                   |              |
# |    fps                  | 605          |
# |    iterations           | 8            |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 67584        |
# | train/                  |              |
# |    approx_kl            | 0.0044452553 |
# |    clip_fraction        | 0.0293       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.01        |
# |    explained_variance   | 1.19e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.71e+04     |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.00577     |
# |    value_loss           | 5.53e+05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 83.1        |
# |    ep_rew_mean          | 2.62e+03    |
# | time/                   |             |
# |    fps                  | 611         |
# |    iterations           | 9           |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.008682924 |
# |    clip_fraction        | 0.0318      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1          |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.42e+05    |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.00495    |
# |    value_loss           | 1.11e+06    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 80.4        |
# |    ep_rew_mean          | 2.69e+03    |
# | time/                   |             |
# |    fps                  | 611         |
# |    iterations           | 10          |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.002605985 |
# |    clip_fraction        | 0.0162      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.99       |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.33e+05    |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.00414    |
# |    value_loss           | 7.16e+05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 80.4        |
# |    ep_rew_mean          | 2.8e+03     |
# | time/                   |             |
# |    fps                  | 615         |
# |    iterations           | 11          |
# |    time_elapsed         | 36          |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.008271538 |
# |    clip_fraction        | 0.0281      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1          |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.76e+05    |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.00496    |
# |    value_loss           | 8.41e+05    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 79.8       |
# |    ep_rew_mean          | 2.8e+03    |
# | time/                   |            |
# |    fps                  | 602        |
# |    iterations           | 12         |
# |    time_elapsed         | 40         |
# |    total_timesteps      | 75776      |
# | train/                  |            |
# |    approx_kl            | 0.00653153 |
# |    clip_fraction        | 0.0238     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.954     |
# |    explained_variance   | 1.19e-07   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 3.72e+05   |
# |    n_updates            | 360        |
# |    policy_gradient_loss | -0.00356   |
# |    value_loss           | 7.12e+05   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 80.3        |
# |    ep_rew_mean          | 2.76e+03    |
# | time/                   |             |
# |    fps                  | 605         |
# |    iterations           | 13          |
# |    time_elapsed         | 43          |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.004136061 |
# |    clip_fraction        | 0.0189      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.972      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.61e+05    |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.00553    |
# |    value_loss           | 1.02e+06    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 80.6         |
# |    ep_rew_mean          | 2.82e+03     |
# | time/                   |              |
# |    fps                  | 599          |
# |    iterations           | 14           |
# |    time_elapsed         | 47           |
# |    total_timesteps      | 79872        |
# | train/                  |              |
# |    approx_kl            | 0.0040249573 |
# |    clip_fraction        | 0.0255       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.977       |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.93e+05     |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.00297     |
# |    value_loss           | 6.43e+05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 79.7        |
# |    ep_rew_mean          | 2.81e+03    |
# | time/                   |             |
# |    fps                  | 587         |
# |    iterations           | 15          |
# |    time_elapsed         | 52          |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.003712181 |
# |    clip_fraction        | 0.0475      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.956      |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.41e+05    |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.00606    |
# |    value_loss           | 9e+05       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 78.1         |
# |    ep_rew_mean          | 2.84e+03     |
# | time/                   |              |
# |    fps                  | 551          |
# |    iterations           | 16           |
# |    time_elapsed         | 59           |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 0.0034678734 |
# |    clip_fraction        | 0.0317       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.916       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.06e+05     |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.00575     |
# |    value_loss           | 6.11e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 75.2         |
# |    ep_rew_mean          | 2.96e+03     |
# | time/                   |              |
# |    fps                  | 541          |
# |    iterations           | 17           |
# |    time_elapsed         | 64           |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0033966668 |
# |    clip_fraction        | 0.00508      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.914       |
# |    explained_variance   | 1.19e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.52e+05     |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.00443     |
# |    value_loss           | 1.16e+06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 73.7         |
# |    ep_rew_mean          | 3.09e+03     |
# | time/                   |              |
# |    fps                  | 531          |
# |    iterations           | 18           |
# |    time_elapsed         | 69           |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0049309153 |
# |    clip_fraction        | 0.0222       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.888       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.23e+05     |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.0042      |
# |    value_loss           | 9.04e+05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 73.4        |
# |    ep_rew_mean          | 3.1e+03     |
# | time/                   |             |
# |    fps                  | 529         |
# |    iterations           | 19          |
# |    time_elapsed         | 73          |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.006140985 |
# |    clip_fraction        | 0.0208      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.825      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.21e+05    |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.00495    |
# |    value_loss           | 1.24e+06    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 76.3        |
# |    ep_rew_mean          | 3.04e+03    |
# | time/                   |             |
# |    fps                  | 534         |
# |    iterations           | 20          |
# |    time_elapsed         | 76          |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.004503917 |
# |    clip_fraction        | 0.0148      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.805      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.25e+05    |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.0079     |
# |    value_loss           | 1.1e+06     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 78.5         |
# |    ep_rew_mean          | 2.88e+03     |
# | time/                   |              |
# |    fps                  | 538          |
# |    iterations           | 21           |
# |    time_elapsed         | 79           |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0030533075 |
# |    clip_fraction        | 0.0172       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.816       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.09e+05     |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.00625     |
# |    value_loss           | 8.82e+05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 79.1        |
# |    ep_rew_mean          | 2.74e+03    |
# | time/                   |             |
# |    fps                  | 542         |
# |    iterations           | 22          |
# |    time_elapsed         | 83          |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.011504865 |
# |    clip_fraction        | 0.124       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.722      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.45e+05    |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.0108     |
# |    value_loss           | 5.43e+05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 80.1         |
# |    ep_rew_mean          | 2.65e+03     |
# | time/                   |              |
# |    fps                  | 544          |
# |    iterations           | 23           |
# |    time_elapsed         | 86           |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0054430338 |
# |    clip_fraction        | 0.0292       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.672       |
# |    explained_variance   | -2.38e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.1e+05      |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.00589     |
# |    value_loss           | 7.9e+05      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 80.1        |
# |    ep_rew_mean          | 2.61e+03    |
# | time/                   |             |
# |    fps                  | 543         |
# |    iterations           | 24          |
# |    time_elapsed         | 90          |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.003850483 |
# |    clip_fraction        | 0.0208      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.642      |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.12e+05    |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.00369    |
# |    value_loss           | 6.26e+05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 80.2        |
# |    ep_rew_mean          | 2.67e+03    |
# | time/                   |             |
# |    fps                  | 546         |
# |    iterations           | 25          |
# |    time_elapsed         | 93          |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.003371281 |
# |    clip_fraction        | 0.0352      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.67       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.78e+05    |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.00491    |
# |    value_loss           | 6.58e+05    |
# -----------------------------------------
# Logging to logs\PPO_ROUND1_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 78.9     |
# |    ep_rew_mean     | 2.91e+03 |
# | time/              |          |
# |    fps             | 609      |
# |    iterations      | 1        |
# |    time_elapsed    | 3        |
# |    total_timesteps | 104448   |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 75.9         |
# |    ep_rew_mean          | 2.91e+03     |
# | time/                   |              |
# |    fps                  | 454          |
# |    iterations           | 2            |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 106496       |
# | train/                  |              |
# |    approx_kl            | 0.0017125965 |
# |    clip_fraction        | 0.011        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.687       |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.92e+05     |
# |    n_updates            | 510          |
# |    policy_gradient_loss | -0.00434     |
# |    value_loss           | 1.51e+06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 74.1         |
# |    ep_rew_mean          | 3.04e+03     |
# | time/                   |              |
# |    fps                  | 438          |
# |    iterations           | 3            |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 108544       |
# | train/                  |              |
# |    approx_kl            | 0.0045616166 |
# |    clip_fraction        | 0.0378       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.646       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.49e+05     |
# |    n_updates            | 520          |
# |    policy_gradient_loss | -0.00708     |
# |    value_loss           | 6.85e+05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 78.3        |
# |    ep_rew_mean          | 2.85e+03    |
# | time/                   |             |
# |    fps                  | 461         |
# |    iterations           | 4           |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 110592      |
# | train/                  |             |
# |    approx_kl            | 0.002132668 |
# |    clip_fraction        | 0.0172      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.638      |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.59e+05    |
# |    n_updates            | 530         |
# |    policy_gradient_loss | -0.00223    |
# |    value_loss           | 6.98e+05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 79           |
# |    ep_rew_mean          | 2.71e+03     |
# | time/                   |              |
# |    fps                  | 488          |
# |    iterations           | 5            |
# |    time_elapsed         | 20           |
# |    total_timesteps      | 112640       |
# | train/                  |              |
# |    approx_kl            | 0.0024884234 |
# |    clip_fraction        | 0.0214       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.703       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.77e+05     |
# |    n_updates            | 540          |
# |    policy_gradient_loss | -0.00471     |
# |    value_loss           | 8.39e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 81.8         |
# |    ep_rew_mean          | 2.6e+03      |
# | time/                   |              |
# |    fps                  | 490          |
# |    iterations           | 6            |
# |    time_elapsed         | 25           |
# |    total_timesteps      | 114688       |
# | train/                  |              |
# ...
# | time/                   |             |
# |    fps                  | 586         |
# |    iterations           | 8           |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 477184      |
# | train/                  |             |
# |    approx_kl            | 0.002103442 |
# |    clip_fraction        | 0.0147      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.732      |
# |    explained_variance   | 0.0282      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.44e+05    |
# |    n_updates            | 2320        |
# |    policy_gradient_loss | -0.000671   |
# |    value_loss           | 8.41e+05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 69.7         |
# |    ep_rew_mean          | 3.14e+03     |
# | time/                   |              |
# |    fps                  | 587          |
# |    iterations           | 9            |
# |    time_elapsed         | 31           |
# |    total_timesteps      | 479232       |
# | train/                  |              |
# |    approx_kl            | 0.0029521668 |
# |    clip_fraction        | 0.0353       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.725       |
# |    explained_variance   | 0.0368       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.01e+05     |
# |    n_updates            | 2330         |
# |    policy_gradient_loss | -0.00159     |
# |    value_loss           | 7.81e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 74.4         |
# |    ep_rew_mean          | 2.99e+03     |
# | time/                   |              |
# |    fps                  | 592          |
# |    iterations           | 10           |
# |    time_elapsed         | 34           |
# |    total_timesteps      | 481280       |
# | train/                  |              |
# |    approx_kl            | 0.0042026816 |
# |    clip_fraction        | 0.0332       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.707       |
# |    explained_variance   | 0.039        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.23e+05     |
# |    n_updates            | 2340         |
# |    policy_gradient_loss | -0.00233     |
# |    value_loss           | 7.12e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 74.6         |
# |    ep_rew_mean          | 3.1e+03      |
# | time/                   |              |
# |    fps                  | 593          |
# |    iterations           | 11           |
# |    time_elapsed         | 37           |
# |    total_timesteps      | 483328       |
# | train/                  |              |
# |    approx_kl            | 0.0031391354 |
# |    clip_fraction        | 0.0218       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.73        |
# |    explained_variance   | 0.00825      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.71e+05     |
# |    n_updates            | 2350         |
# |    policy_gradient_loss | -0.000883    |
# |    value_loss           | 6.17e+05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 75.6        |
# |    ep_rew_mean          | 3.26e+03    |
# | time/                   |             |
# |    fps                  | 583         |
# |    iterations           | 12          |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 485376      |
# | train/                  |             |
# |    approx_kl            | 0.008586528 |
# |    clip_fraction        | 0.0527      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.74       |
# |    explained_variance   | 0.00551     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.08e+05    |
# |    n_updates            | 2360        |
# |    policy_gradient_loss | -0.00133    |
# |    value_loss           | 7.82e+05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 78.4        |
# |    ep_rew_mean          | 3.15e+03    |
# | time/                   |             |
# |    fps                  | 581         |
# |    iterations           | 13          |
# |    time_elapsed         | 45          |
# |    total_timesteps      | 487424      |
# | train/                  |             |
# |    approx_kl            | 0.008157647 |
# |    clip_fraction        | 0.0707      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.726      |
# |    explained_variance   | 0.00122     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.31e+05    |
# |    n_updates            | 2370        |
# |    policy_gradient_loss | -0.0023     |
# |    value_loss           | 8.53e+05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 71.8        |
# |    ep_rew_mean          | 3.37e+03    |
# | time/                   |             |
# |    fps                  | 585         |
# |    iterations           | 14          |
# |    time_elapsed         | 48          |
# |    total_timesteps      | 489472      |
# | train/                  |             |
# |    approx_kl            | 0.009590538 |
# |    clip_fraction        | 0.117       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.693      |
# |    explained_variance   | 7.96e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.18e+05    |
# |    n_updates            | 2380        |
# |    policy_gradient_loss | -0.000963   |
# |    value_loss           | 6.06e+05    |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 68.1          |
# |    ep_rew_mean          | 3.48e+03      |
# | time/                   |               |
# |    fps                  | 588           |
# |    iterations           | 15            |
# |    time_elapsed         | 52            |
# |    total_timesteps      | 491520        |
# | train/                  |               |
# |    approx_kl            | 0.00085126096 |
# |    clip_fraction        | 0.00469       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.691        |
# |    explained_variance   | 0.0225        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 8.07e+05      |
# |    n_updates            | 2390          |
# |    policy_gradient_loss | -0.00214      |
# |    value_loss           | 1.13e+06      |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 68.4        |
# |    ep_rew_mean          | 3.43e+03    |
# | time/                   |             |
# |    fps                  | 588         |
# |    iterations           | 16          |
# |    time_elapsed         | 55          |
# |    total_timesteps      | 493568      |
# | train/                  |             |
# |    approx_kl            | 0.001539061 |
# |    clip_fraction        | 0.00942     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.734      |
# |    explained_variance   | 0.0246      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.9e+05     |
# |    n_updates            | 2400        |
# |    policy_gradient_loss | -0.00331    |
# |    value_loss           | 1.14e+06    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 69.5         |
# |    ep_rew_mean          | 3.34e+03     |
# | time/                   |              |
# |    fps                  | 584          |
# |    iterations           | 17           |
# |    time_elapsed         | 59           |
# |    total_timesteps      | 495616       |
# | train/                  |              |
# |    approx_kl            | 0.0025508257 |
# |    clip_fraction        | 0.00864      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.714       |
# |    explained_variance   | 0.019        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.05e+05     |
# |    n_updates            | 2410         |
# |    policy_gradient_loss | -0.00369     |
# |    value_loss           | 6.59e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 73.7         |
# |    ep_rew_mean          | 3.14e+03     |
# | time/                   |              |
# |    fps                  | 587          |
# |    iterations           | 18           |
# |    time_elapsed         | 62           |
# |    total_timesteps      | 497664       |
# | train/                  |              |
# |    approx_kl            | 0.0043797716 |
# |    clip_fraction        | 0.0158       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.688       |
# |    explained_variance   | 0.0257       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.4e+05      |
# |    n_updates            | 2420         |
# |    policy_gradient_loss | -0.00308     |
# |    value_loss           | 6.36e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 75.9         |
# |    ep_rew_mean          | 3.12e+03     |
# | time/                   |              |
# |    fps                  | 590          |
# |    iterations           | 19           |
# |    time_elapsed         | 65           |
# |    total_timesteps      | 499712       |
# | train/                  |              |
# |    approx_kl            | 0.0024588376 |
# |    clip_fraction        | 0.014        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.716       |
# |    explained_variance   | 0.0258       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.1e+05      |
# |    n_updates            | 2430         |
# |    policy_gradient_loss | -0.00387     |
# |    value_loss           | 7.66e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 75.3         |
# |    ep_rew_mean          | 3.27e+03     |
# | time/                   |              |
# |    fps                  | 592          |
# |    iterations           | 20           |
# |    time_elapsed         | 69           |
# |    total_timesteps      | 501760       |
# | train/                  |              |
# |    approx_kl            | 0.0038574217 |
# |    clip_fraction        | 0.0271       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.695       |
# |    explained_variance   | 0.00532      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.55e+05     |
# |    n_updates            | 2440         |
# |    policy_gradient_loss | -0.000388    |
# |    value_loss           | 8.88e+05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 69.6        |
# |    ep_rew_mean          | 3.49e+03    |
# | time/                   |             |
# |    fps                  | 588         |
# |    iterations           | 21          |
# |    time_elapsed         | 73          |
# |    total_timesteps      | 503808      |
# | train/                  |             |
# |    approx_kl            | 0.009571902 |
# |    clip_fraction        | 0.102       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.69       |
# |    explained_variance   | 0.00019     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.14e+05    |
# |    n_updates            | 2450        |
# |    policy_gradient_loss | -0.00568    |
# |    value_loss           | 7.8e+05     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 68.5         |
# |    ep_rew_mean          | 3.42e+03     |
# | time/                   |              |
# |    fps                  | 585          |
# |    iterations           | 22           |
# |    time_elapsed         | 76           |
# |    total_timesteps      | 505856       |
# | train/                  |              |
# |    approx_kl            | 0.0020175232 |
# |    clip_fraction        | 0.0203       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.721       |
# |    explained_variance   | 0.00501      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.99e+05     |
# |    n_updates            | 2460         |
# |    policy_gradient_loss | -0.00272     |
# |    value_loss           | 1.08e+06     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 69          |
# |    ep_rew_mean          | 3.32e+03    |
# | time/                   |             |
# |    fps                  | 588         |
# |    iterations           | 23          |
# |    time_elapsed         | 80          |
# |    total_timesteps      | 507904      |
# | train/                  |             |
# |    approx_kl            | 0.004814394 |
# |    clip_fraction        | 0.0381      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.701      |
# |    explained_variance   | 0.00635     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.17e+05    |
# |    n_updates            | 2470        |
# |    policy_gradient_loss | -0.00302    |
# |    value_loss           | 1.02e+06    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 72           |
# |    ep_rew_mean          | 3.16e+03     |
# | time/                   |              |
# |    fps                  | 589          |
# |    iterations           | 24           |
# |    time_elapsed         | 83           |
# |    total_timesteps      | 509952       |
# | train/                  |              |
# |    approx_kl            | 0.0055429754 |
# |    clip_fraction        | 0.0325       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.693       |
# |    explained_variance   | 0.00924      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.86e+05     |
# |    n_updates            | 2480         |
# |    policy_gradient_loss | -0.00124     |
# |    value_loss           | 5.69e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 74.8         |
# |    ep_rew_mean          | 3e+03        |
# | time/                   |              |
# |    fps                  | 591          |
# |    iterations           | 25           |
# |    time_elapsed         | 86           |
# |    total_timesteps      | 512000       |
# | train/                  |              |
# |    approx_kl            | 0.0029778997 |
# |    clip_fraction        | 0.032        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.684       |
# |    explained_variance   | 0.039        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.26e+05     |
# |    n_updates            | 2490         |
# |    policy_gradient_loss | -0.00345     |
# |    value_loss           | 5.85e+05     |
# ------------------------------------------

# %% [markdown]
# ROUND 2 OF TRAINING (Add larger punishment for missing)

# %%
STEP_TURN = 20 # degrees (amt to turn per step)
HIT_BASE_REWARD = 6000
HIT_PLANE_REWARD = 6000
MISS_PUNISHMENT = -20
CLOSER_TO_BASE_REWARD = 0
CLOSER_TO_PLANE_REWARD = 0
TURN_TO_BASE_REWARD = 0
TURN_TO_PLANE_REWARD = 0

model = PPO.load(f"{models_dir}/{TIMESTEPS*R1_ITERATIONS}.zip", env=train_env)

model_name = "PPO_ROUND2"
models_dir = f"models/{model_name}"

if not os.path.exists(models_dir):
    os.makedirs(models_dir)

for i in range(R2_ITERATIONS):
    model.learn(total_timesteps=TIMESTEPS, reset_num_timesteps=False, tb_log_name=f"{model_name}")
    model.save(f"{models_dir}/{TIMESTEPS*(i+1)+(R1_ITERATIONS*TIMESTEPS)}")

del model
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to logs\PPO_ROUND2_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 74.5     |
# |    ep_rew_mean     | 2.85e+03 |
# | time/              |          |
# |    fps             | 431      |
# |    iterations      | 1        |
# |    time_elapsed    | 4        |
# |    total_timesteps | 514048   |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 77.2         |
# |    ep_rew_mean          | 2.56e+03     |
# | time/                   |              |
# |    fps                  | 518          |
# |    iterations           | 2            |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 516096       |
# | train/                  |              |
# |    approx_kl            | 0.0025006575 |
# |    clip_fraction        | 0.0223       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.703       |
# |    explained_variance   | 0.0216       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.07e+06     |
# |    n_updates            | 2510         |
# |    policy_gradient_loss | -0.00159     |
# |    value_loss           | 9.86e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 72.8         |
# |    ep_rew_mean          | 2.49e+03     |
# | time/                   |              |
# |    fps                  | 557          |
# |    iterations           | 3            |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 518144       |
# | train/                  |              |
# |    approx_kl            | 0.0065576117 |
# |    clip_fraction        | 0.0403       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.686       |
# |    explained_variance   | 0.0142       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.82e+05     |
# |    n_updates            | 2520         |
# |    policy_gradient_loss | 0.0016       |
# |    value_loss           | 8.37e+05     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 75.2        |
# |    ep_rew_mean          | 2.46e+03    |
# | time/                   |             |
# |    fps                  | 577         |
# |    iterations           | 4           |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 520192      |
# | train/                  |             |
# |    approx_kl            | 0.006158149 |
# |    clip_fraction        | 0.0381      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.697      |
# |    explained_variance   | 0.0393      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.19e+05    |
# |    n_updates            | 2530        |
# |    policy_gradient_loss | 0.001       |
# |    value_loss           | 9.2e+05     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 73           |
# |    ep_rew_mean          | 2.7e+03      |
# | time/                   |              |
# |    fps                  | 558          |
# |    iterations           | 5            |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 522240       |
# | train/                  |              |
# |    approx_kl            | 0.0018499165 |
# |    clip_fraction        | 0.0226       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.695       |
# |    explained_variance   | -0.0011      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.76e+05     |
# |    n_updates            | 2540         |
# |    policy_gradient_loss | -0.000808    |
# |    value_loss           | 1.7e+06      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 73.4         |
# |    ep_rew_mean          | 2.58e+03     |
# | time/                   |              |
# |    fps                  | 572          |
# |    iterations           | 6            |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 524288       |
# | train/                  |              |
# |    approx_kl            | 0.0081618745 |
# |    clip_fraction        | 0.029        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.693       |
# |    explained_variance   | 0.000503     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.3e+05      |
# |    n_updates            | 2550         |
# |    policy_gradient_loss | -0.004       |
# |    value_loss           | 9.91e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 73.4         |
# |    ep_rew_mean          | 2.7e+03      |
# | time/                   |              |
# |    fps                  | 581          |
# |    iterations           | 7            |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 526336       |
# | train/                  |              |
# |    approx_kl            | 0.0029672408 |
# |    clip_fraction        | 0.00923      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.684       |
# |    explained_variance   | 0.00679      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.71e+05     |
# |    n_updates            | 2560         |
# |    policy_gradient_loss | -0.00196     |
# |    value_loss           | 8.2e+05      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 73.8         |
# |    ep_rew_mean          | 2.52e+03     |
# | time/                   |              |
# |    fps                  | 588          |
# |    iterations           | 8            |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 528384       |
# | train/                  |              |
# |    approx_kl            | 0.0011702029 |
# |    clip_fraction        | 0.00874      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.721       |
# |    explained_variance   | 0.00618      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.35e+05     |
# |    n_updates            | 2570         |
# |    policy_gradient_loss | -0.00262     |
# |    value_loss           | 1.41e+06     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 73.8        |
# |    ep_rew_mean          | 2.64e+03    |
# | time/                   |             |
# |    fps                  | 590         |
# |    iterations           | 9           |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 530432      |
# | train/                  |             |
# |    approx_kl            | 0.005186081 |
# |    clip_fraction        | 0.0187      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.718      |
# |    explained_variance   | 0.00697     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.21e+05    |
# |    n_updates            | 2580        |
# |    policy_gradient_loss | -0.00264    |
# |    value_loss           | 8.96e+05    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 70.9       |
# |    ep_rew_mean          | 2.94e+03   |
# | time/                   |            |
# |    fps                  | 584        |
# |    iterations           | 10         |
# |    time_elapsed         | 35         |
# |    total_timesteps      | 532480     |
# | train/                  |            |
# |    approx_kl            | 0.00235744 |
# |    clip_fraction        | 0.0138     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.701     |
# |    explained_variance   | 0.0048     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 6.55e+05   |
# |    n_updates            | 2590       |
# |    policy_gradient_loss | -3.12e-05  |
# |    value_loss           | 1.25e+06   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 73          |
# |    ep_rew_mean          | 2.64e+03    |
# | time/                   |             |
# |    fps                  | 590         |
# |    iterations           | 11          |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 534528      |
# | train/                  |             |
# |    approx_kl            | 0.004436075 |
# |    clip_fraction        | 0.0232      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.688      |
# |    explained_variance   | 0.00717     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.06e+06    |
# |    n_updates            | 2600        |
# |    policy_gradient_loss | -0.00152    |
# |    value_loss           | 1.36e+06    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 71.2         |
# |    ep_rew_mean          | 3e+03        |
# | time/                   |              |
# |    fps                  | 592          |
# |    iterations           | 12           |
# |    time_elapsed         | 41           |
# |    total_timesteps      | 536576       |
# | train/                  |              |
# |    approx_kl            | 0.0020913794 |
# |    clip_fraction        | 0.00576      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.698       |
# |    explained_variance   | 0.00528      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.71e+05     |
# |    n_updates            | 2610         |
# |    policy_gradient_loss | -0.00293     |
# |    value_loss           | 1.09e+06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 69.9         |
# |    ep_rew_mean          | 2.82e+03     |
# | time/                   |              |
# |    fps                  | 597          |
# |    iterations           | 13           |
# |    time_elapsed         | 44           |
# |    total_timesteps      | 538624       |
# | train/                  |              |
# |    approx_kl            | 0.0067283283 |
# |    clip_fraction        | 0.0442       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.711       |
# |    explained_variance   | -0.00261     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.09e+06     |
# |    n_updates            | 2620         |
# |    policy_gradient_loss | -0.00171     |
# |    value_loss           | 1.21e+06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 68           |
# |    ep_rew_mean          | 3.06e+03     |
# | time/                   |              |
# |    fps                  | 592          |
# |    iterations           | 14           |
# |    time_elapsed         | 48           |
# |    total_timesteps      | 540672       |
# | train/                  |              |
# |    approx_kl            | 0.0061197467 |
# |    clip_fraction        | 0.0642       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.706       |
# |    explained_variance   | 0.000369     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.35e+06     |
# |    n_updates            | 2630         |
# |    policy_gradient_loss | -0.000709    |
# |    value_loss           | 1.4e+06      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 65.1        |
# |    ep_rew_mean          | 3.18e+03    |
# | time/                   |             |
# |    fps                  | 592         |
# |    iterations           | 15          |
# |    time_elapsed         | 51          |
# |    total_timesteps      | 542720      |
# | train/                  |             |
# |    approx_kl            | 0.011435339 |
# |    clip_fraction        | 0.0709      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.687      |
# |    explained_variance   | 0.0017      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.24e+06    |
# |    n_updates            | 2640        |
# |    policy_gradient_loss | -0.00166    |
# |    value_loss           | 1.59e+06    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 68.3        |
# |    ep_rew_mean          | 2.94e+03    |
# | time/                   |             |
# |    fps                  | 594         |
# |    iterations           | 16          |
# |    time_elapsed         | 55          |
# |    total_timesteps      | 544768      |
# | train/                  |             |
# |    approx_kl            | 0.010398136 |
# |    clip_fraction        | 0.121       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.687      |
# |    explained_variance   | 3.55e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.74e+05    |
# |    n_updates            | 2650        |
# |    policy_gradient_loss | -0.00335    |
# |    value_loss           | 1.35e+06    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 75          |
# |    ep_rew_mean          | 2.58e+03    |
# | time/                   |             |
# |    fps                  | 597         |
# |    iterations           | 17          |
# |    time_elapsed         | 58          |
# |    total_timesteps      | 546816      |
# | train/                  |             |
# |    approx_kl            | 0.009816262 |
# |    clip_fraction        | 0.0833      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.696      |
# |    explained_variance   | 2.86e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.93e+05    |
# |    n_updates            | 2660        |
# |    policy_gradient_loss | -0.00477    |
# |    value_loss           | 7.93e+05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 74           |
# |    ep_rew_mean          | 2.7e+03      |
# | time/                   |              |
# |    fps                  | 600          |
# |    iterations           | 18           |
# |    time_elapsed         | 61           |
# |    total_timesteps      | 548864       |
# | train/                  |              |
# |    approx_kl            | 0.0033295532 |
# |    clip_fraction        | 0.00742      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.71        |
# |    explained_variance   | 0.00952      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.32e+05     |
# |    n_updates            | 2670         |
# |    policy_gradient_loss | -0.00192     |
# |    value_loss           | 1.07e+06     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 76          |
# |    ep_rew_mean          | 2.58e+03    |
# | time/                   |             |
# |    fps                  | 593         |
# |    iterations           | 19          |
# |    time_elapsed         | 65          |
# |    total_timesteps      | 550912      |
# | train/                  |             |
# |    approx_kl            | 0.013287108 |
# |    clip_fraction        | 0.0604      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.693      |
# |    explained_variance   | 0.00174     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.92e+05    |
# |    n_updates            | 2680        |
# |    policy_gradient_loss | -0.00073    |
# |    value_loss           | 1.42e+06    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 75.8        |
# |    ep_rew_mean          | 2.64e+03    |
# | time/                   |             |
# |    fps                  | 595         |
# |    iterations           | 20          |
# |    time_elapsed         | 68          |
# |    total_timesteps      | 552960      |
# | train/                  |             |
# |    approx_kl            | 0.005483171 |
# |    clip_fraction        | 0.108       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.707      |
# |    explained_variance   | 2.02e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.86e+05    |
# |    n_updates            | 2690        |
# |    policy_gradient_loss | -0.00144    |
# |    value_loss           | 1.03e+06    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 77.1        |
# |    ep_rew_mean          | 2.58e+03    |
# | time/                   |             |
# |    fps                  | 597         |
# |    iterations           | 21          |
# |    time_elapsed         | 72          |
# |    total_timesteps      | 555008      |
# | train/                  |             |
# |    approx_kl            | 0.007559822 |
# |    clip_fraction        | 0.0266      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.71       |
# |    explained_variance   | 8.32e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.05e+06    |
# |    n_updates            | 2700        |
# |    policy_gradient_loss | -0.0045     |
# |    value_loss           | 1.12e+06    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 77.2         |
# |    ep_rew_mean          | 2.46e+03     |
# | time/                   |              |
# |    fps                  | 599          |
# |    iterations           | 22           |
# |    time_elapsed         | 75           |
# |    total_timesteps      | 557056       |
# | train/                  |              |
# |    approx_kl            | 0.0013610525 |
# |    clip_fraction        | 0.0019       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.7         |
# |    explained_variance   | 0.00246      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.19e+05     |
# |    n_updates            | 2710         |
# |    policy_gradient_loss | -0.00208     |
# |    value_loss           | 1.07e+06     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 73.6          |
# |    ep_rew_mean          | 2.82e+03      |
# | time/                   |               |
# |    fps                  | 600           |
# |    iterations           | 23            |
# |    time_elapsed         | 78            |
# |    total_timesteps      | 559104        |
# | train/                  |               |
# |    approx_kl            | 0.00029206625 |
# |    clip_fraction        | 0.00176       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.71         |
# |    explained_variance   | 0.00232       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 8.1e+05       |
# |    n_updates            | 2720          |
# |    policy_gradient_loss | -0.00139      |
# |    value_loss           | 1.01e+06      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 77.5         |
# |    ep_rew_mean          | 2.58e+03     |
# | time/                   |              |
# |    fps                  | 595          |
# |    iterations           | 24           |
# |    time_elapsed         | 82           |
# |    total_timesteps      | 561152       |
# | train/                  |              |
# |    approx_kl            | 0.0007829602 |
# |    clip_fraction        | 0.00366      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.707       |
# |    explained_variance   | 0.00597      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.7e+05      |
# |    n_updates            | 2730         |
# |    policy_gradient_loss | -0.00112     |
# |    value_loss           | 1.42e+06     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 77.2          |
# |    ep_rew_mean          | 2.64e+03      |
# | time/                   |               |
# |    fps                  | 597           |
# |    iterations           | 25            |
# |    time_elapsed         | 85            |
# |    total_timesteps      | 563200        |
# | train/                  |               |
# |    approx_kl            | 0.00064476044 |
# |    clip_fraction        | 0.0042        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.687        |
# |    explained_variance   | 0.000589      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.13e+05      |
# |    n_updates            | 2740          |
# |    policy_gradient_loss | -0.00151      |
# |    value_loss           | 8.63e+05      |
# -------------------------------------------
# Logging to logs\PPO_ROUND2_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 74.9     |
# |    ep_rew_mean     | 2.76e+03 |
# | time/              |          |
# |    fps             | 651      |
# |    iterations      | 1        |
# |    time_elapsed    | 3        |
# |    total_timesteps | 565248   |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 75.8         |
# |    ep_rew_mean          | 2.52e+03     |
# | time/                   |              |
# |    fps                  | 651          |
# |    iterations           | 2            |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 567296       |
# | train/                  |              |
# |    approx_kl            | 0.0041204616 |
# |    clip_fraction        | 0.0211       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.69        |
# |    explained_variance   | 0.000957     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.9e+05      |
# |    n_updates            | 2760         |
# |    policy_gradient_loss | -0.00243     |
# |    value_loss           | 1.38e+06     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 71.4        |
# |    ep_rew_mean          | 2.82e+03    |
# | time/                   |             |
# |    fps                  | 588         |
# |    iterations           | 3           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 569344      |
# | train/                  |             |
# |    approx_kl            | 0.002920641 |
# |    clip_fraction        | 0.041       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.677      |
# |    explained_variance   | 3.68e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.37e+05    |
# |    n_updates            | 2770        |
# |    policy_gradient_loss | -0.00282    |
# |    value_loss           | 7.17e+05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 72.9         |
# |    ep_rew_mean          | 2.82e+03     |
# | time/                   |              |
# |    fps                  | 604          |
# |    iterations           | 4            |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 571392       |
# | train/                  |              |
# |    approx_kl            | 0.0004066026 |
# |    clip_fraction        | 0.00083      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.69        |
# |    explained_variance   | 0.00648      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.01e+05     |
# |    n_updates            | 2780         |
# |    policy_gradient_loss | -0.00132     |
# |    value_loss           | 1.36e+06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 72           |
# |    ep_rew_mean          | 3.06e+03     |
# | time/                   |              |
# |    fps                  | 614          |
# |    iterations           | 5            |
# |    time_elapsed         | 16           |
# |    total_timesteps      | 573440       |
# | train/                  |              |
# |    approx_kl            | 0.0009628968 |
# |    clip_fraction        | 0.00122      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.682       |
# |    explained_variance   | 0.00222      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.53e+05     |
# |    n_updates            | 2790         |
# |    policy_gradient_loss | -0.000868    |
# |    value_loss           | 1.18e+06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 72.1         |
# |    ep_rew_mean          | 3.06e+03     |
# | time/                   |              |
# |    fps                  | 623          |
# |    iterations           | 6            |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 575488       |
# | train/                  |              |
# |    approx_kl            | 0.0033869923 |
# |    clip_fraction        | 0.0312       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.659       |
# |    explained_variance   | 0.00193      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.13e+06     |
# |    n_updates            | 2800         |
# |    policy_gradient_loss | -0.00253     |
# |    value_loss           | 1.78e+06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 70.2         |
# |    ep_rew_mean          | 3.24e+03     |
# | time/                   |              |
# |    fps                  | 627          |
# |    iterations           | 7            |
# |    time_elapsed         | 22           |
# |    total_timesteps      | 577536       |
# | train/                  |              |
# |    approx_kl            | 0.0010973585 |
# |    clip_fraction        | 0.00801      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.679       |
# |    explained_variance   | 0.00012      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.92e+05     |
# |    n_updates            | 2810         |
# |    policy_gradient_loss | -0.00237     |
# |    value_loss           | 9.54e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 71.2         |
# |    ep_rew_mean          | 2.94e+03     |
# | time/                   |              |
# |    fps                  | 603          |
# |    iterations           | 8            |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 579584       |
# | train/                  |              |
# |    approx_kl            | 0.0013776775 |
# |    clip_fraction        | 0.00684      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.695       |
# |    explained_variance   | 0.00524      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.2e+06      |
# |    n_updates            | 2820         |
# |    policy_gradient_loss | -0.000894    |
# |    value_loss           | 1.42e+06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 69.9         |
# |    ep_rew_mean          | 3e+03        |
# | time/                   |              |
# |    fps                  | 608          |
# |    iterations           | 9            |
# |    time_elapsed         | 30           |
# |    total_timesteps      | 581632       |
# | train/                  |              |
# |    approx_kl            | 0.0016862347 |
# |    clip_fraction        | 0.00439      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.684       |
# |    explained_variance   | 0.00152      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.91e+05     |
# |    n_updates            | 2830         |
# |    policy_gradient_loss | -0.00174     |
# |    value_loss           | 9.38e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 74.6         |
# |    ep_rew_mean          | 2.64e+03     |
# | time/                   |              |
# |    fps                  | 613          |
# |    iterations           | 10           |
# |    time_elapsed         | 33           |
# |    total_timesteps      | 583680       |
# | train/                  |              |
# |    approx_kl            | 0.0020218631 |
# |    clip_fraction        | 0.00791      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.671       |
# |    explained_variance   | 0.00887      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.17e+05     |
# |    n_updates            | 2840         |
# |    policy_gradient_loss | -0.00234     |
# |    value_loss           | 1.45e+06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 75.1         |
# |    ep_rew_mean          | 2.46e+03     |
# | time/                   |              |
# |    fps                  | 612          |
# |    iterations           | 11           |
# |    time_elapsed         | 36           |
# |    total_timesteps      | 585728       |
# | train/                  |              |
# |    approx_kl            | 0.0034634161 |
# |    clip_fraction        | 0.0184       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.686       |
# |    explained_variance   | 0.00163      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.56e+05     |
# |    n_updates            | 2850         |
# |    policy_gradient_loss | -0.00226     |
# |    value_loss           | 7.21e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 74.3         |
# |    ep_rew_mean          | 2.46e+03     |
# | time/                   |              |
# |    fps                  | 610          |
# |    iterations           | 12           |
# |    time_elapsed         | 40           |
# |    total_timesteps      | 587776       |
# | train/                  |              |
# |    approx_kl            | 0.0072598113 |
# |    clip_fraction        | 0.0287       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.699       |
# |    explained_variance   | 0.00656      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.42e+05     |
# |    n_updates            | 2860         |
# |    policy_gradient_loss | -0.00609     |
# |    value_loss           | 1.16e+06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 74.8         |
# |    ep_rew_mean          | 2.4e+03      |
# | time/                   |              |
# |    fps                  | 605          |
# |    iterations           | 13           |
# |    time_elapsed         | 43           |
# |    total_timesteps      | 589824       |
# | train/                  |              |
# |    approx_kl            | 0.0018976752 |
# |    clip_fraction        | 0.0136       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.678       |
# |    explained_variance   | 0.00905      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.89e+05     |
# |    n_updates            | 2870         |
# |    policy_gradient_loss | -0.00478     |
# |    value_loss           | 1.05e+06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 76.5         |
# |    ep_rew_mean          | 2.34e+03     |
# | time/                   |              |
# |    fps                  | 608          |
# |    iterations           | 14           |
# |    time_elapsed         | 47           |
# |    total_timesteps      | 591872       |
# | train/                  |              |
# |    approx_kl            | 0.0015144347 |
# |    clip_fraction        | 0.0209       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.683       |
# |    explained_variance   | 0.00764      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.76e+05     |
# |    n_updates            | 2880         |
# |    policy_gradient_loss | -0.00249     |
# |    value_loss           | 1.04e+06     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 77          |
# |    ep_rew_mean          | 2.46e+03    |
# | time/                   |             |
# |    fps                  | 611         |
# |    iterations           | 15          |
# |    time_elapsed         | 50          |
# |    total_timesteps      | 593920      |
# | train/                  |             |
# |    approx_kl            | 0.009886185 |
# |    clip_fraction        | 0.0787      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.697      |
# |    explained_variance   | 0.00294     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.54e+05    |
# |    n_updates            | 2890        |
# |    policy_gradient_loss | -0.000662   |
# |    value_loss           | 7.28e+05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 77.2         |
# |    ep_rew_mean          | 2.46e+03     |
# | time/                   |              |
# |    fps                  | 614          |
# |    iterations           | 16           |
# |    time_elapsed         | 53           |
# |    total_timesteps      | 595968       |
# | train/                  |              |
# |    approx_kl            | 0.0037640047 |
# |    clip_fraction        | 0.0125       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.678       |
# |    explained_variance   | 0.00329      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.68e+05     |
# |    n_updates            | 2900         |
# |    policy_gradient_loss | -0.00205     |
# |    value_loss           | 1.38e+06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 75.5         |
# |    ep_rew_mean          | 2.58e+03     |
# | time/                   |              |
# |    fps                  | 603          |
# |    iterations           | 17           |
# |    time_elapsed         | 57           |
# |    total_timesteps      | 598016       |
# | train/                  |              |
# |    approx_kl            | 0.0015589448 |
# |    clip_fraction        | 0.00718      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.693       |
# |    explained_variance   | 0.00976      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.34e+05     |
# |    n_updates            | 2910         |
# |    policy_gradient_loss | -0.00139     |
# |    value_loss           | 1.03e+06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 72.5         |
# |    ep_rew_mean          | 2.76e+03     |
# | time/                   |              |
# |    fps                  | 603          |
# |    iterations           | 18           |
# |    time_elapsed         | 61           |
# |    total_timesteps      | 600064       |
# | train/                  |              |
# |    approx_kl            | 0.0040963935 |
# |    clip_fraction        | 0.00664      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.687       |
# |    explained_variance   | -0.00328     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.79e+05     |
# |    n_updates            | 2920         |
# |    policy_gradient_loss | -0.00394     |
# |    value_loss           | 1.3e+06      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 74.5         |
# |    ep_rew_mean          | 2.4e+03      |
# | time/                   |              |
# |    fps                  | 606          |
# |    iterations           | 19           |
# |    time_elapsed         | 64           |
# |    total_timesteps      | 602112       |
# | train/                  |              |
# |    approx_kl            | 0.0025278763 |
# |    clip_fraction        | 0.0161       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.682       |
# |    explained_variance   | 0.0142       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.05e+05     |
# |    n_updates            | 2930         |
# |    policy_gradient_loss | -0.00283     |
# |    value_loss           | 9.46e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 76.4         |
# |    ep_rew_mean          | 2.28e+03     |
# | time/                   |              |
# |    fps                  | 606          |
# |    iterations           | 20           |
# |    time_elapsed         | 67           |
# |    total_timesteps      | 604160       |
# | train/                  |              |
# |    approx_kl            | 0.0074304873 |
# |    clip_fraction        | 0.0635       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.682       |
# |    explained_variance   | 0.000679     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.97e+05     |
# |    n_updates            | 2940         |
# |    policy_gradient_loss | -0.00219     |
# |    value_loss           | 8.8e+05      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 74.8         |
# |    ep_rew_mean          | 2.34e+03     |
# | time/                   |              |
# |    fps                  | 597          |
# |    iterations           | 21           |
# |    time_elapsed         | 71           |
# |    total_timesteps      | 606208       |
# | train/                  |              |
# |    approx_kl            | 0.0009663878 |
# |    clip_fraction        | 0.00269      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.697       |
# |    explained_variance   | 0.00381      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.74e+05     |
# |    n_updates            | 2950         |
# |    policy_gradient_loss | -0.00107     |
# |    value_loss           | 1.09e+06     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 76.9        |
# |    ep_rew_mean          | 2.28e+03    |
# | time/                   |             |
# |    fps                  | 590         |
# |    iterations           | 22          |
# |    time_elapsed         | 76          |
# |    total_timesteps      | 608256      |
# | train/                  |             |
# |    approx_kl            | 0.002799862 |
# |    clip_fraction        | 0.0151      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.696      |
# |    explained_variance   | 0.0102      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.27e+05    |
# |    n_updates            | 2960        |
# |    policy_gradient_loss | -0.00279    |
# |    value_loss           | 9.05e+05    |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 75.4          |
# |    ep_rew_mean          | 2.46e+03      |
# | time/                   |               |
# |    fps                  | 592           |
# |    iterations           | 23            |
# |    time_elapsed         | 79            |
# |    total_timesteps      | 610304        |
# | train/                  |               |
# |    approx_kl            | 0.00094738044 |
# |    clip_fraction        | 0.0107        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.704        |
# |    explained_variance   | 0.00451       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.1e+05       |
# |    n_updates            | 2970          |
# |    policy_gradient_loss | -0.00102      |
# |    value_loss           | 9.57e+05      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 76.1         |
# |    ep_rew_mean          | 2.46e+03     |
# | time/                   |              |
# |    fps                  | 595          |
# |    iterations           | 24           |
# |    time_elapsed         | 82           |
# |    total_timesteps      | 612352       |
# | train/                  |              |
# |    approx_kl            | 0.0017537721 |
# |    clip_fraction        | 0.0112       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.684       |
# |    explained_variance   | 0.0133       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.87e+05     |
# |    n_updates            | 2980         |
# |    policy_gradient_loss | -0.00156     |
# |    value_loss           | 1.09e+06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 69.5         |
# |    ep_rew_mean          | 2.94e+03     |
# | time/                   |              |
# |    fps                  | 597          |
# |    iterations           | 25           |
# |    time_elapsed         | 85           |
# |    total_timesteps      | 614400       |
# | train/                  |              |
# |    approx_kl            | 0.0007870747 |
# |    clip_fraction        | 0.00527      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.712       |
# |    explained_variance   | 0.00698      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.06e+05     |
# |    n_updates            | 2990         |
# |    policy_gradient_loss | -0.0014      |
# |    value_loss           | 1.21e+06     |
# ------------------------------------------
# Logging to logs\PPO_ROUND2_0
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 68.5     |
# |    ep_rew_mean     | 3.24e+03 |
# | time/              |          |
# |    fps             | 510      |
# |    iterations      | 1        |
# |    time_elapsed    | 4        |
# |    total_timesteps | 616448   |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 65          |
# |    ep_rew_mean          | 3.36e+03    |
# | time/                   |             |
# |    fps                  | 550         |
# |    iterations           | 2           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 618496      |
# | train/                  |             |
# |    approx_kl            | 0.010086764 |
# |    clip_fraction        | 0.115       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.694      |
# |    explained_variance   | -7.52e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.19e+05    |
# |    n_updates            | 3010        |
# |    policy_gradient_loss | 0.00263     |
# |    value_loss           | 1.3e+06     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 70.7       |
# |    ep_rew_mean          | 2.94e+03   |
# | time/                   |            |
# |    fps                  | 582        |
# |    iterations           | 3          |
# |    time_elapsed         | 10         |
# |    total_timesteps      | 620544     |
# | train/                  |            |
# |    approx_kl            | 0.00625601 |
# |    clip_fraction        | 0.0855     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.724     |
# |    explained_variance   | -1.07e-06  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 7.48e+05   |
# |    n_updates            | 3020       |
# |    policy_gradient_loss | -0.00253   |
# |    value_loss           | 1.27e+06   |
# ----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 73            |
# |    ep_rew_mean          | 2.7e+03       |
# | time/                   |               |
# |    fps                  | 599           |
# |    iterations           | 4             |
# |    time_elapsed         | 13            |
# |    total_timesteps      | 622592        |
# | train/                  |               |
# |    approx_kl            | 0.00087564334 |
# |    clip_fraction        | 0.0041        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.729        |
# |    explained_variance   | 0.00156       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.29e+05      |
# |    n_updates            | 3030          |
# |    policy_gradient_loss | -0.00221      |
# |    value_loss           | 8.13e+05      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 72           |
# |    ep_rew_mean          | 2.76e+03     |
# | time/                   |              |
# |    fps                  | 586          |
# |    iterations           | 5            |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 624640       |
# | train/                  |              |
# |    approx_kl            | 0.0049772807 |
# |    clip_fraction        | 0.0061       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.723       |
# |    explained_variance   | 0.00435      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.88e+05     |
# |    n_updates            | 3040         |
# |    policy_gradient_loss | -0.00263     |
# |    value_loss           | 1.05e+06     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 74.5        |
# ...
# | time/                   |              |
# |    fps                  | 585          |
# |    iterations           | 8            |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 989184       |
# | train/                  |              |
# |    approx_kl            | 0.0006440011 |
# |    clip_fraction        | 0.00371      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.696       |
# |    explained_variance   | 0.0068       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.34e+05     |
# |    n_updates            | 4820         |
# |    policy_gradient_loss | -0.00187     |
# |    value_loss           | 1.19e+06     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 74.8        |
# |    ep_rew_mean          | 2.58e+03    |
# | time/                   |             |
# |    fps                  | 590         |
# |    iterations           | 9           |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 991232      |
# | train/                  |             |
# |    approx_kl            | 0.005411721 |
# |    clip_fraction        | 0.0252      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.696      |
# |    explained_variance   | 0.000169    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.41e+05    |
# |    n_updates            | 4830        |
# |    policy_gradient_loss | -0.00157    |
# |    value_loss           | 6.67e+05    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 72.8         |
# |    ep_rew_mean          | 2.88e+03     |
# | time/                   |              |
# |    fps                  | 596          |
# |    iterations           | 10           |
# |    time_elapsed         | 34           |
# |    total_timesteps      | 993280       |
# | train/                  |              |
# |    approx_kl            | 0.0023922664 |
# |    clip_fraction        | 0.0133       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.674       |
# |    explained_variance   | 0.0018       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.41e+05     |
# |    n_updates            | 4840         |
# |    policy_gradient_loss | -0.00118     |
# |    value_loss           | 1.27e+06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 75.2         |
# |    ep_rew_mean          | 2.7e+03      |
# | time/                   |              |
# |    fps                  | 598          |
# |    iterations           | 11           |
# |    time_elapsed         | 37           |
# |    total_timesteps      | 995328       |
# | train/                  |              |
# |    approx_kl            | 0.0014785363 |
# |    clip_fraction        | 0.0143       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.694       |
# |    explained_variance   | -0.000618    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.95e+05     |
# |    n_updates            | 4850         |
# |    policy_gradient_loss | -0.00144     |
# |    value_loss           | 1.24e+06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 70           |
# |    ep_rew_mean          | 2.94e+03     |
# | time/                   |              |
# |    fps                  | 592          |
# |    iterations           | 12           |
# |    time_elapsed         | 41           |
# |    total_timesteps      | 997376       |
# | train/                  |              |
# |    approx_kl            | 0.0027650148 |
# |    clip_fraction        | 0.0222       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.699       |
# |    explained_variance   | 0.000936     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.06e+05     |
# |    n_updates            | 4860         |
# |    policy_gradient_loss | -0.00229     |
# |    value_loss           | 1.1e+06      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 70.5        |
# |    ep_rew_mean          | 2.94e+03    |
# | time/                   |             |
# |    fps                  | 587         |
# |    iterations           | 13          |
# |    time_elapsed         | 45          |
# |    total_timesteps      | 999424      |
# | train/                  |             |
# |    approx_kl            | 0.002691731 |
# |    clip_fraction        | 0.015       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.67       |
# |    explained_variance   | 0.00358     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.24e+05    |
# |    n_updates            | 4870        |
# |    policy_gradient_loss | -0.00289    |
# |    value_loss           | 1.29e+06    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 76           |
# |    ep_rew_mean          | 2.52e+03     |
# | time/                   |              |
# |    fps                  | 591          |
# |    iterations           | 14           |
# |    time_elapsed         | 48           |
# |    total_timesteps      | 1001472      |
# | train/                  |              |
# |    approx_kl            | 0.0026253415 |
# |    clip_fraction        | 0.0163       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.684       |
# |    explained_variance   | 5.44e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.05e+05     |
# |    n_updates            | 4880         |
# |    policy_gradient_loss | -0.000834    |
# |    value_loss           | 1.12e+06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 76.4         |
# |    ep_rew_mean          | 2.46e+03     |
# | time/                   |              |
# |    fps                  | 593          |
# |    iterations           | 15           |
# |    time_elapsed         | 51           |
# |    total_timesteps      | 1003520      |
# | train/                  |              |
# |    approx_kl            | 0.0120586455 |
# |    clip_fraction        | 0.0703       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.668       |
# |    explained_variance   | 0.00164      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.6e+05      |
# |    n_updates            | 4890         |
# |    policy_gradient_loss | -0.00327     |
# |    value_loss           | 5.49e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 77.4         |
# |    ep_rew_mean          | 2.4e+03      |
# | time/                   |              |
# |    fps                  | 597          |
# |    iterations           | 16           |
# |    time_elapsed         | 54           |
# |    total_timesteps      | 1005568      |
# | train/                  |              |
# |    approx_kl            | 0.0024795446 |
# |    clip_fraction        | 0.0169       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.676       |
# |    explained_variance   | 0.00459      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.42e+06     |
# |    n_updates            | 4900         |
# |    policy_gradient_loss | -0.00159     |
# |    value_loss           | 1.19e+06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 78           |
# |    ep_rew_mean          | 2.34e+03     |
# | time/                   |              |
# |    fps                  | 589          |
# |    iterations           | 17           |
# |    time_elapsed         | 59           |
# |    total_timesteps      | 1007616      |
# | train/                  |              |
# |    approx_kl            | 0.0028967515 |
# |    clip_fraction        | 0.0147       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.679       |
# |    explained_variance   | 0.00645      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.36e+05     |
# |    n_updates            | 4910         |
# |    policy_gradient_loss | -0.00198     |
# |    value_loss           | 1.17e+06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 72.1         |
# |    ep_rew_mean          | 2.82e+03     |
# | time/                   |              |
# |    fps                  | 592          |
# |    iterations           | 18           |
# |    time_elapsed         | 62           |
# |    total_timesteps      | 1009664      |
# | train/                  |              |
# |    approx_kl            | 0.0043419087 |
# |    clip_fraction        | 0.028        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.677       |
# |    explained_variance   | 0.00287      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.6e+05      |
# |    n_updates            | 4920         |
# |    policy_gradient_loss | -0.00155     |
# |    value_loss           | 9.45e+05     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 72.7         |
# |    ep_rew_mean          | 2.88e+03     |
# | time/                   |              |
# |    fps                  | 595          |
# |    iterations           | 19           |
# |    time_elapsed         | 65           |
# |    total_timesteps      | 1011712      |
# | train/                  |              |
# |    approx_kl            | 0.0016296329 |
# |    clip_fraction        | 0.0135       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.673       |
# |    explained_variance   | 0.000349     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.07e+05     |
# |    n_updates            | 4930         |
# |    policy_gradient_loss | -0.00225     |
# |    value_loss           | 1.3e+06      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 74.7         |
# |    ep_rew_mean          | 2.58e+03     |
# | time/                   |              |
# |    fps                  | 598          |
# |    iterations           | 20           |
# |    time_elapsed         | 68           |
# |    total_timesteps      | 1013760      |
# | train/                  |              |
# |    approx_kl            | 0.0022294756 |
# |    clip_fraction        | 0.0118       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.678       |
# |    explained_variance   | -0.00176     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.8e+05      |
# |    n_updates            | 4940         |
# |    policy_gradient_loss | -0.00143     |
# |    value_loss           | 1.15e+06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 73.2         |
# |    ep_rew_mean          | 2.76e+03     |
# | time/                   |              |
# |    fps                  | 600          |
# |    iterations           | 21           |
# |    time_elapsed         | 71           |
# |    total_timesteps      | 1015808      |
# | train/                  |              |
# |    approx_kl            | 0.0031877363 |
# |    clip_fraction        | 0.0226       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.685       |
# |    explained_variance   | -0.00252     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.51e+05     |
# |    n_updates            | 4950         |
# |    policy_gradient_loss | -0.00305     |
# |    value_loss           | 1.08e+06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 73           |
# |    ep_rew_mean          | 2.82e+03     |
# | time/                   |              |
# |    fps                  | 592          |
# |    iterations           | 22           |
# |    time_elapsed         | 76           |
# |    total_timesteps      | 1017856      |
# | train/                  |              |
# |    approx_kl            | 0.0023952206 |
# |    clip_fraction        | 0.0219       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.69        |
# |    explained_variance   | 0.00168      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.93e+05     |
# |    n_updates            | 4960         |
# |    policy_gradient_loss | -0.00145     |
# |    value_loss           | 1.16e+06     |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 73.8       |
# |    ep_rew_mean          | 2.76e+03   |
# | time/                   |            |
# |    fps                  | 594        |
# |    iterations           | 23         |
# |    time_elapsed         | 79         |
# |    total_timesteps      | 1019904    |
# | train/                  |            |
# |    approx_kl            | 0.00168655 |
# |    clip_fraction        | 0.0129     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.672     |
# |    explained_variance   | 0.00546    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 7.05e+05   |
# |    n_updates            | 4970       |
# |    policy_gradient_loss | -0.000963  |
# |    value_loss           | 1.17e+06   |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 76.2         |
# |    ep_rew_mean          | 2.7e+03      |
# | time/                   |              |
# |    fps                  | 596          |
# |    iterations           | 24           |
# |    time_elapsed         | 82           |
# |    total_timesteps      | 1021952      |
# | train/                  |              |
# |    approx_kl            | 0.0022671528 |
# |    clip_fraction        | 0.0315       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.675       |
# |    explained_variance   | -0.022       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.38e+05     |
# |    n_updates            | 4980         |
# |    policy_gradient_loss | -0.00162     |
# |    value_loss           | 1.12e+06     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 78           |
# |    ep_rew_mean          | 2.46e+03     |
# | time/                   |              |
# |    fps                  | 598          |
# |    iterations           | 25           |
# |    time_elapsed         | 85           |
# |    total_timesteps      | 1024000      |
# | train/                  |              |
# |    approx_kl            | 0.0018010703 |
# |    clip_fraction        | 0.0173       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.693       |
# |    explained_variance   | -4.79e-05    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.53e+05     |
# |    n_updates            | 4990         |
# |    policy_gradient_loss | -0.00166     |
# |    value_loss           | 8.48e+05     |
# ------------------------------------------

# %% [markdown]
# EVALUATION OF 100 GAMES

# %%
eval_env = BattleEnvironment(False)

model = PPO.load(f"{models_dir}/{TIMESTEPS*R1_ITERATIONS + TIMESTEPS*R2_ITERATIONS}.zip", env=eval_env) # Loads the saved model

episodes = 100
for episode in range(episodes): # Evaluates the model n times
    state = eval_env.reset()
    score = 0
    while not eval_env.done:
        action, _states = model.predict(state)
        n_state, red_reward, done, info = eval_env.step(action)
        score += red_reward
    print('Episode:{} Score:{}'.format(episode+1, score))

eval_env.show_wins()
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Episode:1 Score:6000
# Episode:2 Score:0
# Episode:3 Score:0
# Episode:4 Score:0
# Episode:5 Score:6000
# Episode:6 Score:0
# Episode:7 Score:0
# Episode:8 Score:0
# Episode:9 Score:6000
# Episode:10 Score:6000
# Episode:11 Score:6000
# Episode:12 Score:0
# Episode:13 Score:6000
# Episode:14 Score:6000
# Episode:15 Score:0
# Episode:16 Score:0
# Episode:17 Score:0
# Episode:18 Score:0
# Episode:19 Score:0
# Episode:20 Score:0
# Episode:21 Score:0
# Episode:22 Score:6000
# Episode:23 Score:0
# Episode:24 Score:0
# Episode:25 Score:6000
# Episode:26 Score:0
# Episode:27 Score:0
# Episode:28 Score:0
# Episode:29 Score:0
# Episode:30 Score:6000
# Episode:31 Score:0
# Episode:32 Score:0
# Episode:33 Score:0
# Episode:34 Score:0
# Episode:35 Score:0
# Episode:36 Score:0
# Episode:37 Score:0
# Episode:38 Score:0
# Episode:39 Score:0
# Episode:40 Score:6000
# Episode:41 Score:0
# Episode:42 Score:6000
# Episode:43 Score:6000
# Episode:44 Score:0
# Episode:45 Score:6000
# Episode:46 Score:0
# Episode:47 Score:6000
# Episode:48 Score:6000
# Episode:49 Score:0
# Episode:50 Score:0
# Episode:51 Score:0
# Episode:52 Score:6000
# Episode:53 Score:0
# Episode:54 Score:6000
# Episode:55 Score:6000
# Episode:56 Score:0
# Episode:57 Score:0
# Episode:58 Score:0
# Episode:59 Score:0
# Episode:60 Score:0
# Episode:61 Score:0
# Episode:62 Score:0
# Episode:63 Score:0
# Episode:64 Score:6000
# Episode:65 Score:6000
# Episode:66 Score:0
# Episode:67 Score:0
# Episode:68 Score:6000
# Episode:69 Score:0
# Episode:70 Score:6000
# Episode:71 Score:0
# Episode:72 Score:0
# Episode:73 Score:0
# Episode:74 Score:0
# Episode:75 Score:6000
# Episode:76 Score:6000
# Episode:77 Score:0
# Episode:78 Score:0
# Episode:79 Score:0
# Episode:80 Score:0
# Episode:81 Score:6000
# Episode:82 Score:6000
# Episode:83 Score:0
# Episode:84 Score:0
# Episode:85 Score:0
# Episode:86 Score:0
# Episode:87 Score:0
# Episode:88 Score:6000
# Episode:89 Score:0
# Episode:90 Score:0
# Episode:91 Score:0
# Episode:92 Score:6000
# Episode:93 Score:0
# Episode:94 Score:0
# Episode:95 Score:0
# Episode:96 Score:0
# Episode:97 Score:6000
# Episode:98 Score:6000
# Episode:99 Score:6000
# Episode:100 Score:6000
# Wins by red: 22
# Wins by blue: 11
# Tied games: 67

# %% [markdown]
# Run PyGame for one episode

# %%
game_env = BattleEnvironment(True)
model = PPO.load(f"{models_dir}/{TIMESTEPS*R1_ITERATIONS + TIMESTEPS*R2_ITERATIONS}.zip", env=game_env) # Loads the saved model
state = eval_env.reset()
score = 0
while not eval_env.done:
    action, _states = model.predict(state)
    n_state, red_reward, done, info = eval_env.step(action)
    score += red_reward
print('Episode:{} Score:{}'.format(episode+1, score))
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Episode:100 Score:6000
