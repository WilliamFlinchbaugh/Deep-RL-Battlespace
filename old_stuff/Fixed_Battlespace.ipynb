# %%
# %pip install pygame # 2.1.2
# %pip install numpy # 1.21.5
# %pip install gym # 2.0.0
# %pip install stable-baselines3[extra] # 1.5.0 and torch 1.11.0
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -orch (c:\users\willi\anaconda3\lib\site-packages)
# ERROR: Invalid requirement: '#'
# WARNING: Ignoring invalid distribution -orch (c:\users\willi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\willi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\willi\anaconda3\lib\site-packages)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -orch (c:\users\willi\anaconda3\lib\site-packages)
# ERROR: Invalid requirement: '#'
# WARNING: Ignoring invalid distribution -orch (c:\users\willi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\willi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\willi\anaconda3\lib\site-packages)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -orch (c:\users\willi\anaconda3\lib\site-packages)
# ERROR: Invalid requirement: '#'
# WARNING: Ignoring invalid distribution -orch (c:\users\willi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\willi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\willi\anaconda3\lib\site-packages)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -orch (c:\users\willi\anaconda3\lib\site-packages)
# ERROR: Invalid requirement: '#'
# WARNING: Ignoring invalid distribution -orch (c:\users\willi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\willi\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\willi\anaconda3\lib\site-packages)

# %%
import random
import pygame
from pygame.locals import *
import numpy as np
import numpy.linalg as LA
import math
from collections import defaultdict
import gym
from gym import spaces
import os
import sys
os.environ['KMP_DUPLICATE_LIB_OK']='True'
# Out:
# pygame 2.1.2 (SDL 2.0.18, Python 3.9.12)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
WHITE = (255, 255, 255)
RED = (138, 24, 26)
BLUE = (0, 93, 135)
BLACK = (0, 0, 0)
DISP_WIDTH = 1000
DISP_HEIGHT = 1000
FPS = pygame.time.Clock()

# %% [markdown]
# ---------- Default Config ----------

# %%
DEFAULT_CONFIG_DICT = {
    'time_step': 0.1, # hours per time step
    'plane_speed': 450, # mph
    'bullet_speed': 700, # mph
    'max_time': 10, # hours the epoch can last
    'show_viz': False, # show the pygame animation
    'step_turn': 20, # degrees to turn per step
    'hit_base_reward': 100, # reward for shooting enemy base
    'hit_plane_reward': 100, # reward for shooting enemy plane
    'miss_punishment': -1, # punishment for missing a shot
    'too_long_punishment': 0, # punishment for taking too long to end the game
    'closer_to_base_reward': 0, # reward for getting closer to enemy base
    'closer_to_plane_reward': 0, # reward for getting closer to enemy plane
    'turn_to_base_reward': 0, # reward for turning towards the enemy base
    'turn_to_plane_reward': 0, # reward for turning towards the enemy plane
    'red_policy': 'ai', # policy for the red team
    'blue_policy': 'random' # policy for the blue team
}

# %% [markdown]
# ---------- Helper Functions ----------

# %%
def get_angle(p1, p0):
    return math.degrees(math.atan2(p1[1]-p0[1],p1[0]-p0[0]))

def dist(p1,p0):
    return math.sqrt((p1[0]-p0[0])**2 + (p1[1]-p0[1])**2)

def blitRotate(image, pos, originPos, angle):

    # offset from pivot to center
    image_rect = image.get_rect(topleft = (pos[0] - originPos[0], pos[1]-originPos[1]))
    offset_center_to_pivot = pygame.math.Vector2(pos) - image_rect.center
    
    # roatated offset from pivot to center
    rotated_offset = offset_center_to_pivot.rotate(-angle)

    # rotated image center
    rotated_image_center = (pos[0] - rotated_offset.x, pos[1] - rotated_offset.y)

    # get a rotated image
    rotated_image = pygame.transform.rotate(image, angle)
    rotated_image_rect = rotated_image.get_rect(center = rotated_image_center)

    return rotated_image, rotated_image_rect

def calc_new_xy(old_xy, speed, time, angle):
    new_x = old_xy[0] + (speed*time*math.cos(-math.radians(angle)))
    new_y = old_xy[1] + (speed*time*math.sin(-math.radians(angle)))
    return (new_x, new_y)

# %% [markdown]
# ---------- Plane Class ----------

# %%
class Plane:
    def __init__(self, team): 
        self.team = team
        self.image = pygame.image.load(f"Images/{team}_plane.png")
        self.w, self.h = self.image.get_size()
        self.heading = 0
        self.rect = self.image.get_rect()
        self.reset()

    def reset(self):
        if self.team == 'red':
            x = (DISP_WIDTH - self.w/2)/2 * random.random()
            y = (DISP_HEIGHT - self.h/2) * random.random()
            self.rect.center = (x, y)
            self.heading = 90 * random.random() if random.random() < .5 else 90 * random.random() + 270
            
        else:
            x = (DISP_WIDTH - self.w/2)/2 * random.random() + (DISP_WIDTH - self.w/2)/2
            y = (DISP_HEIGHT - self.h/2) * random.random()
            self.rect.center = (x, y)
            self.heading = 180 * random.random() + 90
        
    def rotate(self, angle):
        self.heading += angle
        while self.heading > 360:
            self.heading -= 360
        while self.heading < 0:
            self.heading += 360
        # Keep player on the screen
        if self.rect.left < 0:
            self.rect.left = 0
        if self.rect.right > DISP_WIDTH:
            self.rect.right = DISP_WIDTH
        if self.rect.top <= 0:
            self.rect.top = 0
        if self.rect.bottom >= DISP_HEIGHT:
            self.rect.bottom = DISP_HEIGHT

    def set_heading(self, heading):
        self.heading = heading

    def forward(self, speed, time):
        oldpos = self.rect.center
        self.rect.center = calc_new_xy(oldpos, speed, time, self.heading)
        # Keep player on the screen
        if self.rect.left < 0:
            self.rect.left = 0
        if self.rect.right > DISP_WIDTH:
            self.rect.right = DISP_WIDTH
        if self.rect.top <= 0:
            self.rect.top = 0
        if self.rect.bottom >= DISP_HEIGHT:
            self.rect.bottom = DISP_HEIGHT

    def draw(self, surface):
        image, rect = blitRotate(self.image, self.rect.center, (self.w/2, self.h/2), self.heading)
        surface.blit(image, rect)

    def update(self):
        # Keep player on the screen
        if self.rect.left < 0:
            self.rect.left = 0
        if self.rect.right > DISP_WIDTH:
            self.rect.right = DISP_WIDTH
        if self.rect.top <= 0:
            self.rect.top = 0
        if self.rect.bottom >= DISP_HEIGHT:
            self.rect.bottom = DISP_HEIGHT

    def get_pos(self):
        image, rect = blitRotate(self.image, self.rect.center, (self.w/2, self.h/2), self.heading)
        return (rect.centerx, rect.centery)

# %% [markdown]
# ----------- Base Class ----------

# %%
class Base:
    
    def __init__(self, team):
        self.team = team
        self.image = pygame.image.load(f"Images/{team}_base.png")
        self.w, self.h = self.image.get_size()
        self.rect = self.image.get_rect()
        self.reset()
        
    def reset(self):
        if self.team == 'red':
            x = (DISP_WIDTH - self.w/2)/2 * random.random()
            y = (DISP_HEIGHT - self.h/2) * random.random()
            self.rect.center = (x, y)
        else:
            x = (DISP_WIDTH - self.w/2)/2 * random.random() + (DISP_WIDTH - self.w/2)/2
            y = (DISP_HEIGHT - self.h/2) * random.random()
            self.rect.center = (x, y)

    def draw(self, surface):
        surface.blit(self.image, self.rect)
            
    def get_pos(self):
        return self.rect.center

# %% [markdown]
# ---------- Bullet Class ----------

# %%
class Bullet(pygame.sprite.Sprite):
    def __init__(self, x, y, angle, speed, fteam, oteam):
        pygame.sprite.Sprite.__init__(self)
        self.off_screen = False
        self.image = pygame.Surface((8, 4), pygame.SRCALPHA)
        self.fteam = fteam
        self.color = RED if self.fteam == 'red' else BLUE
        self.oteam = oteam
        self.image.fill(self.color)
        self.rect = self.image.get_rect(center=(x, y))
        self.w, self.h = self.image.get_size()
        self.heading = angle + (random.random() * 10 - 5)
        self.pos = (x, y)
        self.speed = speed

    def update(self, screen_width, screen_height, time):
        oldpos = self.rect.center
        self.rect.center = calc_new_xy(oldpos, self.speed, time, self.heading)
        if self.rect.centerx > screen_width or self.rect.centerx < 0 or self.rect.centery > screen_height or self.rect.centery < 0:
            return 'miss'
        for plane in self.oteam['planes']:
            if self.rect.colliderect(plane.rect):
                return 'plane'
        if self.rect.colliderect(self.oteam['base'].rect):
            return 'base'
        return 'none'

    def draw(self, surface):
        image, rect = blitRotate(self.image, self.rect.center, (self.w/2, self.h/2), self.heading)
        surface.blit(image, rect)

# %% [markdown]
# ----------- Battle Environment ----------

# %%
class BattleEnvironment(gym.Env):
    def __init__(self, config: dict=DEFAULT_CONFIG_DICT):
        super(BattleEnvironment, self).__init__()
        self.width = DISP_WIDTH
        self.height = DISP_HEIGHT
        self.max_time = config['max_time']
        high = np.array( # Observation space: fplane_pos_x, fplane_pos_y, fplane_angle, obase_pos_x, obase_pos_y, oplane_pos_x, oplane_pos_y, time
            [
                self.width,
                self.height,
                360,
                self.width,
                self.height,
                self.width,
                self.height,
                self.max_time,
            ],
            dtype=np.float32,
        )
        # AI agent: 1.forwards, 2.shoot, 3.left, 4.right
        # Random agent: 1.forwards, 2.shoot, 3.turn to enemy plane, 4.turn to enemy base
        self.action_space = spaces.Discrete(4)
        self.observation_space = spaces.Box(-high, high, dtype=np.float32)
        self.team = {}
        self.team['red'] = {}
        self.team['blue'] = {}
        self.team['red']['base'] = Base('red')
        self.team['blue']['base'] = Base('blue')
        self.team['red']['planes'] = []
        self.team['red']['planes'].append(Plane('red'))
        self.team['blue']['planes'] = []
        self.team['blue']['planes'].append(Plane('blue'))
        self.team['red']['wins'] = 0
        self.team['blue']['wins'] = 0
        self.team['red']['policy'] = config['red_policy']
        self.team['blue']['policy'] = config['blue_policy']
        self.ties = 0
        self.bullets = []
        self.speed = config['plane_speed']
        self.bullet_speed = config['bullet_speed']
        self.total_time = 0 # in hours
        self.time_step = config['time_step']
        self.show = config['show_viz']
        self.step_turn = config['step_turn']
        self.hit_base_reward = config['hit_base_reward']
        self.hit_plane_reward = config['hit_plane_reward']
        self.miss_punishment = config['miss_punishment']
        self.too_long_punishment = config['too_long_punishment']
        self.closer_to_base_reward = config['closer_to_base_reward']
        self.closer_to_plane_reward = config['closer_to_plane_reward']
        self.turn_to_base_reward = config['turn_to_base_reward']
        self.turn_to_plane_reward = config['turn_to_plane_reward']
    
    def _get_observation(self):
        # Observation space: fplane_pos_x, fplane_pos_y, fplane_angle, obase_pos_x, obase_pos_y, oplane_pos_x, oplane_pos_y, time
        # This code will all have to be changed when adding multiple planes
        fplane = self.team['red']['planes'][0]
        oplane = self.team['blue']['planes'][0]
        obase = self.team['red']['base']

        fplane_pos = fplane.get_pos()
        fplane_angle = fplane.heading
        oplane_pos = oplane.get_pos()
        obase_pos = obase.get_pos()
        
        self.observation = (fplane_pos[0], fplane_pos[1], fplane_angle, obase_pos[0], obase_pos[1], oplane_pos[0], oplane_pos[1], self.total_time)
        # print(self.observation)
        return np.array(self.observation, dtype=np.float32)

        
    def reset(self): # return observation
        self.done = False
        self.winner = 'none'

        self.team['red']['base'].reset()
        self.team['blue']['base'].reset()

        for plane in self.team['red']['planes']:
            plane.reset()
        for plane in self.team['blue']['planes']:
            plane.reset()

        self.total_time = 0
        self.bullets = []

        if self.show:
            pygame.init()
            self.display = pygame.display.set_mode((DISP_WIDTH, DISP_HEIGHT))
            pygame.display.set_caption("Battlespace Simulator")

        return self._get_observation()

    def step(self, action): # return observation, reward, done, info
        reward = 0

        # Check if over time, if so, end game in tie
        self.total_time += self.time_step
        if self.total_time >= self.max_time:
            self.done = True
            self.ties += 1
            if self.show:
                self.render()
                print("Draw")
            return self._get_observation(), 0, self.done, {}

        # Red turn
        self.friendly = 'red'
        self.opponent = 'blue'
        reward += self._process_action(action, self.team[self.friendly], self.team[self.opponent])
        
        # Blue turn
        self.friendly = 'blue'
        self.opponent = 'red'
        self._process_action(random.randint(0, 3), self.team[self.friendly], self.team[self.opponent])        

        # Check if bullets hit and move them
        for bullet in self.bullets:
            outcome = bullet.update(self.width, self.height, self.time_step)
            if outcome == 'miss':
                reward += self.miss_punishment
                self.bullets.pop(self.bullets.index(bullet))
            elif outcome == 'plane' or outcome == 'base': # If a bullet hit
                self.winner = bullet.fteam
                self.team[self.winner]['wins'] += 1
                self.done = True
                reward = reward + self.hit_base_reward if outcome == 'base' else reward + self.hit_plane_reward
                if self.show:
                    self.render()
                    print(f"{self.winner} wins")
                return self._get_observation(), reward, self.done, {}
            
        # Check if past half of max time and give punishment
        if (self.total_time > self.max_time//2):
            reward += self.too_long_punishment

        # Continue game
        if self.show:
            self.render()
        return self._get_observation(), reward, self.done, {}
    
    def _process_action(self, action, fteam, oteam): # friendly and opponent
        policy = fteam['policy']
        reward = 0

        fplane = fteam['planes'][0]
        oplane = oteam['planes'][0]
        obase = oteam['base']

        fplane_pos = fplane.get_pos()
        fplane_angle = fplane.heading
        oplane_pos = oplane.get_pos()
        obase_pos = obase.get_pos()

        dist_oplane = dist(oplane_pos, fplane_pos)
        dist_obase = dist(obase_pos, fplane_pos)

        angle_to_oplane = get_angle(oplane_pos, fplane_pos)
        angle_to_obase = get_angle(obase_pos, fplane_pos)
        rel_angle_oplane = (angle_to_oplane - fplane_angle) % 360
        rel_angle_obase = (angle_to_obase - fplane_angle) % 360

        # --------------- FORWARDS ---------------
        if action == 0: 
            fplane.forward(self.speed, self.time_step)

         # --------------- SHOOT ---------------
        elif action == 1:
            self.bullets.append(Bullet(fplane_pos[0], fplane_pos[1], fplane_angle, self.bullet_speed, self.friendly, oteam))
            fplane.forward(self.speed, self.time_step)
        
        # --------------- TURN RIGHT or TURN TO ENEMY PLANE ---------------
        elif action == 2: # Turn right
            if policy == 'ai':
                fplane.rotate(-self.step_turn)
                fplane.forward(self.speed, self.time_step)
            else:
                if rel_angle_oplane < 0:
                    fplane.rotate(-self.step_turn)
                else:
                    fplane.rotate(self.step_turn)
                fplane.forward(self.speed, self.time_step)

        # ---------------- TURN LEFT or TURN TO ENEMY BASE ----------------
        elif action == 3:
            if policy == 'ai':
                fplane.rotate(self.step_turn)
                fplane.forward(self.speed, self.time_step)
            else:
                if rel_angle_obase < 0:
                    fplane.rotate(-self.step_turn)
                else:
                    fplane.rotate(self.step_turn)
                fplane.forward(self.speed, self.time_step)

        # ---------------- GIVE REWARDS IF CLOSER (DIST OR ANGLE) ----------------
        new_fplane_pos = fplane.get_pos()
        new_fplane_angle = fplane.heading
        new_oplane_pos = oplane.get_pos()
        new_obase_pos = obase.get_pos()

        new_dist_oplane = dist(new_oplane_pos, new_fplane_pos)
        new_dist_obase = dist(new_obase_pos, new_fplane_pos)

        new_angle_to_oplane = get_angle(new_oplane_pos, new_fplane_pos)
        new_angle_to_obase = get_angle(new_obase_pos, new_fplane_pos)
        new_rel_angle_oplane = (new_angle_to_oplane - new_fplane_angle) % 360
        new_rel_angle_obase = (new_angle_to_obase - new_fplane_angle) % 360

        if new_dist_oplane < dist_oplane: # If got closer to enemy plane
            reward += self.closer_to_plane_reward

        if new_dist_obase < dist_obase: # If got closer to enemy base
            reward += self.closer_to_base_reward

        if math.fabs(new_rel_angle_oplane) < math.fabs(rel_angle_oplane): # If aiming closer to enemy plane
            reward += self.turn_to_plane_reward

        if math.fabs(new_rel_angle_obase) < math.fabs(rel_angle_obase): # If aiming closer to enemy base
            reward += self.turn_to_base_reward

        return reward

    def draw_shot(self, hit, friendly_pos, target_pos, team):
        color = BLACK
        color = RED if team == 'red' else BLUE
        if not hit: target_pos = (target_pos[0] + (random.random() * 2 - 1) * 100, target_pos[1] + (random.random() * 2 - 1) * 100)
        self.shot_history.append((hit, friendly_pos, target_pos, color))
    
    def winner_screen(self):
        if self.show:
            font = pygame.font.Font('freesansbold.ttf', 32)
            if self.winner != 'none':
                text = font.render(f"THE WINNER IS {self.winner.upper()}", True, BLACK)
                textRect = text.get_rect()
                textRect.center = (DISP_WIDTH//2, DISP_HEIGHT//2)
            else:
                text = font.render(f"THE GAME IS A TIE", True, BLACK)
                textRect = text.get_rect()
                textRect.center = (DISP_WIDTH//2, DISP_HEIGHT//2)
            self.display.blit(text, textRect)

    def show_wins(self):
        print("Wins by red:", self.team['red']['wins'])
        print("Wins by blue:", self.team['blue']['wins'])
        print("Tied games:", self.ties)

    def render(self, mode="human"):
        if self.show: # Just to ensure it won't render if self.show == False
            for event in pygame.event.get():
                # Check for KEYDOWN event
                if event.type == KEYDOWN:
                    # If the Esc key is pressed, then exit the main loop
                    if event.key == K_ESCAPE:
                        pygame.quit()
                        sys.exit()
                        return
                # Check for QUIT event. If QUIT, then set running to false.
                elif event.type == QUIT:
                    pygame.quit()
                    sys.exit()
                    return
                    
            # Fill background
            self.display.fill(WHITE)

            # Draw bullets
            for bullet in self.bullets:
                bullet.draw(self.display)
                    
            # Draw bases
            self.team['red']['base'].draw(self.display)
            self.team['blue']['base'].draw(self.display)

            # Draw planes
            for plane in self.team['red']['planes']:
                plane.update()
                plane.draw(self.display)
            for plane in self.team['blue']['planes']:
                plane.update()
                plane.draw(self.display)

            # Winner Screen
            if self.done:
                font = pygame.font.Font('freesansbold.ttf', 32)
                if self.winner != 'none':
                    text = font.render(f"THE WINNER IS {self.winner.upper()}", True, BLACK)
                    textRect = text.get_rect()
                    textRect.center = (DISP_WIDTH//2, DISP_HEIGHT//2)
                else:
                    text = font.render(f"THE GAME IS A TIE", True, BLACK)
                    textRect = text.get_rect()
                    textRect.center = (DISP_WIDTH//2, DISP_HEIGHT//2)
                self.display.blit(text, textRect)
                pygame.display.update()
                pygame.time.wait(3000)
                pygame.quit()
                return
            
            pygame.display.update()
            FPS.tick(7)

# %% [markdown]
# ----------- Callback and Training ---------

# %%
import stable_baselines3
from stable_baselines3 import DQN

LOG_DIR = 'DQN/logs/'
OPT_DIR = 'DQN/opt/'
if not os.path.exists(LOG_DIR):
    os.makedirs(LOG_DIR)
if not os.path.exists(OPT_DIR):
    os.makedirs(OPT_DIR)

# %%
from stable_baselines3.common.callbacks import BaseCallback

class TrainAndLoggingCallback(BaseCallback):
    def __init__(self, check_freq, save_path, verbose=1):
        super(TrainAndLoggingCallback, self).__init__(verbose)
        self.check_freq = check_freq
        self.save_path = save_path

    def _init_callback(self):
        if self.save_path is not None:
            os.makedirs(self.save_path, exist_ok=True)

    def _on_step(self):
        if self.n_calls % self.check_freq == 0:
            model_path = os.path.join(self.save_path, 'best_model_{}'.format(self.n_calls))
            self.model.save(model_path)
        return True

CHECKPOINT_DIR = 'DQN/train/'
callback = TrainAndLoggingCallback(check_freq=30000, save_path=CHECKPOINT_DIR)

# %%
env = BattleEnvironment()
model = DQN('MlpPolicy', env, tensorboard_log=LOG_DIR, verbose=1)
model.learn(total_timesteps=2000000, callback=callback)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to DQN/logs/DQN_1
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 76.5     |
# |    ep_rew_mean      | 14.8     |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 39       |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 306      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 66.9     |
# |    ep_rew_mean      | 44.6     |
# |    exploration_rate | 0.997    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 68       |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 535      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 60.9     |
# |    ep_rew_mean      | 47       |
# |    exploration_rate | 0.997    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 93       |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 731      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 61.9     |
# |    ep_rew_mean      | 40.1     |
# |    exploration_rate | 0.995    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 124      |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 990      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 60.2     |
# |    ep_rew_mean      | 43       |
# |    exploration_rate | 0.994    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 149      |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 1205     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 64.7     |
# |    ep_rew_mean      | 32.8     |
# |    exploration_rate | 0.993    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 189      |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 1553     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 67.4     |
# |    ep_rew_mean      | 30.3     |
# |    exploration_rate | 0.991    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 226      |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 1886     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 67.2     |
# |    ep_rew_mean      | 29.2     |
# |    exploration_rate | 0.99     |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 254      |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 2150     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 67.7     |
# |    ep_rew_mean      | 28.2     |
# |    exploration_rate | 0.988    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 285      |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 2437     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 68.1     |
# |    ep_rew_mean      | 29.7     |
# |    exploration_rate | 0.987    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 314      |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 2724     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 65.2     |
# |    ep_rew_mean      | 32.6     |
# |    exploration_rate | 0.986    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 328      |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 2868     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 65.3     |
# |    ep_rew_mean      | 31.8     |
# |    exploration_rate | 0.985    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 354      |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 3133     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 66       |
# |    ep_rew_mean      | 32.4     |
# |    exploration_rate | 0.984    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 383      |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 3434     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 66.8     |
# |    ep_rew_mean      | 29.5     |
# |    exploration_rate | 0.982    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 411      |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 3743     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 66.1     |
# |    ep_rew_mean      | 28.9     |
# |    exploration_rate | 0.981    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 431      |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 3968     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 67.6     |
# |    ep_rew_mean      | 25.8     |
# |    exploration_rate | 0.979    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 462      |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 4329     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 65.8     |
# |    ep_rew_mean      | 29.4     |
# |    exploration_rate | 0.979    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 475      |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 4475     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 67.2     |
# |    ep_rew_mean      | 28.1     |
# |    exploration_rate | 0.977    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 505      |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 4839     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 67.8     |
# |    ep_rew_mean      | 25.8     |
# |    exploration_rate | 0.976    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 532      |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 5150     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 67       |
# |    ep_rew_mean      | 27.1     |
# |    exploration_rate | 0.975    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 549      |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 5361     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 67.2     |
# |    ep_rew_mean      | 27.9     |
# |    exploration_rate | 0.973    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 571      |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 5641     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 66       |
# |    ep_rew_mean      | 29.3     |
# |    exploration_rate | 0.972    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 582      |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 5809     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 66.5     |
# |    ep_rew_mean      | 27.4     |
# |    exploration_rate | 0.971    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 607      |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 6122     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 66       |
# |    ep_rew_mean      | 27.3     |
# |    exploration_rate | 0.97     |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 623      |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 6339     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 64.9     |
# |    ep_rew_mean      | 28.5     |
# |    exploration_rate | 0.969    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 634      |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 6490     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 65.3     |
# |    ep_rew_mean      | 28.2     |
# |    exploration_rate | 0.968    |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 659      |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 6833     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 65.9     |
# |    ep_rew_mean      | 26       |
# |    exploration_rate | 0.966    |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 681      |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 7127     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 67.1     |
# |    ep_rew_mean      | 23.1     |
# |    exploration_rate | 0.965    |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 701      |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 7441     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 68.1     |
# |    ep_rew_mean      | 22.7     |
# |    exploration_rate | 0.963    |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 723      |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 7800     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 69.2     |
# |    ep_rew_mean      | 22       |
# |    exploration_rate | 0.961    |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 739      |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 8128     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 67.5     |
# |    ep_rew_mean      | 26.2     |
# |    exploration_rate | 0.961    |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 748      |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 8306     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 66.2     |
# |    ep_rew_mean      | 27.7     |
# |    exploration_rate | 0.96     |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 760      |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 8510     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 67.6     |
# |    ep_rew_mean      | 25       |
# |    exploration_rate | 0.958    |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 782      |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 8914     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 68.6     |
# |    ep_rew_mean      | 23.4     |
# |    exploration_rate | 0.956    |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 803      |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 9294     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 67.7     |
# |    ep_rew_mean      | 23.9     |
# |    exploration_rate | 0.955    |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 812      |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 9493     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 68.8     |
# |    ep_rew_mean      | 22.2     |
# |    exploration_rate | 0.954    |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 825      |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 9743     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 69.1     |
# |    ep_rew_mean      | 21.8     |
# |    exploration_rate | 0.952    |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 841      |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 10043    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 69       |
# |    ep_rew_mean      | 20.9     |
# |    exploration_rate | 0.951    |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 854      |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 10333    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 68.4     |
# |    ep_rew_mean      | 23.1     |
# |    exploration_rate | 0.95     |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 866      |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 10584    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 69.7     |
# |    ep_rew_mean      | 22.4     |
# |    exploration_rate | 0.948    |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 882      |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 10936    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 69.2     |
# |    ep_rew_mean      | 22.8     |
# |    exploration_rate | 0.947    |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 895      |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 11246    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 70.2     |
# |    ep_rew_mean      | 20.4     |
# |    exploration_rate | 0.945    |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 905      |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 11495    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 68.8     |
# |    ep_rew_mean      | 21.2     |
# |    exploration_rate | 0.944    |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 913      |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 11722    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 68       |
# |    ep_rew_mean      | 22.8     |
# |    exploration_rate | 0.943    |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 922      |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 11949    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 69.9     |
# |    ep_rew_mean      | 18.8     |
# |    exploration_rate | 0.941    |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 938      |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 12353    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 70.9     |
# |    ep_rew_mean      | 16.1     |
# |    exploration_rate | 0.94     |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 952      |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 12735    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 72.2     |
# |    ep_rew_mean      | 14.3     |
# |    exploration_rate | 0.938    |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 962      |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 13033    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 73.2     |
# |    ep_rew_mean      | 12.8     |
# |    exploration_rate | 0.936    |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 977      |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 13437    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 72.8     |
# |    ep_rew_mean      | 14.1     |
# |    exploration_rate | 0.935    |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 984      |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 13621    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 75.3     |
# |    ep_rew_mean      | 10.9     |
# |    exploration_rate | 0.933    |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 1002     |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 14023    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 74.2     |
# |    ep_rew_mean      | 11.5     |
# |    exploration_rate | 0.932    |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 1011     |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 14256    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 73.4     |
# |    ep_rew_mean      | 12.8     |
# |    exploration_rate | 0.931    |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 1020     |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 14464    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 72.3     |
# |    ep_rew_mean      | 15.5     |
# |    exploration_rate | 0.93     |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 1029     |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 14674    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 71.6     |
# |    ep_rew_mean      | 15.7     |
# |    exploration_rate | 0.929    |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 1041     |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 14957    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 70.9     |
# |    ep_rew_mean      | 15       |
# |    exploration_rate | 0.928    |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 1052     |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 15216    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 71.5     |
# |    ep_rew_mean      | 13.4     |
# |    exploration_rate | 0.927    |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 1061     |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 15456    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 72.8     |
# |    ep_rew_mean      | 10.8     |
# |    exploration_rate | 0.925    |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 1075     |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 15787    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 72       |
# |    ep_rew_mean      | 13.2     |
# |    exploration_rate | 0.923    |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 1089     |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 16118    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 71.5     |
# |    ep_rew_mean      | 14.3     |
# |    exploration_rate | 0.922    |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 1102     |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 16448    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 73.6     |
# |    ep_rew_mean      | 11.1     |
# |    exploration_rate | 0.92     |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 1118     |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 16850    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 74.3     |
# |    ep_rew_mean      | 10.8     |
# |    exploration_rate | 0.918    |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 1131     |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 17175    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 74.7     |
# |    ep_rew_mean      | 9.81     |
# |    exploration_rate | 0.917    |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 1143     |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 17517    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 73.8     |
# |    ep_rew_mean      | 11.2     |
# |    exploration_rate | 0.916    |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 1150     |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 17718    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 74.8     |
# |    ep_rew_mean      | 9.81     |
# |    exploration_rate | 0.914    |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 1163     |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 18060    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 74.8     |
# |    ep_rew_mean      | 8.89     |
# |    exploration_rate | 0.913    |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 1176     |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 18415    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 73.9     |
# |    ep_rew_mean      | 10.3     |
# |    exploration_rate | 0.911    |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 1184     |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 18636    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 73.8     |
# |    ep_rew_mean      | 11.3     |
# |    exploration_rate | 0.91     |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 1191     |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 18870    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 74.6     |
# |    ep_rew_mean      | 9.76     |
# |    exploration_rate | 0.909    |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 1201     |
# |    time_elapsed     | 15       |
# |    total_timesteps  | 19181    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 75.6     |
# |    ep_rew_mean      | 9.12     |
# |    exploration_rate | 0.907    |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 1212     |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 19511    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 74.2     |
# |    ep_rew_mean      | 12.7     |
# |    exploration_rate | 0.906    |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 1220     |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 19769    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 73.2     |
# |    ep_rew_mean      | 14.5     |
# |    exploration_rate | 0.905    |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 1229     |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 20058    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 72.8     |
# |    ep_rew_mean      | 15.7     |
# |    exploration_rate | 0.903    |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 1238     |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 20318    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 71.2     |
# |    ep_rew_mean      | 18.8     |
# |    exploration_rate | 0.902    |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 1245     |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 20553    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 72.7     |
# |    ep_rew_mean      | 16.1     |
# |    exploration_rate | 0.901    |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 1257     |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 20890    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 71.8     |
# |    ep_rew_mean      | 16.4     |
# |    exploration_rate | 0.899    |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 1267     |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 21201    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 73.1     |
# |    ep_rew_mean      | 14.7     |
# |    exploration_rate | 0.898    |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 1278     |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 21563    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 74.1     |
# |    ep_rew_mean      | 13.4     |
# |    exploration_rate | 0.896    |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 1287     |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 21872    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 73.8     |
# |    ep_rew_mean      | 13.5     |
# |    exploration_rate | 0.895    |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 1292     |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 22059    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 73.5     |
# |    ep_rew_mean      | 13.7     |
# |    exploration_rate | 0.894    |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 1299     |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 22308    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 74.2     |
# |    ep_rew_mean      | 12.6     |
# |    exploration_rate | 0.892    |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 1308     |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 22633    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 74.9     |
# |    ep_rew_mean      | 10.3     |
# |    exploration_rate | 0.891    |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 1318     |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 22946    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 75.2     |
# |    ep_rew_mean      | 11.1     |
# |    exploration_rate | 0.889    |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 1328     |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 23303    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 74.5     |
# |    ep_rew_mean      | 11.3     |
# |    exploration_rate | 0.888    |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 1336     |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 23565    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 72.7     |
# |    ep_rew_mean      | 13.2     |
# |    exploration_rate | 0.887    |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 1340     |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 23721    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 70.9     |
# |    ep_rew_mean      | 16.2     |
# |    exploration_rate | 0.886    |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 1345     |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 23941    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 69.1     |
# |    ep_rew_mean      | 18.1     |
# |    exploration_rate | 0.886    |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 1349     |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 24085    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 69.7     |
# |    ep_rew_mean      | 16.7     |
# |    exploration_rate | 0.884    |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 1361     |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 24489    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 70.5     |
# |    ep_rew_mean      | 16.6     |
# |    exploration_rate | 0.882    |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 1368     |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 24764    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 68.9     |
# |    ep_rew_mean      | 18.2     |
# |    exploration_rate | 0.881    |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 1373     |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 24949    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 68       |
# |    ep_rew_mean      | 21.8     |
# |    exploration_rate | 0.88     |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 1379     |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 25210    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 68.2     |
# |    ep_rew_mean      | 21.5     |
# |    exploration_rate | 0.879    |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 1386     |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 25461    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 69.7     |
# |    ep_rew_mean      | 18.7     |
# |    exploration_rate | 0.877    |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 1396     |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 25837    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 69.8     |
# |    ep_rew_mean      | 18.6     |
# |    exploration_rate | 0.876    |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 1405     |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 26160    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 69       |
# |    ep_rew_mean      | 19.2     |
# |    exploration_rate | 0.875    |
# | time/               |          |
# |    episodes         | 376      |
# |    fps              | 1411     |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 26414    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 70.5     |
# |    ep_rew_mean      | 15.5     |
# |    exploration_rate | 0.873    |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 1422     |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 26818    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 71.2     |
# |    ep_rew_mean      | 14       |
# |    exploration_rate | 0.871    |
# | time/               |          |
# |    episodes         | 384      |
# |    fps              | 1431     |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 27181    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 71.4     |
# |    ep_rew_mean      | 12.6     |
# |    exploration_rate | 0.87     |
# | time/               |          |
# |    episodes         | 388      |
# |    fps              | 1431     |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 27458    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 72.1     |
# |    ep_rew_mean      | 13.2     |
# |    exploration_rate | 0.868    |
# | time/               |          |
# |    episodes         | 392      |
# |    fps              | 1438     |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 27762    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 72.2     |
# |    ep_rew_mean      | 13.2     |
# |    exploration_rate | 0.866    |
# | time/               |          |
# |    episodes         | 396      |
# |    fps              | 1447     |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 28111    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 72.3     |
# |    ep_rew_mean      | 13.3     |
# |    exploration_rate | 0.865    |
# | time/               |          |
# |    episodes         | 400      |
# |    fps              | 1454     |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 28436    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 71.2     |
# |    ep_rew_mean      | 14.9     |
# |    exploration_rate | 0.864    |
# | time/               |          |
# |    episodes         | 404      |
# |    fps              | 1459     |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 28687    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 72.1     |
# |    ep_rew_mean      | 13.4     |
# |    exploration_rate | 0.862    |
# | time/               |          |
# |    episodes         | 408      |
# |    fps              | 1468     |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 29078    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 73.9     |
# |    ep_rew_mean      | 10.5     |
# |    exploration_rate | 0.86     |
# | time/               |          |
# |    episodes         | 412      |
# |    fps              | 1476     |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 29448    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 73.9     |
# |    ep_rew_mean      | 10.5     |
# |    exploration_rate | 0.859    |
# | time/               |          |
# |    episodes         | 416      |
# |    fps              | 1481     |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 29700    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 73.7     |
# |    ep_rew_mean      | 11.7     |
# |    exploration_rate | 0.857    |
# | time/               |          |
# |    episodes         | 420      |
# |    fps              | 1487     |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 30006    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 73       |
# |    ep_rew_mean      | 13.9     |
# |    exploration_rate | 0.856    |
# | time/               |          |
# |    episodes         | 424      |
# |    fps              | 1492     |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 30241    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 71.6     |
# |    ep_rew_mean      | 15.6     |
# |    exploration_rate | 0.855    |
# | time/               |          |
# |    episodes         | 428      |
# |    fps              | 1496     |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 30464    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 71.8     |
# |    ep_rew_mean      | 15.6     |
# |    exploration_rate | 0.854    |
# | time/               |          |
# |    episodes         | 432      |
# |    fps              | 1502     |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 30749    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 73.5     |
# |    ep_rew_mean      | 13.1     |
# |    exploration_rate | 0.852    |
# | time/               |          |
# |    episodes         | 436      |
# |    fps              | 1507     |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 31066    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 73.4     |
# |    ep_rew_mean      | 12       |
# |    exploration_rate | 0.851    |
# | time/               |          |
# |    episodes         | 440      |
# |    fps              | 1511     |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 31283    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 75.6     |
# |    ep_rew_mean      | 9.98     |
# |    exploration_rate | 0.85     |
# | time/               |          |
# |    episodes         | 444      |
# |    fps              | 1519     |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 31647    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 74.5     |
# |    ep_rew_mean      | 12.4     |
# |    exploration_rate | 0.848    |
# | time/               |          |
# |    episodes         | 448      |
# |    fps              | 1525     |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 31939    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 74.3     |
# |    ep_rew_mean      | 11.5     |
# |    exploration_rate | 0.847    |
# | time/               |          |
# |    episodes         | 452      |
# |    fps              | 1530     |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 32198    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 75.4     |
# |    ep_rew_mean      | 9.97     |
# |    exploration_rate | 0.846    |
# | time/               |          |
# |    episodes         | 456      |
# |    fps              | 1536     |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 32491    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 75.3     |
# |    ep_rew_mean      | 8.86     |
# |    exploration_rate | 0.844    |
# | time/               |          |
# |    episodes         | 460      |
# |    fps              | 1540     |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 32745    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 75       |
# |    ep_rew_mean      | 9.15     |
# |    exploration_rate | 0.843    |
# | time/               |          |
# |    episodes         | 464      |
# |    fps              | 1543     |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 32960    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 74.7     |
# |    ep_rew_mean      | 9.25     |
# |    exploration_rate | 0.842    |
# | time/               |          |
# |    episodes         | 468      |
# |    fps              | 1550     |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 33303    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 75       |
# |    ep_rew_mean      | 9.08     |
# |    exploration_rate | 0.84     |
# | time/               |          |
# |    episodes         | 472      |
# |    fps              | 1557     |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 33656    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 75       |
# |    ep_rew_mean      | 9.22     |
# |    exploration_rate | 0.839    |
# | time/               |          |
# |    episodes         | 476      |
# |    fps              | 1562     |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 33910    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 72.4     |
# |    ep_rew_mean      | 14.7     |
# |    exploration_rate | 0.838    |
# | time/               |          |
# |    episodes         | 480      |
# |    fps              | 1565     |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 34056    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 72       |
# |    ep_rew_mean      | 14.9     |
# |    exploration_rate | 0.837    |
# | time/               |          |
# |    episodes         | 484      |
# |    fps              | 1570     |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 34384    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 72.2     |
# |    ep_rew_mean      | 15       |
# |    exploration_rate | 0.835    |
# | time/               |          |
# |    episodes         | 488      |
# |    fps              | 1570     |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 34674    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 72.5     |
# |    ep_rew_mean      | 12.9     |
# |    exploration_rate | 0.834    |
# | time/               |          |
# |    episodes         | 492      |
# |    fps              | 1572     |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 35010    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 72.7     |
# |    ep_rew_mean      | 12.7     |
# |    exploration_rate | 0.832    |
# | time/               |          |
# |    episodes         | 496      |
# |    fps              | 1573     |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 35377    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 72.2     |
# |    ep_rew_mean      | 14.1     |
# ...
# |    ep_rew_mean      | 12.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 11132    |
# |    fps              | 590      |
# |    time_elapsed     | 1362     |
# |    total_timesteps  | 804729   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.05     |
# |    n_updates        | 188682   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 83.5     |
# |    ep_rew_mean      | 9.77     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 11136    |
# |    fps              | 590      |
# |    time_elapsed     | 1363     |
# |    total_timesteps  | 805133   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.89     |
# |    n_updates        | 188783   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 83.5     |
# |    ep_rew_mean      | 10.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 11140    |
# |    fps              | 590      |
# |    time_elapsed     | 1364     |
# |    total_timesteps  | 805531   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.332    |
# |    n_updates        | 188882   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 82.8     |
# |    ep_rew_mean      | 11.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 11144    |
# |    fps              | 590      |
# |    time_elapsed     | 1365     |
# |    total_timesteps  | 805804   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.247    |
# |    n_updates        | 188950   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 82.3     |
# |    ep_rew_mean      | 11.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 11148    |
# |    fps              | 589      |
# |    time_elapsed     | 1366     |
# |    total_timesteps  | 806080   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.424    |
# |    n_updates        | 189019   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 84.5     |
# |    ep_rew_mean      | 7.6      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 11152    |
# |    fps              | 589      |
# |    time_elapsed     | 1367     |
# |    total_timesteps  | 806411   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.603    |
# |    n_updates        | 189102   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 83.4     |
# |    ep_rew_mean      | 8.74     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 11156    |
# |    fps              | 589      |
# |    time_elapsed     | 1368     |
# |    total_timesteps  | 806678   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.956    |
# |    n_updates        | 189169   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 84.5     |
# |    ep_rew_mean      | 6.53     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 11160    |
# |    fps              | 589      |
# |    time_elapsed     | 1369     |
# |    total_timesteps  | 806993   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.531    |
# |    n_updates        | 189248   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 84.1     |
# |    ep_rew_mean      | 7.59     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 11164    |
# |    fps              | 589      |
# |    time_elapsed     | 1369     |
# |    total_timesteps  | 807304   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.342    |
# |    n_updates        | 189325   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 83.5     |
# |    ep_rew_mean      | 8.79     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 11168    |
# |    fps              | 589      |
# |    time_elapsed     | 1370     |
# |    total_timesteps  | 807604   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.525    |
# |    n_updates        | 189400   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 82.6     |
# |    ep_rew_mean      | 10.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 11172    |
# |    fps              | 589      |
# |    time_elapsed     | 1370     |
# |    total_timesteps  | 807858   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.61     |
# |    n_updates        | 189464   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 83.4     |
# |    ep_rew_mean      | 9.83     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 11176    |
# |    fps              | 589      |
# |    time_elapsed     | 1371     |
# |    total_timesteps  | 808251   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.67     |
# |    n_updates        | 189562   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 82.7     |
# |    ep_rew_mean      | 9.83     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 11180    |
# |    fps              | 589      |
# |    time_elapsed     | 1372     |
# |    total_timesteps  | 808514   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.221    |
# |    n_updates        | 189628   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 82.1     |
# |    ep_rew_mean      | 9.99     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 11184    |
# |    fps              | 588      |
# |    time_elapsed     | 1373     |
# |    total_timesteps  | 808824   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.56     |
# |    n_updates        | 189705   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 81.5     |
# |    ep_rew_mean      | 11.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 11188    |
# |    fps              | 588      |
# |    time_elapsed     | 1374     |
# |    total_timesteps  | 809080   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.314    |
# |    n_updates        | 189769   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 79.5     |
# |    ep_rew_mean      | 13.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 11192    |
# |    fps              | 588      |
# |    time_elapsed     | 1375     |
# |    total_timesteps  | 809242   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.5      |
# |    n_updates        | 189810   |
# ----------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\Willi\OneDrive\Research\Fixed_Battlespace.ipynb Cell 19' in <cell line: 3>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Willi/OneDrive/Research/Fixed_Battlespace.ipynb#ch0000018?line=0'>1</a> env = BattleEnvironment()
#       <a href='vscode-notebook-cell:/c%3A/Users/Willi/OneDrive/Research/Fixed_Battlespace.ipynb#ch0000018?line=1'>2</a> model = DQN('MlpPolicy', env, tensorboard_log=LOG_DIR, verbose=1)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Willi/OneDrive/Research/Fixed_Battlespace.ipynb#ch0000018?line=2'>3</a> model.learn(total_timesteps=2000000, callback=callback)
#
# File c:\Users\Willi\anaconda3\lib\site-packages\stable_baselines3\dqn\dqn.py:258, in DQN.learn(self, total_timesteps, callback, log_interval, eval_env, eval_freq, n_eval_episodes, tb_log_name, eval_log_path, reset_num_timesteps)
#     245 def learn(
#     246     self,
#     247     total_timesteps: int,
#    (...)
#     255     reset_num_timesteps: bool = True,
#     256 ) -> OffPolicyAlgorithm:
# --> 258     return super(DQN, self).learn(
#     259         total_timesteps=total_timesteps,
#     260         callback=callback,
#     261         log_interval=log_interval,
#     262         eval_env=eval_env,
#     263         eval_freq=eval_freq,
#     264         n_eval_episodes=n_eval_episodes,
#     265         tb_log_name=tb_log_name,
#     266         eval_log_path=eval_log_path,
#     267         reset_num_timesteps=reset_num_timesteps,
#     268     )
#
# File c:\Users\Willi\anaconda3\lib\site-packages\stable_baselines3\common\off_policy_algorithm.py:347, in OffPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, eval_env, eval_freq, n_eval_episodes, tb_log_name, eval_log_path, reset_num_timesteps)
#     344 callback.on_training_start(locals(), globals())
#     346 while self.num_timesteps < total_timesteps:
# --> 347     rollout = self.collect_rollouts(
#     348         self.env,
#     349         train_freq=self.train_freq,
#     350         action_noise=self.action_noise,
#     351         callback=callback,
#     352         learning_starts=self.learning_starts,
#     353         replay_buffer=self.replay_buffer,
#     354         log_interval=log_interval,
#     355     )
#     357     if rollout.continue_training is False:
#     358         break
#
# File c:\Users\Willi\anaconda3\lib\site-packages\stable_baselines3\common\off_policy_algorithm.py:580, in OffPolicyAlgorithm.collect_rollouts(self, env, callback, train_freq, replay_buffer, action_noise, learning_starts, log_interval)
#     577 actions, buffer_actions = self._sample_action(learning_starts, action_noise, env.num_envs)
#     579 # Rescale and perform action
# --> 580 new_obs, rewards, dones, infos = env.step(actions)
#     582 self.num_timesteps += env.num_envs
#     583 num_collected_steps += 1
#
# File c:\Users\Willi\anaconda3\lib\site-packages\stable_baselines3\common\vec_env\base_vec_env.py:162, in VecEnv.step(self, actions)
#     155 """
#     156 Step the environments with the given action
#     157
#     158 :param actions: the action
#     159 :return: observation, reward, done, information
#     160 """
#     161 self.step_async(actions)
# --> 162 return self.step_wait()
#
# File c:\Users\Willi\anaconda3\lib\site-packages\stable_baselines3\common\vec_env\dummy_vec_env.py:43, in DummyVecEnv.step_wait(self)
#      41 def step_wait(self) -> VecEnvStepReturn:
#      42     for env_idx in range(self.num_envs):
# ---> 43         obs, self.buf_rews[env_idx], self.buf_dones[env_idx], self.buf_infos[env_idx] = self.envs[env_idx].step(
#      44             self.actions[env_idx]
#      45         )
#      46         if self.buf_dones[env_idx]:
#      47             # save final observation where user can get it, then reset
#      48             self.buf_infos[env_idx]["terminal_observation"] = obs
#
# File c:\Users\Willi\anaconda3\lib\site-packages\stable_baselines3\common\monitor.py:90, in Monitor.step(self, action)
#      88 if self.needs_reset:
#      89     raise RuntimeError("Tried to step environment that needs reset")
# ---> 90 observation, reward, done, info = self.env.step(action)
#      91 self.rewards.append(reward)
#      92 if done:
#
# c:\Users\Willi\OneDrive\Research\Fixed_Battlespace.ipynb Cell 15' in BattleEnvironment.step(self, action)
#     <a href='vscode-notebook-cell:/c%3A/Users/Willi/OneDrive/Research/Fixed_Battlespace.ipynb#ch0000014?line=111'>112</a> self.friendly = 'blue'
#     <a href='vscode-notebook-cell:/c%3A/Users/Willi/OneDrive/Research/Fixed_Battlespace.ipynb#ch0000014?line=112'>113</a> self.opponent = 'red'
# --> <a href='vscode-notebook-cell:/c%3A/Users/Willi/OneDrive/Research/Fixed_Battlespace.ipynb#ch0000014?line=113'>114</a> self._process_action(random.randint(0, 3), self.team[self.friendly], self.team[self.opponent])
#     <a href='vscode-notebook-cell:/c%3A/Users/Willi/OneDrive/Research/Fixed_Battlespace.ipynb#ch0000014?line=115'>116</a> # Check if bullets hit and move them
#     <a href='vscode-notebook-cell:/c%3A/Users/Willi/OneDrive/Research/Fixed_Battlespace.ipynb#ch0000014?line=116'>117</a> for bullet in self.bullets:
#
# c:\Users\Willi\OneDrive\Research\Fixed_Battlespace.ipynb Cell 15' in BattleEnvironment._process_action(self, action, fteam, oteam)
#     <a href='vscode-notebook-cell:/c%3A/Users/Willi/OneDrive/Research/Fixed_Battlespace.ipynb#ch0000014?line=195'>196</a> new_fplane_pos = fplane.get_pos()
#     <a href='vscode-notebook-cell:/c%3A/Users/Willi/OneDrive/Research/Fixed_Battlespace.ipynb#ch0000014?line=196'>197</a> new_fplane_angle = fplane.heading
# --> <a href='vscode-notebook-cell:/c%3A/Users/Willi/OneDrive/Research/Fixed_Battlespace.ipynb#ch0000014?line=197'>198</a> new_oplane_pos = oplane.get_pos()
#     <a href='vscode-notebook-cell:/c%3A/Users/Willi/OneDrive/Research/Fixed_Battlespace.ipynb#ch0000014?line=198'>199</a> new_obase_pos = obase.get_pos()
#     <a href='vscode-notebook-cell:/c%3A/Users/Willi/OneDrive/Research/Fixed_Battlespace.ipynb#ch0000014?line=200'>201</a> new_dist_oplane = dist(new_oplane_pos, new_fplane_pos)
#
# c:\Users\Willi\OneDrive\Research\Fixed_Battlespace.ipynb Cell 9' in Plane.get_pos(self)
#      <a href='vscode-notebook-cell:/c%3A/Users/Willi/OneDrive/Research/Fixed_Battlespace.ipynb#ch0000008?line=69'>70</a> def get_pos(self):
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Willi/OneDrive/Research/Fixed_Battlespace.ipynb#ch0000008?line=70'>71</a>     image, rect = blitRotate(self.image, self.rect.center, (self.w/2, self.h/2), self.heading)
#      <a href='vscode-notebook-cell:/c%3A/Users/Willi/OneDrive/Research/Fixed_Battlespace.ipynb#ch0000008?line=71'>72</a>     return (rect.centerx, rect.centery)
#
# c:\Users\Willi\OneDrive\Research\Fixed_Battlespace.ipynb Cell 7' in blitRotate(image, pos, originPos, angle)
#      <a href='vscode-notebook-cell:/c%3A/Users/Willi/OneDrive/Research/Fixed_Battlespace.ipynb#ch0000006?line=16'>17</a> rotated_image_center = (pos[0] - rotated_offset.x, pos[1] - rotated_offset.y)
#      <a href='vscode-notebook-cell:/c%3A/Users/Willi/OneDrive/Research/Fixed_Battlespace.ipynb#ch0000006?line=18'>19</a> # get a rotated image
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Willi/OneDrive/Research/Fixed_Battlespace.ipynb#ch0000006?line=19'>20</a> rotated_image = pygame.transform.rotate(image, angle)
#      <a href='vscode-notebook-cell:/c%3A/Users/Willi/OneDrive/Research/Fixed_Battlespace.ipynb#ch0000006?line=20'>21</a> rotated_image_rect = rotated_image.get_rect(center = rotated_image_center)
#      <a href='vscode-notebook-cell:/c%3A/Users/Willi/OneDrive/Research/Fixed_Battlespace.ipynb#ch0000006?line=22'>23</a> return rotated_image, rotated_image_rect
#
# KeyboardInterrupt:

# %% [markdown]
# ----------- Evaluation ----------

# %%
env = BattleEnvironment()
episodes = 100
for episode in range(episodes): # Evaluates the model n times
    state = env.reset()
    score = 0
    while not env.done:
        action, _states = model.predict(state)
        n_state, red_reward, done, info = env.step(action)
        score += red_reward
    print('Episode:{} Score:{}'.format(episode+1, score))
env.show_wins()
