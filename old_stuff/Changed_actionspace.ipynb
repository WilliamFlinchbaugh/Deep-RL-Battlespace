# %%
# %pip install pygame
# %pip install numpy
# %pip install gym
# Out:
# Requirement already satisfied: pygame in e:\anaconda\lib\site-packages (2.1.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: numpy in e:\anaconda\lib\site-packages (1.21.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: gym in e:\anaconda\lib\site-packages (0.21.0)
# Requirement already satisfied: cloudpickle>=1.2.0 in e:\anaconda\lib\site-packages (from gym) (2.0.0)
# Requirement already satisfied: numpy>=1.18.0 in e:\anaconda\lib\site-packages (from gym) (1.21.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import random
import pygame
from pygame.locals import *
import numpy as np
import numpy.linalg as LA
import math
from collections import defaultdict
import gym
from gym import spaces
import os
import sys
os.environ['KMP_DUPLICATE_LIB_OK']='True'
# Out:
# pygame 2.1.0 (SDL 2.0.16, Python 3.9.12)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
WHITE = (255, 255, 255)
RED = (138, 24, 26)
BLUE = (0, 93, 135)
BLACK = (0, 0, 0)
DISP_WIDTH = 1000
DISP_HEIGHT = 1000
FPS = pygame.time.Clock()

# %% [markdown]
# ---------- Default Config ----------

# %%
DEFAULT_CONFIG_DICT = {
    'time_step': 0.1, # hours per time step
    'plane_speed': 500, # mph
    'bullet_speed': 700, # mph
    'max_time': 10, # hours the epoch can last
    'show_viz': False, # show the pygame animation
    'step_turn': 15, # degrees to turn per step
    'hit_base_reward': 100, # reward for shooting enemy base
    'hit_plane_reward': 100, # reward for shooting enemy plane
    'miss_punishment': -1, # punishment for missing a shot
    'too_long_punishment': 0, # punishment for taking too long to end the game
    'closer_to_base_reward': 0, # reward for getting closer to enemy base
    'closer_to_plane_reward': 0, # reward for getting closer to enemy plane
    'turn_to_base_reward': 0, # reward for turning towards the enemy base
    'turn_to_plane_reward': 0, # reward for turning towards the enemy plane
    'red_policy': 'ai', # policy for the red team
    'blue_policy': 'random' # policy for the blue team
}

# %% [markdown]
# ---------- Helper Functions ----------

# %%
def get_angle(p1, p0):
    return math.degrees(math.atan2(p1[1]-p0[1],p1[0]-p0[0]))

def dist(p1,p0):
    return math.sqrt((p1[0]-p0[0])**2 + (p1[1]-p0[1])**2)

def blitRotate(image, pos, originPos, angle):

    # offset from pivot to center
    image_rect = image.get_rect(topleft = (pos[0] - originPos[0], pos[1]-originPos[1]))
    offset_center_to_pivot = pygame.math.Vector2(pos) - image_rect.center
    
    # roatated offset from pivot to center
    rotated_offset = offset_center_to_pivot.rotate(-angle)

    # rotated image center
    rotated_image_center = (pos[0] - rotated_offset.x, pos[1] - rotated_offset.y)

    # get a rotated image
    rotated_image = pygame.transform.rotate(image, angle)
    rotated_image_rect = rotated_image.get_rect(center = rotated_image_center)

    return rotated_image, rotated_image_rect

def calc_new_xy(old_xy, speed, time, angle):
    new_x = old_xy[0] + (speed*time*math.cos(-math.radians(angle)))
    new_y = old_xy[1] + (speed*time*math.sin(-math.radians(angle)))
    return (new_x, new_y)

# %% [markdown]
# ---------- Plane Class ----------

# %%
class Plane:
    def __init__(self, team): 
        self.team = team
        self.image = pygame.image.load(f"Images/{team}_plane.png")
        self.w, self.h = self.image.get_size()
        self.heading = 0
        self.rect = self.image.get_rect()
        self.reset()

    def reset(self):
        if self.team == 'red':
            x = (DISP_WIDTH - self.w/2)/2 * random.random()
            y = (DISP_HEIGHT - self.h/2) * random.random()
            self.rect.center = (x, y)
            self.heading = 90 * random.random() if random.random() < .5 else 90 * random.random() + 270
            
        else:
            x = (DISP_WIDTH - self.w/2)/2 * random.random() + (DISP_WIDTH - self.w/2)/2
            y = (DISP_HEIGHT - self.h/2) * random.random()
            self.rect.center = (x, y)
            self.heading = 180 * random.random() + 90
        
    def rotate(self, angle):
        self.heading += angle

    def set_heading(self, heading):
        self.heading = heading

    def forward(self, speed, time):
        oldpos = self.rect.center
        self.rect.center = calc_new_xy(oldpos, speed, time, self.heading)

    def draw(self, surface):
        image, rect = blitRotate(self.image, self.rect.center, (self.w/2, self.h/2), self.heading)
        surface.blit(image, rect)

    def update(self):
        # Keep player on the screen
        if self.rect.left < 0:
            self.rect.left = 0
        if self.rect.right > DISP_WIDTH:
            self.rect.right = DISP_WIDTH
        if self.rect.top <= 0:
            self.rect.top = 0
        if self.rect.bottom >= DISP_HEIGHT:
            self.rect.bottom = DISP_HEIGHT

    def get_pos(self):
        return self.rect.center

# %% [markdown]
# ----------- Base Class ----------

# %%
class Base:
    
    def __init__(self, team):
        self.team = team
        self.image = pygame.image.load(f"Images/{team}_base.png")
        self.w, self.h = self.image.get_size()
        self.rect = self.image.get_rect()
        self.reset()
        
    def reset(self):
        if self.team == 'red':
            x = (DISP_WIDTH - self.w/2)/2 * random.random()
            y = (DISP_HEIGHT - self.h/2) * random.random()
            self.rect.center = (x, y)
        else:
            x = (DISP_WIDTH - self.w/2)/2 * random.random() + (DISP_WIDTH - self.w/2)/2
            y = (DISP_HEIGHT - self.h/2) * random.random()
            self.rect.center = (x, y)

    def draw(self, surface):
        surface.blit(self.image, self.rect)
            
    def get_pos(self):
        return self.rect.center

# %% [markdown]
# ---------- Bullet Class ----------

# %%
class Bullet(pygame.sprite.Sprite):
    def __init__(self, x, y, angle, speed, fteam, oteam):
        pygame.sprite.Sprite.__init__(self)
        self.off_screen = False
        self.image = pygame.Surface((8, 4), pygame.SRCALPHA)
        self.fteam = fteam
        self.color = RED if self.fteam == 'red' else BLUE
        self.oteam = oteam
        self.image.fill(self.color)
        self.rect = self.image.get_rect(center=(x, y))
        self.w, self.h = self.image.get_size()
        self.heading = angle + (random.random() * 10 - 5)
        self.pos = (x, y)
        self.speed = speed

    def update(self, screen_width, screen_height, time):
        oldpos = self.rect.center
        self.rect.center = calc_new_xy(oldpos, self.speed, time, self.heading)
        if self.rect.centerx > screen_width or self.rect.centerx < 0 or self.rect.centery > screen_height or self.rect.centery < 0:
            return 'miss'
        for plane in self.oteam['planes']:
            if self.rect.colliderect(plane.rect):
                return 'plane'
        if self.rect.colliderect(self.oteam['base'].rect):
            return 'base'
        return 'none'

    def draw(self, surface):
        image, rect = blitRotate(self.image, self.rect.center, (self.w/2, self.h/2), self.heading)
        surface.blit(image, rect)

# %% [markdown]
# ----------- Battle Environment ----------

# %%
class BattleEnvironment(gym.Env):
    def __init__(self, config: dict=DEFAULT_CONFIG_DICT):
        super(BattleEnvironment, self).__init__()
        self.width = DISP_WIDTH
        self.height = DISP_HEIGHT
        self.max_time = config['max_time']
        high = np.array( # Observation space: fplane_pos_x, fplane_pos_y, fplane_angle, dist_obase, dist_oplane, rel_angle_obase, rel_angle_oplane
            [
                self.width,
                self.height,
                720,
                math.sqrt(math.pow(self.width, 2) + math.pow(self.height, 2)),
                math.sqrt(math.pow(self.width, 2) + math.pow(self.height, 2)),
                720,
                720,
                self.max_time,
            ],
            dtype=np.float32,
        )
        # AI agent: 1.forwards, 2.shoot, 3.left, 4.right
        # Random agent: 1.forwards, 2.shoot, 3.turn to enemy plane, 4.turn to enemy base
        self.action_space = spaces.Discrete(4)
        self.observation_space = spaces.Box(-high, high, dtype=np.float32)
        self.team = {}
        self.team['red'] = {}
        self.team['blue'] = {}
        self.team['red']['base'] = Base('red')
        self.team['blue']['base'] = Base('blue')
        self.team['red']['planes'] = []
        self.team['red']['planes'].append(Plane('red'))
        self.team['blue']['planes'] = []
        self.team['blue']['planes'].append(Plane('blue'))
        self.team['red']['wins'] = 0
        self.team['blue']['wins'] = 0
        self.team['red']['policy'] = config['red_policy']
        self.team['blue']['policy'] = config['blue_policy']
        self.ties = 0
        self.bullets = []
        self.speed = config['plane_speed']
        self.bullet_speed = config['bullet_speed']
        self.total_time = 0 # in hours
        self.time_step = config['time_step']
        self.show = config['show_viz']
        self.step_turn = config['step_turn']
        self.hit_base_reward = config['hit_base_reward']
        self.hit_plane_reward = config['hit_plane_reward']
        self.miss_punishment = config['miss_punishment']
        self.too_long_punishment = config['too_long_punishment']
        self.closer_to_base_reward = config['closer_to_base_reward']
        self.closer_to_plane_reward = config['closer_to_plane_reward']
        self.turn_to_base_reward = config['turn_to_base_reward']
        self.turn_to_plane_reward = config['turn_to_plane_reward']

    def get_done(self): return self.done
    
    def _get_observation(self):
        # This code will all have to be changed when adding multiple planes
        fplane = self.team['red']['planes'][0]
        oplane = self.team['blue']['planes'][0]
        obase = self.team['red']['base']

        fplane_pos = fplane.get_pos()
        fplane_angle = fplane.heading
        oplane_pos = oplane.get_pos()
        obase_pos = obase.get_pos()

        dist_oplane = dist(oplane_pos, fplane_pos)
        dist_obase = dist(obase_pos, fplane_pos)

        angle_to_oplane = get_angle(oplane_pos, fplane_pos)
        angle_to_obase = get_angle(obase_pos, fplane_pos)
        rel_angle_oplane = (angle_to_oplane - fplane_angle) % 360
        rel_angle_obase = (angle_to_obase - fplane_angle) % 360
        
        self.observation = (fplane_pos[0], fplane_pos[1], fplane_angle, dist_obase, dist_oplane, rel_angle_obase, rel_angle_oplane, self.total_time)
        return np.array(self.observation, dtype=np.float32)

        
    def reset(self): # return observation
        self.done = False
        self.winner = 'none'

        self.team['red']['base'].reset()
        self.team['blue']['base'].reset()

        for plane in self.team['red']['planes']:
            plane.reset()
        for plane in self.team['blue']['planes']:
            plane.reset()

        self.total_time = 0
        self.bullets = []

        if self.show:
            pygame.init()
            self.display = pygame.display.set_mode((DISP_WIDTH, DISP_HEIGHT))
            pygame.display.set_caption("Battlespace Simulator")

        return self._get_observation()

    def step(self, action): # return observation, reward, done, info
        reward = 0

        # Check if over time, if so, end game in tie
        self.total_time += self.time_step
        if self.total_time >= self.max_time:
            self.done = True
            self.ties += 1
            if self.show:
                self.render()
                print("Draw")
            return self._get_observation(), 0, self.done, {}

        # Red turn
        self.friendly = 'red'
        self.opponent = 'blue'
        reward += self._process_action(action, self.team[self.friendly], self.team[self.opponent])
        
        # Blue turn
        self.friendly = 'blue'
        self.opponent = 'red'
        self._process_action(random.randint(0, 3), self.team[self.friendly], self.team[self.opponent])        

        # Check if bullets hit and move them
        for bullet in self.bullets:
            outcome = bullet.update(self.width, self.height, self.time_step)
            if outcome == 'miss':
                reward += self.miss_punishment
                self.bullets.pop(self.bullets.index(bullet))
            elif outcome == 'plane' or outcome == 'base': # If a bullet hit
                self.winner = bullet.fteam
                self.team[self.winner]['wins'] += 1
                self.done = True
                reward = reward + self.hit_base_reward if outcome == 'base' else reward + self.hit_plane_reward
                if self.show:
                    self.render()
                    print(f"{self.winner} wins")
                return self._get_observation(), reward, self.done, {}
            
        # Check if past half of max time and give punishment
        if (self.total_time > self.max_time//2):
            reward += self.too_long_punishment

        # Continue game
        if self.show:
            self.render()
        return self._get_observation(), reward, self.done, {}
    
    def _process_action(self, action, fteam, oteam): # friendly and opponent
        policy = fteam['policy']
        reward = 0

        fplane = fteam['planes'][0]
        oplane = oteam['planes'][0]
        obase = oteam['base']

        fplane_pos = fplane.get_pos()
        fplane_angle = fplane.heading
        oplane_pos = oplane.get_pos()
        obase_pos = obase.get_pos()

        dist_oplane = dist(oplane_pos, fplane_pos)
        dist_obase = dist(obase_pos, fplane_pos)

        angle_to_oplane = get_angle(oplane_pos, fplane_pos)
        angle_to_obase = get_angle(obase_pos, fplane_pos)
        rel_angle_oplane = (angle_to_oplane - fplane_angle) % 360
        rel_angle_obase = (angle_to_obase - fplane_angle) % 360

        # --------------- FORWARDS ---------------
        if action == 0: 
            fplane.forward(self.speed, self.time_step)

         # --------------- SHOOT ---------------
        elif action == 1:
            self.bullets.append(Bullet(fplane_pos[0], fplane_pos[1], fplane_angle, self.bullet_speed, self.friendly, oteam))
            fplane.forward(self.speed, self.time_step)
        
        # --------------- TURN RIGHT or TURN TO ENEMY PLANE ---------------
        elif action == 2: # Turn right
            if policy == 'ai':
                fplane.rotate(-self.step_turn)
                fplane.forward(self.speed, self.time_step)
            else:
                if rel_angle_oplane < 0:
                    fplane.rotate(-self.step_turn)
                else:
                    fplane.rotate(self.step_turn)
                fplane.forward(self.speed, self.time_step)

        # ---------------- TURN LEFT or TURN TO ENEMY BASE ----------------
        elif action == 3:
            if policy == 'ai':
                fplane.rotate(self.step_turn)
                fplane.forward(self.speed, self.time_step)
            else:
                if rel_angle_obase < 0:
                    fplane.rotate(-self.step_turn)
                else:
                    fplane.rotate(self.step_turn)
                fplane.forward(self.speed, self.time_step)

        # ---------------- GIVE REWARDS IF CLOSER (DIST OR ANGLE) ----------------
        new_fplane_pos = fplane.get_pos()
        new_fplane_angle = fplane.heading
        new_oplane_pos = oplane.get_pos()
        new_obase_pos = obase.get_pos()

        new_dist_oplane = dist(new_oplane_pos, new_fplane_pos)
        new_dist_obase = dist(new_obase_pos, new_fplane_pos)

        new_angle_to_oplane = get_angle(new_oplane_pos, new_fplane_pos)
        new_angle_to_obase = get_angle(new_obase_pos, new_fplane_pos)
        new_rel_angle_oplane = (new_angle_to_oplane - new_fplane_angle) % 360
        new_rel_angle_obase = (new_angle_to_obase - new_fplane_angle) % 360

        if new_dist_oplane < dist_oplane: # If got closer to enemy plane
            reward += self.closer_to_plane_reward

        if new_dist_obase < dist_obase: # If got closer to enemy base
            reward += self.closer_to_base_reward

        if math.fabs(new_rel_angle_oplane) < math.fabs(rel_angle_oplane): # If aiming closer to enemy plane
            reward += self.turn_to_plane_reward

        if math.fabs(new_rel_angle_obase) < math.fabs(rel_angle_obase): # If aiming closer to enemy base
            reward += self.turn_to_base_reward

        return reward

    def draw_shot(self, hit, friendly_pos, target_pos, team):
        color = BLACK
        color = RED if team == 'red' else BLUE
        if not hit: target_pos = (target_pos[0] + (random.random() * 2 - 1) * 100, target_pos[1] + (random.random() * 2 - 1) * 100)
        self.shot_history.append((hit, friendly_pos, target_pos, color))
    
    def winner_screen(self):
        if self.show:
            font = pygame.font.Font('freesansbold.ttf', 32)
            if self.winner != 'none':
                text = font.render(f"THE WINNER IS {self.winner.upper()}", True, BLACK)
                textRect = text.get_rect()
                textRect.center = (DISP_WIDTH//2, DISP_HEIGHT//2)
            else:
                text = font.render(f"THE GAME IS A TIE", True, BLACK)
                textRect = text.get_rect()
                textRect.center = (DISP_WIDTH//2, DISP_HEIGHT//2)
            self.display.blit(text, textRect)

    def show_wins(self):
        print("Wins by red:", self.team['red']['wins'])
        print("Wins by blue:", self.team['blue']['wins'])
        print("Tied games:", self.ties)

    def render(self, mode="human"):
        if self.show: # Just to ensure it won't render if self.show == False
            for event in pygame.event.get():
                # Check for KEYDOWN event
                if event.type == KEYDOWN:
                    # If the Esc key is pressed, then exit the main loop
                    if event.key == K_ESCAPE:
                        pygame.quit()
                        sys.exit()
                        return
                # Check for QUIT event. If QUIT, then set running to false.
                elif event.type == QUIT:
                    pygame.quit()
                    sys.exit()
                    return
                    
            # Fill background
            self.display.fill(WHITE)

            # Draw bullets
            for bullet in self.bullets:
                bullet.draw(self.display)
                    
            # Draw bases
            self.team['red']['base'].draw(self.display)
            self.team['blue']['base'].draw(self.display)

            # Draw planes
            for plane in self.team['red']['planes']:
                plane.update()
                plane.draw(self.display)
            for plane in self.team['blue']['planes']:
                plane.update()
                plane.draw(self.display)

            # Winner Screen
            if self.done:
                font = pygame.font.Font('freesansbold.ttf', 32)
                if self.winner != 'none':
                    text = font.render(f"THE WINNER IS {self.winner.upper()}", True, BLACK)
                    textRect = text.get_rect()
                    textRect.center = (DISP_WIDTH//2, DISP_HEIGHT//2)
                else:
                    text = font.render(f"THE GAME IS A TIE", True, BLACK)
                    textRect = text.get_rect()
                    textRect.center = (DISP_WIDTH//2, DISP_HEIGHT//2)
                self.display.blit(text, textRect)
                pygame.display.update()
                pygame.time.wait(3000)
                pygame.quit()
                return
            
            pygame.display.update()
            FPS.tick(7)

# %% [markdown]
# ---------- Hyperparameter Tuning ----------

# %%
# %pip install torch==1.10.2+cu113 torchvision==0.11.3+cu113 torchaudio===0.10.2+cu113 -f https://download.pytorch.org/whl/cu113/torch_stable.html
# %pip install stable-baselines3[extra] optuna
# Out:
# Looking in links: https://download.pytorch.org/whl/cu113/torch_stable.html
# Requirement already satisfied: torch==1.10.2+cu113 in e:\anaconda\lib\site-packages (1.10.2+cu113)
# Requirement already satisfied: torchvision==0.11.3+cu113 in e:\anaconda\lib\site-packages (0.11.3+cu113)
# Requirement already satisfied: torchaudio===0.10.2+cu113 in e:\anaconda\lib\site-packages (0.10.2+cu113)
# Requirement already satisfied: typing-extensions in e:\anaconda\lib\site-packages (from torch==1.10.2+cu113) (4.1.1)
# Requirement already satisfied: numpy in e:\anaconda\lib\site-packages (from torchvision==0.11.3+cu113) (1.21.0)
# Requirement already satisfied: pillow!=8.3.0,>=5.3.0 in e:\anaconda\lib\site-packages (from torchvision==0.11.3+cu113) (9.0.1)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: stable-baselines3[extra] in e:\anaconda\lib\site-packages (1.5.0)
# Requirement already satisfied: optuna in e:\anaconda\lib\site-packages (2.10.1)
# Requirement already satisfied: matplotlib in e:\anaconda\lib\site-packages (from stable-baselines3[extra]) (3.5.1)
# Requirement already satisfied: torch>=1.8.1 in e:\anaconda\lib\site-packages (from stable-baselines3[extra]) (1.10.2+cu113)
# Requirement already satisfied: numpy in e:\anaconda\lib\site-packages (from stable-baselines3[extra]) (1.21.0)
# Requirement already satisfied: cloudpickle in e:\anaconda\lib\site-packages (from stable-baselines3[extra]) (2.0.0)
# Requirement already satisfied: gym==0.21 in e:\anaconda\lib\site-packages (from stable-baselines3[extra]) (0.21.0)
# Requirement already satisfied: pandas in e:\anaconda\lib\site-packages (from stable-baselines3[extra]) (1.4.2)
# Requirement already satisfied: psutil in e:\anaconda\lib\site-packages (from stable-baselines3[extra]) (5.8.0)
# Requirement already satisfied: opencv-python in e:\anaconda\lib\site-packages (from stable-baselines3[extra]) (4.6.0.66)
# Requirement already satisfied: ale-py~=0.7.4 in e:\anaconda\lib\site-packages (from stable-baselines3[extra]) (0.7.5)
# Requirement already satisfied: tensorboard>=2.2.0 in e:\anaconda\lib\site-packages (from stable-baselines3[extra]) (2.9.0)
# Requirement already satisfied: pillow in e:\anaconda\lib\site-packages (from stable-baselines3[extra]) (9.0.1)
# Requirement already satisfied: autorom[accept-rom-license]~=0.4.2 in e:\anaconda\lib\site-packages (from stable-baselines3[extra]) (0.4.2)
# Requirement already satisfied: cliff in e:\anaconda\lib\site-packages (from optuna) (3.10.1)
# Requirement already satisfied: PyYAML in e:\anaconda\lib\site-packages (from optuna) (6.0)
# Requirement already satisfied: scipy!=1.4.0 in e:\anaconda\lib\site-packages (from optuna) (1.7.3)
# Requirement already satisfied: cmaes>=0.8.2 in e:\anaconda\lib\site-packages (from optuna) (0.8.2)
# Requirement already satisfied: packaging>=20.0 in e:\anaconda\lib\site-packages (from optuna) (21.3)
# Requirement already satisfied: colorlog in e:\anaconda\lib\site-packages (from optuna) (6.6.0)
# Requirement already satisfied: tqdm in e:\anaconda\lib\site-packages (from optuna) (4.64.0)
# Requirement already satisfied: sqlalchemy>=1.1.0 in e:\anaconda\lib\site-packages (from optuna) (1.4.32)
# Requirement already satisfied: alembic in e:\anaconda\lib\site-packages (from optuna) (1.8.0)
# Requirement already satisfied: importlib-metadata>=4.10.0 in e:\anaconda\lib\site-packages (from ale-py~=0.7.4->stable-baselines3[extra]) (4.11.3)
# Requirement already satisfied: importlib-resources in e:\anaconda\lib\site-packages (from ale-py~=0.7.4->stable-baselines3[extra]) (5.7.1)
# Requirement already satisfied: requests in e:\anaconda\lib\site-packages (from autorom[accept-rom-license]~=0.4.2->stable-baselines3[extra]) (2.27.1)
# Requirement already satisfied: click in e:\anaconda\lib\site-packages (from autorom[accept-rom-license]~=0.4.2->stable-baselines3[extra]) (8.0.4)
# Requirement already satisfied: AutoROM.accept-rom-license in e:\anaconda\lib\site-packages (from autorom[accept-rom-license]~=0.4.2->stable-baselines3[extra]) (0.4.2)
# Requirement already satisfied: zipp>=0.5 in e:\anaconda\lib\site-packages (from importlib-metadata>=4.10.0->ale-py~=0.7.4->stable-baselines3[extra]) (3.7.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in e:\anaconda\lib\site-packages (from packaging>=20.0->optuna) (3.0.4)
# Requirement already satisfied: greenlet!=0.4.17 in e:\anaconda\lib\site-packages (from sqlalchemy>=1.1.0->optuna) (1.1.1)
# Requirement already satisfied: wheel>=0.26 in e:\anaconda\lib\site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (0.37.1)
# Requirement already satisfied: markdown>=2.6.8 in e:\anaconda\lib\site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (3.3.4)
# Requirement already satisfied: werkzeug>=1.0.1 in e:\anaconda\lib\site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (2.0.3)
# Requirement already satisfied: protobuf>=3.9.2 in e:\anaconda\lib\site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (3.19.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in e:\anaconda\lib\site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (1.33.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in e:\anaconda\lib\site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (0.4.6)
# Requirement already satisfied: setuptools>=41.0.0 in e:\anaconda\lib\site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (62.3.4)
# Requirement already satisfied: absl-py>=0.4 in e:\anaconda\lib\site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (1.1.0)
# Requirement already satisfied: grpcio>=1.24.3 in e:\anaconda\lib\site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (1.42.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in e:\anaconda\lib\site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (1.8.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in e:\anaconda\lib\site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]) (0.6.1)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in e:\anaconda\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->stable-baselines3[extra]) (4.2.2)
# Requirement already satisfied: six>=1.9.0 in e:\anaconda\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->stable-baselines3[extra]) (1.16.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in e:\anaconda\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->stable-baselines3[extra]) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in e:\anaconda\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->stable-baselines3[extra]) (4.7.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in e:\anaconda\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->stable-baselines3[extra]) (1.3.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in e:\anaconda\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.2.0->stable-baselines3[extra]) (0.4.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in e:\anaconda\lib\site-packages (from requests->autorom[accept-rom-license]~=0.4.2->stable-baselines3[extra]) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in e:\anaconda\lib\site-packages (from requests->autorom[accept-rom-license]~=0.4.2->stable-baselines3[extra]) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in e:\anaconda\lib\site-packages (from requests->autorom[accept-rom-license]~=0.4.2->stable-baselines3[extra]) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in e:\anaconda\lib\site-packages (from requests->autorom[accept-rom-license]~=0.4.2->stable-baselines3[extra]) (2.0.4)
# Requirement already satisfied: oauthlib>=3.0.0 in e:\anaconda\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->stable-baselines3[extra]) (3.2.0)
# Requirement already satisfied: typing-extensions in e:\anaconda\lib\site-packages (from torch>=1.8.1->stable-baselines3[extra]) (4.1.1)
# Requirement already satisfied: Mako in e:\anaconda\lib\site-packages (from alembic->optuna) (1.2.0)
# Requirement already satisfied: colorama in e:\anaconda\lib\site-packages (from click->autorom[accept-rom-license]~=0.4.2->stable-baselines3[extra]) (0.4.4)
# Requirement already satisfied: stevedore>=2.0.1 in e:\anaconda\lib\site-packages (from cliff->optuna) (3.5.0)
# Requirement already satisfied: autopage>=0.4.0 in e:\anaconda\lib\site-packages (from cliff->optuna) (0.5.1)
# Requirement already satisfied: cmd2>=1.0.0 in e:\anaconda\lib\site-packages (from cliff->optuna) (2.4.1)
# Requirement already satisfied: pbr!=2.1.0,>=2.0.0 in e:\anaconda\lib\site-packages (from cliff->optuna) (5.9.0)
# Requirement already satisfied: PrettyTable>=0.7.2 in e:\anaconda\lib\site-packages (from cliff->optuna) (3.3.0)
# Requirement already satisfied: attrs>=16.3.0 in e:\anaconda\lib\site-packages (from cmd2>=1.0.0->cliff->optuna) (21.4.0)
# Requirement already satisfied: wcwidth>=0.1.7 in e:\anaconda\lib\site-packages (from cmd2>=1.0.0->cliff->optuna) (0.2.5)
# Requirement already satisfied: pyperclip>=1.6 in e:\anaconda\lib\site-packages (from cmd2>=1.0.0->cliff->optuna) (1.8.2)
# Requirement already satisfied: pyreadline3 in e:\anaconda\lib\site-packages (from cmd2>=1.0.0->cliff->optuna) (3.4.1)
# Requirement already satisfied: MarkupSafe>=0.9.2 in e:\anaconda\lib\site-packages (from Mako->alembic->optuna) (2.0.1)
# Requirement already satisfied: fonttools>=4.22.0 in e:\anaconda\lib\site-packages (from matplotlib->stable-baselines3[extra]) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in e:\anaconda\lib\site-packages (from matplotlib->stable-baselines3[extra]) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in e:\anaconda\lib\site-packages (from matplotlib->stable-baselines3[extra]) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in e:\anaconda\lib\site-packages (from matplotlib->stable-baselines3[extra]) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in e:\anaconda\lib\site-packages (from pandas->stable-baselines3[extra]) (2021.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
import optuna
from stable_baselines3 import PPO
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.vec_env import DummyVecEnv, VecFrameStack

# %%
LOG_DIR = './logs/'
OPT_DIR = './opt/'
if not os.path.exists(LOG_DIR):
    os.makedirs(LOG_DIR)
if not os.path.exists(OPT_DIR):
    os.makedirs(OPT_DIR)

# %%
def optimize_ppo(trial): 
    return {
        'n_steps':trial.suggest_int('n_steps', 2048, 8192),
        'gamma':trial.suggest_loguniform('gamma', 0.8, 0.9999),
        'learning_rate':trial.suggest_loguniform('learning_rate', 1e-5, 1e-4),
        'clip_range':trial.suggest_uniform('clip_range', 0.1, 0.4),
        'gae_lambda':trial.suggest_uniform('gae_lambda', 0.8, 0.99)
    }

# %%
def optimize_agent(trial):
    try:
        model_params = optimize_ppo(trial) 

        # Create environment 
        env = BattleEnvironment()
        env = Monitor(env, LOG_DIR)
        env = DummyVecEnv([lambda: env])
        env = VecFrameStack(env, 4, channels_order='last')

        model = PPO('MlpPolicy', env, tensorboard_log=LOG_DIR, verbose=0, **model_params)
        model.learn(total_timesteps=400000)

        # Evaluate model 
        mean_reward, _ = evaluate_policy(model, env, n_eval_episodes=5)

        SAVE_PATH = os.path.join(OPT_DIR, 'trial_{}_best_model'.format(trial.number))
        model.save(SAVE_PATH)

        return mean_reward
    except Exception as e:
        return -1000

# %%
study = optuna.create_study(direction='maximize')
study.optimize(optimize_agent, n_trials=15)
# Out:
# [I 2022-06-27 12:09:15,036] A new study created in memory with name: no-name-4b634803-e168-44d4-9b2c-43a6f6c1ff73
# e:\Anaconda\lib\site-packages\stable_baselines3\ppo\ppo.py:140: UserWarning: You have specified a mini-batch size of 64, but because the `RolloutBuffer` is of size `n_steps * n_envs = 5058`, after every 79 untruncated mini-batches, there will be a truncated mini-batch of size 2
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=5058 and n_envs=1)
#   warnings.warn(
# [I 2022-06-27 12:31:14,783] Trial 0 finished with value: 487.6 and parameters: {'n_steps': 5058, 'gamma': 0.916284227537185, 'learning_rate': 2.447493121513805e-05, 'clip_range': 0.23938406335264115, 'gae_lambda': 0.8784354563456847}. Best is trial 0 with value: 487.6.
# e:\Anaconda\lib\site-packages\stable_baselines3\ppo\ppo.py:140: UserWarning: You have specified a mini-batch size of 64, but because the `RolloutBuffer` is of size `n_steps * n_envs = 4045`, after every 63 untruncated mini-batches, there will be a truncated mini-batch of size 13
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=4045 and n_envs=1)
#   warnings.warn(
# [I 2022-06-27 12:53:00,440] Trial 1 finished with value: 51.8 and parameters: {'n_steps': 4045, 'gamma': 0.9002775538176193, 'learning_rate': 8.901026086306578e-05, 'clip_range': 0.275010638223514, 'gae_lambda': 0.8501943077071829}. Best is trial 0 with value: 487.6.
# e:\Anaconda\lib\site-packages\stable_baselines3\ppo\ppo.py:140: UserWarning: You have specified a mini-batch size of 64, but because the `RolloutBuffer` is of size `n_steps * n_envs = 6786`, after every 106 untruncated mini-batches, there will be a truncated mini-batch of size 2
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=6786 and n_envs=1)
#   warnings.warn(
# [I 2022-06-27 13:13:59,398] Trial 2 finished with value: 289.0 and parameters: {'n_steps': 6786, 'gamma': 0.928650884381476, 'learning_rate': 2.159138303035592e-05, 'clip_range': 0.2201831666881589, 'gae_lambda': 0.8820408484234588}. Best is trial 0 with value: 487.6.
# e:\Anaconda\lib\site-packages\stable_baselines3\ppo\ppo.py:140: UserWarning: You have specified a mini-batch size of 64, but because the `RolloutBuffer` is of size `n_steps * n_envs = 5856`, after every 91 untruncated mini-batches, there will be a truncated mini-batch of size 32
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=5856 and n_envs=1)
#   warnings.warn(
# [I 2022-06-27 13:36:54,667] Trial 3 finished with value: -159.0 and parameters: {'n_steps': 5856, 'gamma': 0.8144688164631025, 'learning_rate': 7.313842229947817e-05, 'clip_range': 0.22541836452242103, 'gae_lambda': 0.9188935063690076}. Best is trial 0 with value: 487.6.
# e:\Anaconda\lib\site-packages\stable_baselines3\ppo\ppo.py:140: UserWarning: You have specified a mini-batch size of 64, but because the `RolloutBuffer` is of size `n_steps * n_envs = 2459`, after every 38 untruncated mini-batches, there will be a truncated mini-batch of size 27
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=2459 and n_envs=1)
#   warnings.warn(
# [I 2022-06-27 13:58:54,703] Trial 4 finished with value: 56.0 and parameters: {'n_steps': 2459, 'gamma': 0.8462660082527512, 'learning_rate': 5.3260869260182926e-05, 'clip_range': 0.24040818996359845, 'gae_lambda': 0.8728791593854517}. Best is trial 0 with value: 487.6.
# e:\Anaconda\lib\site-packages\stable_baselines3\ppo\ppo.py:140: UserWarning: You have specified a mini-batch size of 64, but because the `RolloutBuffer` is of size `n_steps * n_envs = 7582`, after every 118 untruncated mini-batches, there will be a truncated mini-batch of size 30
# We recommend using a `batch_size` that is a factor of `n_steps * n_envs`.
# Info: (n_steps=7582 and n_envs=1)
#   warnings.warn(
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\William\OneDrive\Research\Changed_actionspace.ipynb Cell 22' in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/William/OneDrive/Research/Changed_actionspace.ipynb#ch0000021?line=0'>1</a> study = optuna.create_study(direction='maximize')
# ----> <a href='vscode-notebook-cell:/c%3A/Users/William/OneDrive/Research/Changed_actionspace.ipynb#ch0000021?line=1'>2</a> study.optimize(optimize_agent, n_trials=15)
#
# File e:\Anaconda\lib\site-packages\optuna\study\study.py:400, in Study.optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     392 if n_jobs != 1:
#     393     warnings.warn(
#     394         "`n_jobs` argument has been deprecated in v2.7.0. "
#     395         "This feature will be removed in v4.0.0. "
#     396         "See https://github.com/optuna/optuna/releases/tag/v2.7.0.",
#     397         FutureWarning,
#     398     )
# --> 400 _optimize(
#     401     study=self,
#     402     func=func,
#     403     n_trials=n_trials,
#     404     timeout=timeout,
#     405     n_jobs=n_jobs,
#     406     catch=catch,
#     407     callbacks=callbacks,
#     408     gc_after_trial=gc_after_trial,
#     409     show_progress_bar=show_progress_bar,
#     410 )
#
# File e:\Anaconda\lib\site-packages\optuna\study\_optimize.py:66, in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      64 try:
#      65     if n_jobs == 1:
# ---> 66         _optimize_sequential(
#      67             study,
#      68             func,
#      69             n_trials,
#      70             timeout,
#      71             catch,
#      72             callbacks,
#      73             gc_after_trial,
#      74             reseed_sampler_rng=False,
#      75             time_start=None,
#      76             progress_bar=progress_bar,
#      77         )
#      78     else:
#      79         if show_progress_bar:
#
# File e:\Anaconda\lib\site-packages\optuna\study\_optimize.py:163, in _optimize_sequential(study, func, n_trials, timeout, catch, callbacks, gc_after_trial, reseed_sampler_rng, time_start, progress_bar)
#     160         break
#     162 try:
# --> 163     trial = _run_trial(study, func, catch)
#     164 except Exception:
#     165     raise
#
# File e:\Anaconda\lib\site-packages\optuna\study\_optimize.py:213, in _run_trial(study, func, catch)
#     210     thread.start()
#     212 try:
# --> 213     value_or_values = func(trial)
#     214 except exceptions.TrialPruned as e:
#     215     # TODO(mamu): Handle multi-objective cases.
#     216     state = TrialState.PRUNED
#
# c:\Users\William\OneDrive\Research\Changed_actionspace.ipynb Cell 21' in optimize_agent(trial)
#       <a href='vscode-notebook-cell:/c%3A/Users/William/OneDrive/Research/Changed_actionspace.ipynb#ch0000020?line=8'>9</a> env = VecFrameStack(env, 4, channels_order='last')
#      <a href='vscode-notebook-cell:/c%3A/Users/William/OneDrive/Research/Changed_actionspace.ipynb#ch0000020?line=10'>11</a> model = PPO('MlpPolicy', env, tensorboard_log=LOG_DIR, verbose=0, **model_params)
# ---> <a href='vscode-notebook-cell:/c%3A/Users/William/OneDrive/Research/Changed_actionspace.ipynb#ch0000020?line=11'>12</a> model.learn(total_timesteps=400000)
#      <a href='vscode-notebook-cell:/c%3A/Users/William/OneDrive/Research/Changed_actionspace.ipynb#ch0000020?line=13'>14</a> # Evaluate model
#      <a href='vscode-notebook-cell:/c%3A/Users/William/OneDrive/Research/Changed_actionspace.ipynb#ch0000020?line=14'>15</a> mean_reward, _ = evaluate_policy(model, env, n_eval_episodes=5)
#
# File e:\Anaconda\lib\site-packages\stable_baselines3\ppo\ppo.py:304, in PPO.learn(self, total_timesteps, callback, log_interval, eval_env, eval_freq, n_eval_episodes, tb_log_name, eval_log_path, reset_num_timesteps)
#     291 def learn(
#     292     self,
#     293     total_timesteps: int,
#    (...)
#     301     reset_num_timesteps: bool = True,
#     302 ) -> "PPO":
# --> 304     return super(PPO, self).learn(
#     305         total_timesteps=total_timesteps,
#     306         callback=callback,
#     307         log_interval=log_interval,
#     308         eval_env=eval_env,
#     309         eval_freq=eval_freq,
#     310         n_eval_episodes=n_eval_episodes,
#     311         tb_log_name=tb_log_name,
#     312         eval_log_path=eval_log_path,
#     313         reset_num_timesteps=reset_num_timesteps,
#     314     )
#
# File e:\Anaconda\lib\site-packages\stable_baselines3\common\on_policy_algorithm.py:250, in OnPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, eval_env, eval_freq, n_eval_episodes, tb_log_name, eval_log_path, reset_num_timesteps)
#     246 callback.on_training_start(locals(), globals())
#     248 while self.num_timesteps < total_timesteps:
# --> 250     continue_training = self.collect_rollouts(self.env, callback, self.rollout_buffer, n_rollout_steps=self.n_steps)
#     252     if continue_training is False:
#     253         break
#
# File e:\Anaconda\lib\site-packages\stable_baselines3\common\on_policy_algorithm.py:169, in OnPolicyAlgorithm.collect_rollouts(self, env, callback, rollout_buffer, n_rollout_steps)
#     166 with th.no_grad():
#     167     # Convert to pytorch tensor or to TensorDict
#     168     obs_tensor = obs_as_tensor(self._last_obs, self.device)
# --> 169     actions, values, log_probs = self.policy(obs_tensor)
#     170 actions = actions.cpu().numpy()
#     172 # Rescale and perform action
#
# File e:\Anaconda\lib\site-packages\torch\nn\modules\module.py:1102, in Module._call_impl(self, *input, **kwargs)
#    1098 # If we don't have any hooks, we want to skip the rest of the logic in
#    1099 # this function, and just call forward.
#    1100 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102     return forward_call(*input, **kwargs)
#    1103 # Do not call functions when jit is used
#    1104 full_backward_hooks, non_full_backward_hooks = [], []
#
# File e:\Anaconda\lib\site-packages\stable_baselines3\common\policies.py:594, in ActorCriticPolicy.forward(self, obs, deterministic)
#     592 distribution = self._get_action_dist_from_latent(latent_pi)
#     593 actions = distribution.get_actions(deterministic=deterministic)
# --> 594 log_prob = distribution.log_prob(actions)
#     595 return actions, values, log_prob
#
# File e:\Anaconda\lib\site-packages\stable_baselines3\common\distributions.py:278, in CategoricalDistribution.log_prob(self, actions)
#     277 def log_prob(self, actions: th.Tensor) -> th.Tensor:
# --> 278     return self.distribution.log_prob(actions)
#
# File e:\Anaconda\lib\site-packages\torch\distributions\categorical.py:121, in Categorical.log_prob(self, value)
#     119 value, log_pmf = torch.broadcast_tensors(value, self.logits)
#     120 value = value[..., :1]
# --> 121 return log_pmf.gather(-1, value).squeeze(-1)
#
# KeyboardInterrupt:

# %% [markdown]
# -------- Load the Best Model ----------

# %%
best_model = 'trial_0_best_model.zip'
study.best_params
study.best_trial
# Out:
# FrozenTrial(number=0, values=[487.6], datetime_start=datetime.datetime(2022, 6, 27, 12, 9, 15, 38923), datetime_complete=datetime.datetime(2022, 6, 27, 12, 31, 14, 783395), params={'n_steps': 5058, 'gamma': 0.916284227537185, 'learning_rate': 2.447493121513805e-05, 'clip_range': 0.23938406335264115, 'gae_lambda': 0.8784354563456847}, distributions={'n_steps': IntUniformDistribution(high=8192, low=2048, step=1), 'gamma': LogUniformDistribution(high=0.9999, low=0.8), 'learning_rate': LogUniformDistribution(high=0.0001, low=1e-05), 'clip_range': UniformDistribution(high=0.4, low=0.1), 'gae_lambda': UniformDistribution(high=0.99, low=0.8)}, user_attrs={}, system_attrs={}, intermediate_values={}, trial_id=0, state=TrialState.COMPLETE, value=None)

# %%
model = PPO.load(os.path.join(OPT_DIR, best_model))

# %% [markdown]
# ---------- Callback ----------

# %%
from stable_baselines3.common.callbacks import BaseCallback

# %%
class TrainAndLoggingCallback(BaseCallback):

    def __init__(self, check_freq, save_path, verbose=1):
        super(TrainAndLoggingCallback, self).__init__(verbose)
        self.check_freq = check_freq
        self.save_path = save_path

    def _init_callback(self):
        if self.save_path is not None:
            os.makedirs(self.save_path, exist_ok=True)

    def _on_step(self):
        if self.n_calls % self.check_freq == 0:
            model_path = os.path.join(self.save_path, 'best_model_{}'.format(self.n_calls))
            self.model.save(model_path)
        return True

# %%
CHECKPOINT_DIR = './train/'
callback = TrainAndLoggingCallback(check_freq=10000, save_path=CHECKPOINT_DIR)

# %% [markdown]
# ---------- Train the Model ----------

# %%
env = BattleEnvironment()
env = Monitor(env, LOG_DIR)
env = DummyVecEnv([lambda: env])
env = VecFrameStack(env, 4, channels_order='last')

# %%
model_params = study.best_params
model_params['n_steps'] = (model_params['n_steps'] // 64) * 64 # set to a factor of 64
model = PPO('MlpPolicy', env, tensorboard_log=LOG_DIR, verbose=1, **model_params)
# Out:
# Using cuda device

# %%
model.load(os.path.join(OPT_DIR, best_model))
model.learn(total_timesteps=4000000, callback=callback)
# Out:
# Logging to ./logs/PPO_7
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 85.8     |
# |    ep_rew_mean     | -4.1     |
# | time/              |          |
# |    fps             | 523      |
# |    iterations      | 1        |
# |    time_elapsed    | 9        |
# |    total_timesteps | 5056     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 84.8        |
# |    ep_rew_mean          | 0.54        |
# | time/                   |             |
# |    fps                  | 387         |
# |    iterations           | 2           |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 10112       |
# | train/                  |             |
# |    approx_kl            | 0.005344012 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.239       |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | -0.000553   |
# |    learning_rate        | 2.45e-05    |
# |    loss                 | 144         |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00471    |
# |    value_loss           | 7.86e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 84.8        |
# |    ep_rew_mean          | 14.7        |
# | time/                   |             |
# |    fps                  | 331         |
# |    iterations           | 3           |
# |    time_elapsed         | 45          |
# |    total_timesteps      | 15168       |
# | train/                  |             |
# |    approx_kl            | 0.002102127 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.239       |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 0.00169     |
# |    learning_rate        | 2.45e-05    |
# |    loss                 | 6.07e+03    |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00198    |
# |    value_loss           | 8.93e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 80.3         |
# |    ep_rew_mean          | 103          |
# | time/                   |              |
# |    fps                  | 319          |
# |    iterations           | 4            |
# |    time_elapsed         | 63           |
# |    total_timesteps      | 20224        |
# | train/                  |              |
# |    approx_kl            | 0.0019976455 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.239        |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | 0.000779     |
# |    learning_rate        | 2.45e-05     |
# |    loss                 | 4.65e+03     |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.0017      |
# |    value_loss           | 7.32e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 82.2         |
# |    ep_rew_mean          | 85.9         |
# | time/                   |              |
# |    fps                  | 305          |
# |    iterations           | 5            |
# |    time_elapsed         | 82           |
# |    total_timesteps      | 25280        |
# | train/                  |              |
# |    approx_kl            | 0.0012488575 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.239        |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 0.00029      |
# |    learning_rate        | 2.45e-05     |
# |    loss                 | 602          |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00121     |
# |    value_loss           | 9.45e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 81.1         |
# |    ep_rew_mean          | 126          |
# | time/                   |              |
# |    fps                  | 300          |
# |    iterations           | 6            |
# |    time_elapsed         | 101          |
# |    total_timesteps      | 30336        |
# | train/                  |              |
# |    approx_kl            | 0.0021197316 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.239        |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | 0.00165      |
# |    learning_rate        | 2.45e-05     |
# |    loss                 | 1.05e+04     |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.00163     |
# |    value_loss           | 8.99e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 81.6         |
# |    ep_rew_mean          | 130          |
# | time/                   |              |
# |    fps                  | 301          |
# |    iterations           | 7            |
# |    time_elapsed         | 117          |
# |    total_timesteps      | 35392        |
# | train/                  |              |
# |    approx_kl            | 0.0010343082 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.239        |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | 0.000769     |
# |    learning_rate        | 2.45e-05     |
# |    loss                 | 3.02e+03     |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00104     |
# |    value_loss           | 1.16e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 84.2         |
# |    ep_rew_mean          | 66.4         |
# | time/                   |              |
# |    fps                  | 303          |
# |    iterations           | 8            |
# |    time_elapsed         | 133          |
# |    total_timesteps      | 40448        |
# | train/                  |              |
# |    approx_kl            | 0.0017520813 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.239        |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | 0.00157      |
# |    learning_rate        | 2.45e-05     |
# |    loss                 | 2.32e+03     |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00136     |
# |    value_loss           | 9.53e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 84.8        |
# |    ep_rew_mean          | 76.9        |
# | time/                   |             |
# |    fps                  | 301         |
# |    iterations           | 9           |
# |    time_elapsed         | 151         |
# |    total_timesteps      | 45504       |
# | train/                  |             |
# |    approx_kl            | 0.008174954 |
# |    clip_fraction        | 0.000692    |
# |    clip_range           | 0.239       |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | 0.00182     |
# |    learning_rate        | 2.45e-05    |
# |    loss                 | 92.2        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00323    |
# |    value_loss           | 7.19e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 86.2         |
# |    ep_rew_mean          | 82.2         |
# | time/                   |              |
# |    fps                  | 300          |
# |    iterations           | 10           |
# |    time_elapsed         | 168          |
# |    total_timesteps      | 50560        |
# | train/                  |              |
# |    approx_kl            | 0.0015938808 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.239        |
# |    entropy_loss         | -1.26        |
# |    explained_variance   | 0.000368     |
# |    learning_rate        | 2.45e-05     |
# |    loss                 | 9.11e+03     |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00156     |
# |    value_loss           | 1.04e+04     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 90.7          |
# |    ep_rew_mean          | 49.5          |
# | time/                   |               |
# |    fps                  | 300           |
# |    iterations           | 11            |
# |    time_elapsed         | 185           |
# |    total_timesteps      | 55616         |
# | train/                  |               |
# |    approx_kl            | 0.00085909147 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.239         |
# |    entropy_loss         | -1.24         |
# |    explained_variance   | 0.000681      |
# |    learning_rate        | 2.45e-05      |
# |    loss                 | 353           |
# |    n_updates            | 100           |
# |    policy_gradient_loss | -0.000743     |
# |    value_loss           | 8.41e+03      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 81.7          |
# |    ep_rew_mean          | 171           |
# | time/                   |               |
# |    fps                  | 301           |
# |    iterations           | 12            |
# |    time_elapsed         | 201           |
# |    total_timesteps      | 60672         |
# | train/                  |               |
# |    approx_kl            | 0.00032131455 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.239         |
# |    entropy_loss         | -1.22         |
# |    explained_variance   | -5.46e-05     |
# |    learning_rate        | 2.45e-05      |
# |    loss                 | 8.94e+03      |
# |    n_updates            | 110           |
# |    policy_gradient_loss | -0.000542     |
# |    value_loss           | 6.78e+03      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 85.8          |
# |    ep_rew_mean          | 80.9          |
# | time/                   |               |
# |    fps                  | 301           |
# |    iterations           | 13            |
# |    time_elapsed         | 218           |
# |    total_timesteps      | 65728         |
# | train/                  |               |
# |    approx_kl            | 0.00032339842 |
# |    clip_fraction        | 7.91e-05      |
# |    clip_range           | 0.239         |
# |    entropy_loss         | -1.22         |
# |    explained_variance   | 0.00089       |
# |    learning_rate        | 2.45e-05      |
# |    loss                 | 1.49e+04      |
# |    n_updates            | 120           |
# |    policy_gradient_loss | -0.00069      |
# |    value_loss           | 1.32e+04      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 83.8          |
# |    ep_rew_mean          | 141           |
# | time/                   |               |
# |    fps                  | 300           |
# |    iterations           | 14            |
# |    time_elapsed         | 235           |
# |    total_timesteps      | 70784         |
# | train/                  |               |
# |    approx_kl            | 0.00040524462 |
# |    clip_fraction        | 0.000158      |
# |    clip_range           | 0.239         |
# |    entropy_loss         | -1.21         |
# |    explained_variance   | -0.00119      |
# |    learning_rate        | 2.45e-05      |
# |    loss                 | 282           |
# |    n_updates            | 130           |
# |    policy_gradient_loss | -0.000738     |
# |    value_loss           | 6.75e+03      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 83.5         |
# |    ep_rew_mean          | 101          |
# | time/                   |              |
# |    fps                  | 299          |
# |    iterations           | 15           |
# |    time_elapsed         | 253          |
# |    total_timesteps      | 75840        |
# | train/                  |              |
# |    approx_kl            | 0.0013371311 |
# |    clip_fraction        | 3.96e-05     |
# |    clip_range           | 0.239        |
# |    entropy_loss         | -1.19        |
# |    explained_variance   | 0.00118      |
# |    learning_rate        | 2.45e-05     |
# |    loss                 | 7.89e+03     |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.001       |
# |    value_loss           | 1.17e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 83           |
# |    ep_rew_mean          | 154          |
# | time/                   |              |
# |    fps                  | 298          |
# |    iterations           | 16           |
# |    time_elapsed         | 271          |
# |    total_timesteps      | 80896        |
# | train/                  |              |
# |    approx_kl            | 0.0009355779 |
# |    clip_fraction        | 0.000435     |
# |    clip_range           | 0.239        |
# |    entropy_loss         | -1.17        |
# |    explained_variance   | 0.00115      |
# |    learning_rate        | 2.45e-05     |
# |    loss                 | 9.23e+03     |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.001       |
# |    value_loss           | 6.66e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 81.6         |
# |    ep_rew_mean          | 189          |
# | time/                   |              |
# |    fps                  | 296          |
# |    iterations           | 17           |
# |    time_elapsed         | 290          |
# |    total_timesteps      | 85952        |
# | train/                  |              |
# |    approx_kl            | 0.0005304159 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.239        |
# |    entropy_loss         | -1.16        |
# |    explained_variance   | 0.000465     |
# |    learning_rate        | 2.45e-05     |
# |    loss                 | 122          |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.000681    |
# |    value_loss           | 1.41e+04     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 85.9          |
# |    ep_rew_mean          | 101           |
# | time/                   |               |
# |    fps                  | 294           |
# |    iterations           | 18            |
# |    time_elapsed         | 308           |
# |    total_timesteps      | 91008         |
# | train/                  |               |
# |    approx_kl            | 0.00027076938 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.239         |
# |    entropy_loss         | -1.14         |
# |    explained_variance   | 0.000975      |
# |    learning_rate        | 2.45e-05      |
# |    loss                 | 77.1          |
# |    n_updates            | 170           |
# |    policy_gradient_loss | -0.00073      |
# |    value_loss           | 8.66e+03      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 86.6         |
# |    ep_rew_mean          | 93.5         |
# | time/                   |              |
# |    fps                  | 294          |
# |    iterations           | 19           |
# |    time_elapsed         | 326          |
# |    total_timesteps      | 96064        |
# | train/                  |              |
# |    approx_kl            | 0.0010577806 |
# |    clip_fraction        | 0.000316     |
# |    clip_range           | 0.239        |
# |    entropy_loss         | -1.13        |
# |    explained_variance   | 0.000881     |
# |    learning_rate        | 2.45e-05     |
# |    loss                 | 2.93e+03     |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.000937    |
# |    value_loss           | 1e+04        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 87.2         |
# |    ep_rew_mean          | 107          |
# | time/                   |              |
# |    fps                  | 294          |
# |    iterations           | 20           |
# |    time_elapsed         | 343          |
# |    total_timesteps      | 101120       |
# | train/                  |              |
# |    approx_kl            | 0.0077325236 |
# |    clip_fraction        | 0.0034       |
# |    clip_range           | 0.239        |
# |    entropy_loss         | -1.08        |
# |    explained_variance   | 0.000503     |
# |    learning_rate        | 2.45e-05     |
# |    loss                 | 7.89e+03     |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00343     |
# |    value_loss           | 5.6e+03      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 82.2         |
# |    ep_rew_mean          | 186          |
# | time/                   |              |
# |    fps                  | 294          |
# |    iterations           | 21           |
# |    time_elapsed         | 360          |
# |    total_timesteps      | 106176       |
# | train/                  |              |
# |    approx_kl            | 0.0011351049 |
# |    clip_fraction        | 1.98e-05     |
# |    clip_range           | 0.239        |
# |    entropy_loss         | -1.03        |
# |    explained_variance   | 7.93e-06     |
# |    learning_rate        | 2.45e-05     |
# |    loss                 | 1.25e+03     |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00103     |
# |    value_loss           | 1.01e+04     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 83.6          |
# |    ep_rew_mean          | 165           |
# | time/                   |               |
# |    fps                  | 293           |
# |    iterations           | 22            |
# |    time_elapsed         | 379           |
# |    total_timesteps      | 111232        |
# | train/                  |               |
# |    approx_kl            | 0.00038921664 |
# |    clip_fraction        | 5.93e-05      |
# |    clip_range           | 0.239         |
# |    entropy_loss         | -1.02         |
# |    explained_variance   | 0.000257      |
# |    learning_rate        | 2.45e-05      |
# |    loss                 | 6.65e+03      |
# |    n_updates            | 210           |
# |    policy_gradient_loss | -0.000628     |
# |    value_loss           | 1.17e+04      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 86.6         |
# |    ep_rew_mean          | 79.8         |
# | time/                   |              |
# |    fps                  | 292          |
# |    iterations           | 23           |
# |    time_elapsed         | 396          |
# |    total_timesteps      | 116288       |
# | train/                  |              |
# |    approx_kl            | 0.0034049666 |
# |    clip_fraction        | 0.000119     |
# |    clip_range           | 0.239        |
# |    entropy_loss         | -1.05        |
# |    explained_variance   | 0.000908     |
# |    learning_rate        | 2.45e-05     |
# |    loss                 | 1.57e+03     |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00213     |
# |    value_loss           | 7.22e+03     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 81.9          |
# |    ep_rew_mean          | 158           |
# | time/                   |               |
# |    fps                  | 292           |
# |    iterations           | 24            |
# |    time_elapsed         | 414           |
# |    total_timesteps      | 121344        |
# | train/                  |               |
# |    approx_kl            | 0.00073261815 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.239         |
# |    entropy_loss         | -1.05         |
# |    explained_variance   | 0.000648      |
# |    learning_rate        | 2.45e-05      |
# |    loss                 | 3.44e+03      |
# |    n_updates            | 230           |
# |    policy_gradient_loss | -0.00101      |
# |    value_loss           | 8.34e+03      |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 84.7          |
# |    ep_rew_mean          | 102           |
# | time/                   |               |
# |    fps                  | 293           |
# |    iterations           | 25            |
# |    time_elapsed         | 430           |
# |    total_timesteps      | 126400        |
# | train/                  |               |
# |    approx_kl            | 0.00066979666 |
# |    clip_fraction        | 1.98e-05      |
# |    clip_range           | 0.239         |
# |    entropy_loss         | -1.05         |
# |    explained_variance   | 0.00138       |
# |    learning_rate        | 2.45e-05      |
# |    loss                 | 64.2          |
# |    n_updates            | 240           |
# |    policy_gradient_loss | -0.000608     |
# |    value_loss           | 1.06e+04      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 79           |
# |    ep_rew_mean          | 228          |
# | time/                   |              |
# |    fps                  | 292          |
# |    iterations           | 26           |
# |    time_elapsed         | 448          |
# |    total_timesteps      | 131456       |
# | train/                  |              |
# |    approx_kl            | 0.0006533457 |
# |    clip_fraction        | 9.89e-05     |
# |    clip_range           | 0.239        |
# |    entropy_loss         | -1.05        |
# |    explained_variance   | 0.000886     |
# |    learning_rate        | 2.45e-05     |
# |    loss                 | 7.82e+03     |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.00114     |
# |    value_loss           | 7.82e+03     |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 78.7       |
# |    ep_rew_mean          | 188        |
# | time/                   |            |
# |    fps                  | 293        |
# |    iterations           | 27         |
# |    time_elapsed         | 465        |
# |    total_timesteps      | 136512     |
# | train/                  |            |
# |    approx_kl            | 0.00028565 |
# |    clip_fraction        | 0          |
# |    clip_range           | 0.239      |
# |    entropy_loss         | -1.04      |
# |    explained_variance   | 0.000334   |
# |    learning_rate        | 2.45e-05   |
# |    loss                 | 2.3e+03    |
# |    n_updates            | 260        |
# |    policy_gradient_loss | -0.000652  |
# |    value_loss           | 1.3e+04    |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 83.7         |
# |    ep_rew_mean          | 136          |
# | time/                   |              |
# |    fps                  | 293          |
# |    iterations           | 28           |
# |    time_elapsed         | 481          |
# |    total_timesteps      | 141568       |
# | train/                  |              |
# |    approx_kl            | 0.0003097505 |
# |    clip_fraction        | 0.000138     |
# |    clip_range           | 0.239        |
# |    entropy_loss         | -1.04        |
# |    explained_variance   | 0.00144      |
# |    learning_rate        | 2.45e-05     |
# |    loss                 | 5.63e+03     |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.000731    |
# |    value_loss           | 9.04e+03     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 87.5          |
# |    ep_rew_mean          | 86.2          |
# | time/                   |               |
# |    fps                  | 294           |
# |    iterations           | 29            |
# |    time_elapsed         | 497           |
# |    total_timesteps      | 146624        |
# | train/                  |               |
# |    approx_kl            | 0.00013987195 |
# |    clip_fraction        | 0.000158      |
# |    clip_range           | 0.239         |
# |    entropy_loss         | -1.03         |
# |    explained_variance   | 0.0019        |
# |    learning_rate        | 2.45e-05      |
# |    loss                 | 4.79e+03      |
# |    n_updates            | 280           |
# |    policy_gradient_loss | -0.00083      |
# |    value_loss           | 8.87e+03      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 90           |
# |    ep_rew_mean          | 55.2         |
# | time/                   |              |
# |    fps                  | 295          |
# |    iterations           | 30           |
# |    time_elapsed         | 513          |
# |    total_timesteps      | 151680       |
# | train/                  |              |
# |    approx_kl            | 0.0009983358 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.239        |
# |    entropy_loss         | -1.04        |
# |    explained_variance   | -0.000664    |
# |    learning_rate        | 2.45e-05     |
# |    loss                 | 8.35e+03     |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.00116     |
# |    value_loss           | 7.26e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 88.4         |
# |    ep_rew_mean          | 45           |
# | time/                   |              |
# |    fps                  | 296          |
# |    iterations           | 31           |
# |    time_elapsed         | 529          |
# |    total_timesteps      | 156736       |
# | train/                  |              |
# |    approx_kl            | 0.0036348845 |
# |    clip_fraction        | 0.000138     |
# |    clip_range           | 0.239        |
# |    entropy_loss         | -1.06        |
# |    explained_variance   | 0.00053      |
# |    learning_rate        | 2.45e-05     |
# |    loss                 | 159          |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.00168     |
# |    value_loss           | 6.1e+03      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 83.5         |
# |    ep_rew_mean          | 138          |
# | time/                   |              |
# |    fps                  | 297          |
# |    iterations           | 32           |
# |    time_elapsed         | 544          |
# |    total_timesteps      | 161792       |
# | train/                  |              |
# |    approx_kl            | 0.0005772212 |
# |    clip_fraction        | 0.000534     |
# |    clip_range           | 0.239        |
# |    entropy_loss         | -1.07        |
# |    explained_variance   | 0.00122      |
# |    learning_rate        | 2.45e-05     |
# |    loss                 | 2.18e+03     |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.000914    |
# |    value_loss           | 7.22e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 85.7         |
# |    ep_rew_mean          | 93.7         |
# | time/                   |              |
# |    fps                  | 298          |
# |    iterations           | 33           |
# |    time_elapsed         | 559          |
# |    total_timesteps      | 166848       |
# | train/                  |              |
# |    approx_kl            | 0.0020491926 |
# |    clip_fraction        | 0.000534     |
# |    clip_range           | 0.239        |
# |    entropy_loss         | -1.07        |
# |    explained_variance   | 0.00101      |
# |    learning_rate        | 2.45e-05     |
# |    loss                 | 1.44e+03     |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.00125     |
# |    value_loss           | 1.1e+04      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 83.9         |
# |    ep_rew_mean          | 128          |
# | time/                   |              |
# |    fps                  | 298          |
# |    iterations           | 34           |
# |    time_elapsed         | 575          |
# |    total_timesteps      | 171904       |
# | train/                  |              |
# |    approx_kl            | 0.0007120876 |
# |    clip_fraction        | 0.000138     |
# |    clip_range           | 0.239        |
# |    entropy_loss         | -1.08        |
# |    explained_variance   | 0.00148      |
# |    learning_rate        | 2.45e-05     |
# |    loss                 | 3.31e+03     |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.000653    |
# |    value_loss           | 6.17e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 85.3         |
# |    ep_rew_mean          | 93.2         |
# | time/                   |              |
# |    fps                  | 299          |
# |    iterations           | 35           |
# |    time_elapsed         | 590          |
# |    total_timesteps      | 176960       |
# | train/                  |              |
# |    approx_kl            | 0.0022437817 |
# |    clip_fraction        | 0.000178     |
# |    clip_range           | 0.239        |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | 0.000499     |
# |    learning_rate        | 2.45e-05     |
# |    loss                 | 3.29e+03     |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.000887    |
# |    value_loss           | 1.05e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 84.8         |
# |    ep_rew_mean          | 146          |
# | time/                   |              |
# |    fps                  | 300          |
# |    iterations           | 36           |
# |    time_elapsed         | 605          |
# |    total_timesteps      | 182016       |
# | train/                  |              |
# |    approx_kl            | 0.0007678565 |
# |    clip_fraction        | 0.000138     |
# |    clip_range           | 0.239        |
# |    entropy_loss         | -1.1         |
# |    explained_variance   | 0.00135      |
# |    learning_rate        | 2.45e-05     |
# |    loss                 | 5.04e+03     |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.000509    |
# |    value_loss           | 6.16e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 87.4         |
# |    ep_rew_mean          | 113          |
# | time/                   |              |
# |    fps                  | 301          |
# |    iterations           | 37           |
# |    time_elapsed         | 620          |
# |    total_timesteps      | 187072       |
# | train/                  |              |
# |    approx_kl            | 0.0012248714 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.239        |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | 0.000533     |
# |    learning_rate        | 2.45e-05     |
# |    loss                 | 1.89e+04     |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.000581    |
# |    value_loss           | 1.16e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 85.4         |
# |    ep_rew_mean          | 157          |
# | time/                   |              |
# |    fps                  | 302          |
# |    iterations           | 38           |
# |    time_elapsed         | 635          |
# |    total_timesteps      | 192128       |
# | train/                  |              |
# |    approx_kl            | 0.0036186134 |
# |    clip_fraction        | 0.000119     |
# |    clip_range           | 0.239        |
# |    entropy_loss         | -1.07        |
# |    explained_variance   | 0.000413     |
# |    learning_rate        | 2.45e-05     |
# |    loss                 | 135          |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.00088     |
# |    value_loss           | 7.77e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 85.5         |
# |    ep_rew_mean          | 95           |
# | time/                   |              |
# |    fps                  | 302          |
# |    iterations           | 39           |
# |    time_elapsed         | 650          |
# |    total_timesteps      | 197184       |
# | train/                  |              |
# |    approx_kl            | 9.682613e-05 |
# |    clip_fraction        | 0.000158     |
# |    clip_range           | 0.239        |
# |    entropy_loss         | -1.07        |
# |    explained_variance   | 0.00064      |
# |    learning_rate        | 2.45e-05     |
# |    loss                 | 6.12e+03     |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.000691    |
# |    value_loss           | 1.05e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 87.8         |
# |    ep_rew_mean          | 103          |
# | time/                   |              |
# |    fps                  | 303          |
# |    iterations           | 40           |
# |    time_elapsed         | 666          |
# |    total_timesteps      | 202240       |
# | train/                  |              |
# |    approx_kl            | 0.0007183809 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.239        |
# |    entropy_loss         | -1.05        |
# |    explained_variance   | 0.000731     |
# |    learning_rate        | 2.45e-05     |
# |    loss                 | 140          |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.000542    |
# |    value_loss           | 6.72e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 91.1        |
# |    ep_rew_mean          | 53.4        |
# | time/                   |             |
# |    fps                  | 304         |
# |    iterations           | 41          |
# |    time_elapsed         | 680         |
# |    total_timesteps      | 207296      |
# | train/                  |             |
# |    approx_kl            | 0.000391366 |
# |    clip_fraction        | 0.000198    |
# |    clip_range           | 0.239       |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | -0.00183    |
# |    learning_rate        | 2.45e-05    |
# |    loss                 | 124         |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.000846   |
# |    value_loss           | 8.89e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 86.5         |
# |    ep_rew_mean          | 104          |
# | time/                   |              |
# |    fps                  | 304          |
# |    iterations           | 42           |
# |    time_elapsed         | 696          |
# |    total_timesteps      | 212352       |
# | train/                  |              |
# |    approx_kl            | 0.0009919191 |
# |    clip_fraction        | 0.000415     |
# |    clip_range           | 0.239        |
# |    entropy_loss         | -1.04        |
# |    explained_variance   | 0.000691     |
# |    learning_rate        | 2.45e-05     |
# |    loss                 | 7.81e+03     |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.00078     |
# |    value_loss           | 5.36e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 89.1         |
# |    ep_rew_mean          | 58.9         |
# | time/                   |              |
# |    fps                  | 305          |
# |    iterations           | 43           |
# |    time_elapsed         | 712          |
# |    total_timesteps      | 217408       |
# | train/                  |              |
# |    approx_kl            | 0.0030460092 |
# |    clip_fraction        | 0.000138     |
# |    clip_range           | 0.239        |
# |    entropy_loss         | -1.03        |
# |    explained_variance   | 0.00113      |
# |    learning_rate        | 2.45e-05     |
# |    loss                 | 59.5         |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.00188     |
# |    value_loss           | 9.46e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 93.5         |
# |    ep_rew_mean          | 19.4         |
# | time/                   |              |
# |    fps                  | 305          |
# |    iterations           | 44           |
# |    time_elapsed         | 727          |
# |    total_timesteps      | 222464       |
# | train/                  |              |
# |    approx_kl            | 0.0042040856 |
# |    clip_fraction        | 0.000455     |
# |    clip_range           | 0.239        |
# |    entropy_loss         | -1.04        |
# |    explained_variance   | -0.000414    |
# |    learning_rate        | 2.45e-05     |
# |    loss                 | 8.08e+03     |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.00174     |
# |    value_loss           | 5.06e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 86.4         |
# |    ep_rew_mean          | 153          |
# | time/                   |              |
# |    fps                  | 306          |
# |    iterations           | 45           |
# |    time_elapsed         | 743          |
# |    total_timesteps      | 227520       |
# | train/                  |              |
# |    approx_kl            | 0.0031033177 |
# |    clip_fraction        | 5.93e-05     |
# |    clip_range           | 0.239        |
# |    entropy_loss         | -1.05        |
# |    explained_variance   | -0.000808    |
# |    learning_rate        | 2.45e-05     |
# |    loss                 | 1.02e+03     |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.0021      |
# |    value_loss           | 5.42e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 83           |
# |    ep_rew_mean          | 133          |
# | time/                   |              |
# |    fps                  | 306          |
# |    iterations           | 46           |
# |    time_elapsed         | 758          |
# |    total_timesteps      | 232576       |
# | train/                  |              |
# |    approx_kl            | 0.0006335954 |
# |    clip_fraction        | 0.000119     |
# |    clip_range           | 0.239        |
# |    entropy_loss         | -1.03        |
# |    explained_variance   | -0.000183    |
# |    learning_rate        | 2.45e-05     |
# |    loss                 | 572          |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.000536    |
# |    value_loss           | 1.26e+04     |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 80         |
# |    ep_rew_mean          | 215        |
# | time/                   |            |
# |    fps                  | 307        |
# |    iterations           | 47         |
# |    time_elapsed         | 772        |
# |    total_timesteps      | 237632     |
# | train/                  |            |
# |    approx_kl            | 0.00552583 |
# |    clip_fraction        | 0.0175     |
# |    clip_range           | 0.239      |
# |    entropy_loss         | -1.06      |
# |    explained_variance   | -0.000589  |
# |    learning_rate        | 2.45e-05   |
# |    loss                 | 104        |
# |    n_updates            | 460        |
# |    policy_gradient_loss | -0.0038    |
# |    value_loss           | 7.73e+03   |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 84           |
# |    ep_rew_mean          | 142          |
# | time/                   |              |
# |    fps                  | 307          |
# |    iterations           | 48           |
# |    time_elapsed         | 788          |
# |    total_timesteps      | 242688       |
# | train/                  |              |
# |    approx_kl            | 0.0016047253 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.239        |
# |    entropy_loss         | -1.06        |
# |    explained_variance   | 0.000858     |
# |    learning_rate        | 2.45e-05     |
# |    loss                 | 2.35e+03     |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.000872    |
# |    value_loss           | 1.28e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 85.5         |
# |    ep_rew_mean          | 98.5         |
# | time/                   |              |
# |    fps                  | 308          |
# |    iterations           | 49           |
# |    time_elapsed         | 803          |
# |    total_timesteps      | 247744       |
# | train/                  |              |
# |    approx_kl            | 0.0034516198 |
# |    clip_fraction        | 0.000198     |
# |    clip_range           | 0.239        |
# |    entropy_loss         | -1.03        |
# |    explained_variance   | -0.00023     |
# |    learning_rate        | 2.45e-05     |
# |    loss                 | 66.7         |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.00183     |
# |    value_loss           | 6.73e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 82           |
# |    ep_rew_mean          | 176          |
# | time/                   |              |
# |    fps                  | 308          |
# |    iterations           | 50           |
# |    time_elapsed         | 819          |
# |    total_timesteps      | 252800       |
# | train/                  |              |
# |    approx_kl            | 0.0016232568 |
# |    clip_fraction        | 0.000316     |
# |    clip_range           | 0.239        |
# |    entropy_loss         | -1.01        |
# |    explained_variance   | 7.1e-05      |
# |    learning_rate        | 2.45e-05     |
# |    loss                 | 8.22e+03     |
# |    n_updates            | 490          |
# |    policy_gradient_loss | -0.00146     |
# |    value_loss           | 8.24e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 82.1         |
# |    ep_rew_mean          | 192          |
# | time/                   |              |
# |    fps                  | 308          |
# |    iterations           | 51           |
# |    time_elapsed         | 835          |
# |    total_timesteps      | 257856       |
# | train/                  |              |
# |    approx_kl            | 0.0005815281 |
# |    clip_fraction        | 0.000257     |
# |    clip_range           | 0.239        |
# |    entropy_loss         | -1.01        |
# |    explained_variance   | -0.000378    |
# |    learning_rate        | 2.45e-05     |
# |    loss                 | 1.35e+04     |
# |    n_updates            | 500          |
# |    policy_gradient_loss | -0.00111     |
# |    value_loss           | 1.22e+04     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 89.7          |
# |    ep_rew_mean          | 76            |
# | time/                   |               |
# |    fps                  | 308           |
# |    iterations           | 52            |
# |    time_elapsed         | 851           |
# |    total_timesteps      | 262912        |
# | train/                  |               |
# |    approx_kl            | 0.00047729225 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.239         |
# |    entropy_loss         | -1.02         |
# |    explained_variance   | -0.00067      |
# |    learning_rate        | 2.45e-05      |
# |    loss                 | 145           |
# |    n_updates            | 510           |
# |    policy_gradient_loss | -0.000765     |
# |    value_loss           | 8.23e+03      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 84.5         |
# |    ep_rew_mean          | 131          |
# | time/                   |              |
# |    fps                  | 309          |
# |    iterations           | 53           |
# |    time_elapsed         | 866          |
# |    total_timesteps      | 267968       |
# | train/                  |              |
# |    approx_kl            | 0.0017898721 |
# |    clip_fraction        | 0.000119     |
# |    clip_range           | 0.239        |
# |    entropy_loss         | -0.995       |
# |    explained_variance   | -0.000182    |
# |    learning_rate        | 2.45e-05     |
# |    loss                 | 571          |
# |    n_updates            | 520          |
# |    policy_gradient_loss | -0.00112     |
# |    value_loss           | 7.68e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 81.3         |
# |    ep_rew_mean          | 145          |
# | time/                   |              |
# |    fps                  | 309          |
# |    iterations           | 54           |
# |    time_elapsed         | 882          |
# |    total_timesteps      | 273024       |
# | train/                  |              |
# |    approx_kl            | 0.0012465284 |
# |    clip_fraction        | 0.000574     |
# |    clip_range           | 0.239        |
# |    entropy_loss         | -0.97        |
# ...
# |    learning_rate        | 2.45e-05      |
# |    loss                 | 3.68e+03      |
# |    n_updates            | 4550          |
# |    policy_gradient_loss | -0.000858     |
# |    value_loss           | 7.55e+03      |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 88.9        |
# |    ep_rew_mean          | 87.5        |
# | time/                   |             |
# |    fps                  | 325         |
# |    iterations           | 457         |
# |    time_elapsed         | 7106        |
# |    total_timesteps      | 2310592     |
# | train/                  |             |
# |    approx_kl            | 0.001113598 |
# |    clip_fraction        | 0.0057      |
# |    clip_range           | 0.239       |
# |    entropy_loss         | -0.313      |
# |    explained_variance   | -0.000291   |
# |    learning_rate        | 2.45e-05    |
# |    loss                 | 56.2        |
# |    n_updates            | 4560        |
# |    policy_gradient_loss | -0.00117    |
# |    value_loss           | 6.62e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 86.2         |
# |    ep_rew_mean          | 133          |
# | time/                   |              |
# |    fps                  | 325          |
# |    iterations           | 458          |
# |    time_elapsed         | 7123         |
# |    total_timesteps      | 2315648      |
# | train/                  |              |
# |    approx_kl            | 0.0007551338 |
# |    clip_fraction        | 0.00431      |
# |    clip_range           | 0.239        |
# |    entropy_loss         | -0.303       |
# |    explained_variance   | -0.000316    |
# |    learning_rate        | 2.45e-05     |
# |    loss                 | 4.7e+03      |
# |    n_updates            | 4570         |
# |    policy_gradient_loss | -0.000672    |
# |    value_loss           | 6.71e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 85.7         |
# |    ep_rew_mean          | 154          |
# | time/                   |              |
# |    fps                  | 325          |
# |    iterations           | 459          |
# |    time_elapsed         | 7139         |
# |    total_timesteps      | 2320704      |
# | train/                  |              |
# |    approx_kl            | 0.0015797954 |
# |    clip_fraction        | 0.00651      |
# |    clip_range           | 0.239        |
# |    entropy_loss         | -0.267       |
# |    explained_variance   | 0.00143      |
# |    learning_rate        | 2.45e-05     |
# |    loss                 | 649          |
# |    n_updates            | 4580         |
# |    policy_gradient_loss | -0.00173     |
# |    value_loss           | 1.08e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 85           |
# |    ep_rew_mean          | 152          |
# | time/                   |              |
# |    fps                  | 324          |
# |    iterations           | 460          |
# |    time_elapsed         | 7156         |
# |    total_timesteps      | 2325760      |
# | train/                  |              |
# |    approx_kl            | 0.0010555615 |
# |    clip_fraction        | 0.00388      |
# |    clip_range           | 0.239        |
# |    entropy_loss         | -0.269       |
# |    explained_variance   | 0.00166      |
# |    learning_rate        | 2.45e-05     |
# |    loss                 | 6.44e+03     |
# |    n_updates            | 4590         |
# |    policy_gradient_loss | -0.000529    |
# |    value_loss           | 1.15e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 87.1         |
# |    ep_rew_mean          | 108          |
# | time/                   |              |
# |    fps                  | 324          |
# |    iterations           | 461          |
# |    time_elapsed         | 7172         |
# |    total_timesteps      | 2330816      |
# | train/                  |              |
# |    approx_kl            | 0.0015972616 |
# |    clip_fraction        | 0.00465      |
# |    clip_range           | 0.239        |
# |    entropy_loss         | -0.239       |
# |    explained_variance   | 0.00287      |
# |    learning_rate        | 2.45e-05     |
# |    loss                 | 83           |
# |    n_updates            | 4600         |
# |    policy_gradient_loss | -0.00118     |
# |    value_loss           | 7.67e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 81.2         |
# |    ep_rew_mean          | 211          |
# | time/                   |              |
# |    fps                  | 324          |
# |    iterations           | 462          |
# |    time_elapsed         | 7187         |
# |    total_timesteps      | 2335872      |
# | train/                  |              |
# |    approx_kl            | 0.0005815749 |
# |    clip_fraction        | 0.00212      |
# |    clip_range           | 0.239        |
# |    entropy_loss         | -0.23        |
# |    explained_variance   | -0.00136     |
# |    learning_rate        | 2.45e-05     |
# |    loss                 | 680          |
# |    n_updates            | 4610         |
# |    policy_gradient_loss | -0.000544    |
# |    value_loss           | 8.11e+03     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 80.8          |
# |    ep_rew_mean          | 172           |
# | time/                   |               |
# |    fps                  | 324           |
# |    iterations           | 463           |
# |    time_elapsed         | 7204          |
# |    total_timesteps      | 2340928       |
# | train/                  |               |
# |    approx_kl            | 0.00070345605 |
# |    clip_fraction        | 0.00421       |
# |    clip_range           | 0.239         |
# |    entropy_loss         | -0.22         |
# |    explained_variance   | -0.00102      |
# |    learning_rate        | 2.45e-05      |
# |    loss                 | 5.12e+03      |
# |    n_updates            | 4620          |
# |    policy_gradient_loss | -0.000923     |
# |    value_loss           | 1.24e+04      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 85.5         |
# |    ep_rew_mean          | 79.7         |
# | time/                   |              |
# |    fps                  | 324          |
# |    iterations           | 464          |
# |    time_elapsed         | 7220         |
# |    total_timesteps      | 2345984      |
# | train/                  |              |
# |    approx_kl            | 0.0017631394 |
# |    clip_fraction        | 0.00471      |
# |    clip_range           | 0.239        |
# |    entropy_loss         | -0.256       |
# |    explained_variance   | -0.00391     |
# |    learning_rate        | 2.45e-05     |
# |    loss                 | 903          |
# |    n_updates            | 4630         |
# |    policy_gradient_loss | -0.000658    |
# |    value_loss           | 6.04e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 83.3         |
# |    ep_rew_mean          | 136          |
# | time/                   |              |
# |    fps                  | 324          |
# |    iterations           | 465          |
# |    time_elapsed         | 7236         |
# |    total_timesteps      | 2351040      |
# | train/                  |              |
# |    approx_kl            | 0.0012929189 |
# |    clip_fraction        | 0.00601      |
# |    clip_range           | 0.239        |
# |    entropy_loss         | -0.265       |
# |    explained_variance   | 0.00661      |
# |    learning_rate        | 2.45e-05     |
# |    loss                 | 1.42e+04     |
# |    n_updates            | 4640         |
# |    policy_gradient_loss | -0.00147     |
# |    value_loss           | 7.13e+03     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 82.3          |
# |    ep_rew_mean          | 177           |
# | time/                   |               |
# |    fps                  | 324           |
# |    iterations           | 466           |
# |    time_elapsed         | 7254          |
# |    total_timesteps      | 2356096       |
# | train/                  |               |
# |    approx_kl            | 0.00093863526 |
# |    clip_fraction        | 0.00348       |
# |    clip_range           | 0.239         |
# |    entropy_loss         | -0.225        |
# |    explained_variance   | -0.000439     |
# |    learning_rate        | 2.45e-05      |
# |    loss                 | 8.73e+03      |
# |    n_updates            | 4650          |
# |    policy_gradient_loss | -0.000814     |
# |    value_loss           | 9.92e+03      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 87           |
# |    ep_rew_mean          | 161          |
# | time/                   |              |
# |    fps                  | 324          |
# |    iterations           | 467          |
# |    time_elapsed         | 7272         |
# |    total_timesteps      | 2361152      |
# | train/                  |              |
# |    approx_kl            | 0.0011572115 |
# |    clip_fraction        | 0.00421      |
# |    clip_range           | 0.239        |
# |    entropy_loss         | -0.246       |
# |    explained_variance   | 0.00271      |
# |    learning_rate        | 2.45e-05     |
# |    loss                 | 92.2         |
# |    n_updates            | 4660         |
# |    policy_gradient_loss | -0.00181     |
# |    value_loss           | 8.82e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 84.5         |
# |    ep_rew_mean          | 154          |
# | time/                   |              |
# |    fps                  | 324          |
# |    iterations           | 468          |
# |    time_elapsed         | 7288         |
# |    total_timesteps      | 2366208      |
# | train/                  |              |
# |    approx_kl            | 0.0010538346 |
# |    clip_fraction        | 0.00431      |
# |    clip_range           | 0.239        |
# |    entropy_loss         | -0.232       |
# |    explained_variance   | 0.000995     |
# |    learning_rate        | 2.45e-05     |
# |    loss                 | 1.12e+04     |
# |    n_updates            | 4670         |
# |    policy_gradient_loss | -0.00151     |
# |    value_loss           | 1.15e+04     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 86.3          |
# |    ep_rew_mean          | 141           |
# | time/                   |               |
# |    fps                  | 324           |
# |    iterations           | 469           |
# |    time_elapsed         | 7304          |
# |    total_timesteps      | 2371264       |
# | train/                  |               |
# |    approx_kl            | 0.00043951752 |
# |    clip_fraction        | 0.00156       |
# |    clip_range           | 0.239         |
# |    entropy_loss         | -0.216        |
# |    explained_variance   | 0.00056       |
# |    learning_rate        | 2.45e-05      |
# |    loss                 | 3.33e+03      |
# |    n_updates            | 4680          |
# |    policy_gradient_loss | -0.000689     |
# |    value_loss           | 1.08e+04      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 86.8         |
# |    ep_rew_mean          | 128          |
# | time/                   |              |
# |    fps                  | 324          |
# |    iterations           | 470          |
# |    time_elapsed         | 7322         |
# |    total_timesteps      | 2376320      |
# | train/                  |              |
# |    approx_kl            | 0.0006238622 |
# |    clip_fraction        | 0.00275      |
# |    clip_range           | 0.239        |
# |    entropy_loss         | -0.226       |
# |    explained_variance   | 0.00274      |
# |    learning_rate        | 2.45e-05     |
# |    loss                 | 241          |
# |    n_updates            | 4690         |
# |    policy_gradient_loss | -0.000951    |
# |    value_loss           | 9.32e+03     |
# ------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\William\OneDrive\Research\Changed_actionspace.ipynb Cell 33' in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/William/OneDrive/Research/Changed_actionspace.ipynb#ch0000032?line=0'>1</a> model.load(os.path.join(OPT_DIR, best_model))
# ----> <a href='vscode-notebook-cell:/c%3A/Users/William/OneDrive/Research/Changed_actionspace.ipynb#ch0000032?line=1'>2</a> model.learn(total_timesteps=4000000, callback=callback)
#
# File e:\Anaconda\lib\site-packages\stable_baselines3\ppo\ppo.py:304, in PPO.learn(self, total_timesteps, callback, log_interval, eval_env, eval_freq, n_eval_episodes, tb_log_name, eval_log_path, reset_num_timesteps)
#     291 def learn(
#     292     self,
#     293     total_timesteps: int,
#    (...)
#     301     reset_num_timesteps: bool = True,
#     302 ) -> "PPO":
# --> 304     return super(PPO, self).learn(
#     305         total_timesteps=total_timesteps,
#     306         callback=callback,
#     307         log_interval=log_interval,
#     308         eval_env=eval_env,
#     309         eval_freq=eval_freq,
#     310         n_eval_episodes=n_eval_episodes,
#     311         tb_log_name=tb_log_name,
#     312         eval_log_path=eval_log_path,
#     313         reset_num_timesteps=reset_num_timesteps,
#     314     )
#
# File e:\Anaconda\lib\site-packages\stable_baselines3\common\on_policy_algorithm.py:270, in OnPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, eval_env, eval_freq, n_eval_episodes, tb_log_name, eval_log_path, reset_num_timesteps)
#     267         self.logger.record("time/total_timesteps", self.num_timesteps, exclude="tensorboard")
#     268         self.logger.dump(step=self.num_timesteps)
# --> 270     self.train()
#     272 callback.on_training_end()
#     274 return self
#
# File e:\Anaconda\lib\site-packages\stable_baselines3\ppo\ppo.py:266, in PPO.train(self)
#     264     loss.backward()
#     265     # Clip grad norm
# --> 266     th.nn.utils.clip_grad_norm_(self.policy.parameters(), self.max_grad_norm)
#     267     self.policy.optimizer.step()
#     269 if not continue_training:
#
# File e:\Anaconda\lib\site-packages\torch\nn\utils\clip_grad.py:42, in clip_grad_norm_(parameters, max_norm, norm_type, error_if_nonfinite)
#      40     total_norm = norms[0] if len(norms) == 1 else torch.max(torch.stack(norms))
#      41 else:
# ---> 42     total_norm = torch.norm(torch.stack([torch.norm(p.grad.detach(), norm_type).to(device) for p in parameters]), norm_type)
#      43 if error_if_nonfinite and torch.logical_or(total_norm.isnan(), total_norm.isinf()):
#      44     raise RuntimeError(
#      45         f'The total norm of order {norm_type} for gradients from '
#      46         '`parameters` is non-finite, so it cannot be clipped. To disable '
#      47         'this error and scale the gradients by the non-finite norm anyway, '
#      48         'set `error_if_nonfinite=False`')
#
# KeyboardInterrupt:

# %% [markdown]
# ---------- Evaluation ---------

# %%
env = BattleEnvironment()
env = Monitor(env, LOG_DIR)
env = DummyVecEnv([lambda: env])
env = VecFrameStack(env, 4, channels_order='last')
model = PPO.load(f"./opt/{best_model}")

# %%
episodes = 100
for episode in range(episodes): # Evaluates the model n times
    state = env.reset()
    score = 0
    while not env.env_method('get_done'):
        action, _states = model.predict(state)
        n_state, red_reward, done, info = env.step(action)
        score += red_reward
    print('Episode:{} Score:{}'.format(episode+1, score))
env.env_method('show_wins')
# Out:
# Episode:1 Score:0
# Episode:2 Score:0
# Episode:3 Score:0
# Episode:4 Score:0
# Episode:5 Score:0
# Episode:6 Score:0
# Episode:7 Score:0
# Episode:8 Score:0
# Episode:9 Score:0
# Episode:10 Score:0
# Episode:11 Score:0
# Episode:12 Score:0
# Episode:13 Score:0
# Episode:14 Score:0
# Episode:15 Score:0
# Episode:16 Score:0
# Episode:17 Score:0
# Episode:18 Score:0
# Episode:19 Score:0
# Episode:20 Score:0
# Episode:21 Score:0
# Episode:22 Score:0
# Episode:23 Score:0
# Episode:24 Score:0
# Episode:25 Score:0
# Episode:26 Score:0
# Episode:27 Score:0
# Episode:28 Score:0
# Episode:29 Score:0
# Episode:30 Score:0
# Episode:31 Score:0
# Episode:32 Score:0
# Episode:33 Score:0
# Episode:34 Score:0
# Episode:35 Score:0
# Episode:36 Score:0
# Episode:37 Score:0
# Episode:38 Score:0
# Episode:39 Score:0
# Episode:40 Score:0
# Episode:41 Score:0
# Episode:42 Score:0
# Episode:43 Score:0
# Episode:44 Score:0
# Episode:45 Score:0
# Episode:46 Score:0
# Episode:47 Score:0
# Episode:48 Score:0
# Episode:49 Score:0
# Episode:50 Score:0
# Episode:51 Score:0
# Episode:52 Score:0
# Episode:53 Score:0
# Episode:54 Score:0
# Episode:55 Score:0
# Episode:56 Score:0
# Episode:57 Score:0
# Episode:58 Score:0
# Episode:59 Score:0
# Episode:60 Score:0
# Episode:61 Score:0
# Episode:62 Score:0
# Episode:63 Score:0
# Episode:64 Score:0
# Episode:65 Score:0
# Episode:66 Score:0
# Episode:67 Score:0
# Episode:68 Score:0
# Episode:69 Score:0
# Episode:70 Score:0
# Episode:71 Score:0
# Episode:72 Score:0
# Episode:73 Score:0
# Episode:74 Score:0
# Episode:75 Score:0
# Episode:76 Score:0
# Episode:77 Score:0
# Episode:78 Score:0
# Episode:79 Score:0
# Episode:80 Score:0
# Episode:81 Score:0
# Episode:82 Score:0
# Episode:83 Score:0
# Episode:84 Score:0
# Episode:85 Score:0
# Episode:86 Score:0
# Episode:87 Score:0
# Episode:88 Score:0
# Episode:89 Score:0
# Episode:90 Score:0
# Episode:91 Score:0
# Episode:92 Score:0
# Episode:93 Score:0
# Episode:94 Score:0
# Episode:95 Score:0
# Episode:96 Score:0
# Episode:97 Score:0
# Episode:98 Score:0
# Episode:99 Score:0
# Episode:100 Score:0
# Wins by red: 0
# Wins by blue: 0
# Tied games: 0
# [None]

# %% [markdown]
# --------- Render One Episode ----------

# %%
# Reset game to starting state
obs = env.reset()
# Set flag to flase
done = False
for game in range(1): 
    while not done: 
        if done: 
            obs = env.reset()
        env.render()
        action = model.predict(obs)
        obs, reward, done, info = env.step(action)
        print(reward)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\William\OneDrive\Research\Changed_actionspace.ipynb Cell 38' in <cell line: 5>()
#       <a href='vscode-notebook-cell:/c%3A/Users/William/OneDrive/Research/Changed_actionspace.ipynb#ch0000037?line=6'>7</a> if done:
#       <a href='vscode-notebook-cell:/c%3A/Users/William/OneDrive/Research/Changed_actionspace.ipynb#ch0000037?line=7'>8</a>     obs = env.reset()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/William/OneDrive/Research/Changed_actionspace.ipynb#ch0000037?line=8'>9</a> env.render()
#      <a href='vscode-notebook-cell:/c%3A/Users/William/OneDrive/Research/Changed_actionspace.ipynb#ch0000037?line=9'>10</a> action = model.predict(obs)
#      <a href='vscode-notebook-cell:/c%3A/Users/William/OneDrive/Research/Changed_actionspace.ipynb#ch0000037?line=10'>11</a> obs, reward, done, info = env.step(action)
#
# File e:\Anaconda\lib\site-packages\stable_baselines3\common\vec_env\base_vec_env.py:281, in VecEnvWrapper.render(self, mode)
#     280 def render(self, mode: str = "human") -> Optional[np.ndarray]:
# --> 281     return self.venv.render(mode=mode)
#
# File e:\Anaconda\lib\site-packages\stable_baselines3\common\vec_env\dummy_vec_env.py:85, in DummyVecEnv.render(self, mode)
#      73 """
#      74 Gym environment rendering. If there are multiple environments then
#      75 they are tiled together in one image via ``BaseVecEnv.render()``.
#    (...)
#      82 :param mode: The rendering type.
#      83 """
#      84 if self.num_envs == 1:
# ---> 85     return self.envs[0].render(mode=mode)
#      86 else:
#      87     return super().render(mode=mode)
#
# File e:\Anaconda\lib\site-packages\gym\core.py:295, in Wrapper.render(self, mode, **kwargs)
#     294 def render(self, mode="human", **kwargs):
# --> 295     return self.env.render(mode, **kwargs)
#
# TypeError: render() takes 1 positional argument but 2 were given
